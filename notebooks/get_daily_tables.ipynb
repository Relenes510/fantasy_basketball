# %%
import requests
from bs4 import BeautifulSoup
from nbainjuries import injury
import duckdb
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time
import os
import unicodedata
import warnings

pd.set_option('display.max_rows', None)
warnings.filterwarnings("ignore")

cwd = os.path.abspath(os.getcwd()).replace("\\", "/")
if cwd.startswith("C:/Users/Rodolfo/"):
    RUN_LOCATION = "local"
else:
    RUN_LOCATION = "cloud"
time_offset = {"local": 3, "cloud": -5}

print("Current working dir:", cwd)
print("RUN_LOCATION =", RUN_LOCATION)
# Out:
# Current working dir: C:/Users/Rodolfo/Jupyter_files/FantasyBasketball/notebooks
# RUN_LOCATION = local

# %%
# %run ./common_utils.ipynb

# %% [markdown]
# # Get Injuries Report

# %%
def get_injuries():
    con = duckdb.connect(database=":memory:")
    df_teams = pd.read_csv("../src/team_info_xref.csv")

    df_inj = injury.get_reportdata(datetime.now() + timedelta(hours=time_offset[RUN_LOCATION]), return_df=True)
    df_inj = df_inj.rename(columns={"Game Date": "Date", "Player Name": "Player", "Current Status": "Status"})
    df_inj['Player'] = df_inj.Player.str.split(",").str[1] + " " + df_inj.Player.str.split(",").str[0]
    df_inj['Player'] = df_inj['Player'].str.strip()
    df_inj['Date'] = pd.to_datetime(df_inj['Date'])
    df_inj = con.execute(f"""SELECT Date, ABV as Team, Player, Status, Reason FROM df_inj 
                             JOIN df_teams ON df_inj.Team = df_teams.Team
                             WHERE Date = '{str((datetime.now() + timedelta(hours=time_offset[RUN_LOCATION])).date())}' AND Status != 'Available'""").fetchdf()
    partition_save_df(df_inj, f"../tables/{YEAR}/injuries.csv")
    display(df_inj[df_inj.Status == 'Out'])
get_injuries()
# Out:
# Validated Injury-Report_2026-01-10_05_00PM.
# ../tables/2025/injuries.csv saved!
#           Date Team                Player Status  \
# 0   2026-01-10  MIN           Mike Conley    Out
# 1   2026-01-10  MIN       Enrique Freeman    Out
# 2   2026-01-10  MIN  Terrence Shannon Jr.    Out
# 3   2026-01-10  MIN        Rocco Zikarsky    Out
# 4   2026-01-10  CLE      Chris Livingston    Out
# 5   2026-01-10  CLE             Max Strus    Out
# 6   2026-01-10  CLE          Luke Travers    Out
# 7   2026-01-10  CLE             Dean Wade    Out
# 8   2026-01-10  MIA      Vladislav Goldin    Out
# 10  2026-01-10  MIA          Terry Rozier    Out
# 11  2026-01-10  MIA          Jahmir Young    Out
# 12  2026-01-10  IND     Tyrese Haliburton    Out
# 13  2026-01-10  IND        Isaiah Jackson    Out
# 14  2026-01-10  IND    Bennedict Mathurin    Out
# 17  2026-01-10  IND            Obi Toppin    Out
# 19  2026-01-10  DET           Jalen Duren    Out
# 20  2026-01-10  DET         Tobias Harris    Out
# 21  2026-01-10  DET     Wendell Moore Jr.    Out
# 24  2026-01-10  DAL         Anthony Davis    Out
# 25  2026-01-10  DAL            Dante Exum    Out
# 26  2026-01-10  DAL          Kyrie Irving    Out
# 28  2026-01-10  DAL      Dereck Lively II    Out
# 29  2026-01-10  DAL       P.J. Washington    Out
# 30  2026-01-10  DAL      Brandon Williams    Out
# 31  2026-01-10  CHI          Zach Collins    Out
# 32  2026-01-10  CHI          Noa Essengue    Out
# 33  2026-01-10  CHI           Josh Giddey    Out
# 35  2026-01-10  CHI         Yuki Kawamura    Out
# 36  2026-01-10  CHI        Emanuel Miller    Out
# 39  2026-01-10  SAS       Harrison Ingram    Out
# 40  2026-01-10  SAS    David Jones Garcia    Out
# 41  2026-01-10  SAS         Stanley Umude    Out
# 42  2026-01-10  SAS         Devin Vassell    Out
# 43  2026-01-10  BOS           Josh Minott    Out
# 44  2026-01-10  BOS          Jayson Tatum    Out
# 46  2026-01-10  CHO         Liam McNeeley    Out
# 47  2026-01-10  CHO         Mason Plumlee    Out
# 48  2026-01-10  CHO        Antonio Reeves    Out
# 49  2026-01-10  CHO            KJ Simpson    Out
# 50  2026-01-10  UTA            Ace Bailey    Out
# 51  2026-01-10  UTA       Elijah Harkless    Out
# 52  2026-01-10  UTA        Walker Kessler    Out
# 53  2026-01-10  UTA       Lauri Markkanen    Out
# 54  2026-01-10  UTA         Georges Niang    Out
# 55  2026-01-10  UTA          Jusuf Nurkic    Out
# 56  2026-01-10  UTA            John Tonje    Out
#
#                                                Reason
# 0                                                Rest
# 1                                  G League - Two-Way
# 2   Injury/Illness - Left Foot; Abductor Hallucis ...
# 3                                  G League - Two-Way
# 4                                  G League - Two-Way
# 5   Injury/Illness - Left Foot; Surgery - Jones Fr...
# 6                                  G League - Two-Way
# 7               Injury/Illness - Left Knee; Contusion
# 8                                  G League - Two-Way
# 10                                      Not With Team
# 11                                 G League - Two-Way
# 12       Injury/Illness - Right Achilles Tendon; Tear
# 13                   Injury/Illness - N/A; Concussion
# 14               Injury/Illness - Right Thumb; Sprain
# 17       Injury/Illness - Right Foot; Stress Fracture
# 19               Injury/Illness - Right Ankle; Sprain
# 20                  Injury/Illness - Left Hip; Sprain
# 21                                 G League - Two-Way
# 24               Injury/Illness - Left Finger; Sprain
# 25               Injury/Illness - Right Knee; Surgery
# 26                Injury/Illness - Left Knee; Surgery
# 28               Injury/Illness - Right Foot; Surgery
# 29               Injury/Illness - Right Ankle; Sprain
# 30                  Injury/Illness - Illness; Illness
# 31             Injury/Illness - Right 1st Toe; Sprain
# 32            Injury/Illness - Left Shoulder; Surgery
# 33            Injury/Illness - Left Hamstring; Strain
# 35                                 G League - Two-Way
# 36                                 G League - Two-Way
# 39                                 G League - Two-Way
# 40                                 G League - Two-Way
# 41                                 G League - Two-Way
# 42             Injury/Illness - Left Adductor; Strain
# 43                Injury/Illness - Left Ankle; Sprain
# 44            Injury/Illness - Right Achilles; Repair
# 46                           G League - On Assignment
# 47              Injury/Illness - Right Groin; Surgery
# 48                                 G League - Two-Way
# 49                                 G League - Two-Way
# 50           Injury/Illness - Left Hip Flexor; Strain
# 51                                 G League - Two-Way
# 52    Injury/Illness - Left Shoulder; Injury Recovery
# 53                                               Rest
# 54  Injury/Illness - Left Foot; Fourth Metatarsal ...
# 55            Injury/Illness - Left First MTP; Sprain
# 56                                 G League - Two-Way

# %% [markdown]
# # Get Betting Odds

# %%
def get_game_odds():

    df_gms = pd.read_csv(f"../tables/{YEAR}/nba_schedule.csv")
    df_gms['Date'] = pd.to_datetime(df_gms.Date)
    df_gms_td = df_gms[(df_gms.Date == str((datetime.now() + timedelta(hours=time_offset[RUN_LOCATION])).date()))]
    df_gms_td['gm_id'] = df_gms_td.AwayABV + "_" + df_gms_td.HomeABV
    df_gms_td['gm_id2'] = df_gms_td.HomeABV + "_" + df_gms_td.AwayABV
    gms_today = df_gms_td.gm_id.tolist() + df_gms_td.gm_id2.tolist()    

    dk_tm_mapping = {
                    "ATL Hawks": "ATL", "BKN Nets": "BRK", "BOS Celtics": "BOS", "CHA Hornets": "CHO", "CHI Bulls": "CHI",
                    "CLE Cavaliers": "CLE", "DAL Mavericks": "DAL", "DEN Nuggets": "DEN", "DET Pistons": "DET", 
                    "GS Warriors": "GSW", "HOU Rockets": "HOU", "IND Pacers": "IND", "LA Clippers": "LAC", 
                    "LA Lakers": "LAL", "MEM Grizzlies": "MEM", "MIA Heat": "MIA", "MIL Bucks": "MIL", "MIN Timberwolves": "MIN",
                    "NO Pelicans": "NOP", "NY Knicks": "NYK", "OKC Thunder": "OKC", "ORL Magic": "ORL", "PHI 76ers": "PHI",
                    "PHO Suns": "PHO", "POR Trail Blazers": "POR", "SA Spurs": "SAS", "SAC Kings": "SAC", "TOR Raptors": "TOR",
                    "UTA Jazz": "UTA", "WAS Wizards": "WAS", "GSW Warriors": "GSW", "LAL Lakers": "LAL", "NOP Pelicans": "NOP",
                    "NYK Knicks": "NYK", "PHX Suns": "PHO", "SAS Spurs": "SAS"
                    }

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Accept": "*/*",
        "Accept-Language": "en-US,en;q=0.9",
        "Referer": "https://sportsbook.draftkings.com/",
        "Origin": "https://sportsbook.draftkings.com"
    }
    response = requests.get(f"https://sportsbook-nash.draftkings.com/sites/US-SB/api/sportscontent/controldata/league/leagueSubcategory/v1/markets?isBatchable=false&templateVars=42648%2C4511&eventsQuery=%24filter%3DleagueId%20eq%20%2742648%27%20AND%20clientMetadata%2FSubcategories%2Fany%28s%3A%20s%2FId%20eq%20%274511%27%29&marketsQuery=%24filter%3DclientMetadata%2FsubCategoryId%20eq%20%274511%27%20AND%20tags%2Fall%28t%3A%20t%20ne%20%27SportcastBetBuilder%27%29&include=Events&entity=events", headers=headers)
    if response.status_code != 200:
        raise Exception('Bad Request')

    ids = []
    rows = []
    for i in range(len(response.json()['selections'])):
        if 'HC' in response.json()['selections'][i]['id'] or 'OU' in response.json()['selections'][i]['id']:
            ids.append(response.json()['selections'][i])
    for i in range(0, len(ids) - 1, 4):
        team1 = ids[i]['label']
        spread1 = ids[i]['points']
        team2 = ids[i+1]['label']
        spread2 = ids[i+1]['points']
        total = ids[i+2]['points']
        rows.append({"Team": team1, "Opp": team2, "Spread": spread1, "Total": total})
        rows.append({"Team": team2, "Opp": team1, "Spread": spread2, "Total": total})
    df_tm_bets = pd.DataFrame(rows)
    
    for key, value in dk_tm_mapping.items():
        df_tm_bets['Team'] = np.where(df_tm_bets.Team == key, value, df_tm_bets.Team)
        df_tm_bets['Opp'] = np.where(df_tm_bets.Opp == key, value, df_tm_bets.Opp)

    df_tm_bets['gm_id'] = df_tm_bets.Team + "_" + df_tm_bets.Opp
    df_tm_bets = df_tm_bets[(df_tm_bets.gm_id.isin(gms_today))].drop(['Opp', 'gm_id'], axis=1)
    
    return df_tm_bets

def get_sportsbook():
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Accept": "*/*",
        "Accept-Language": "en-US,en;q=0.9",
        "Referer": "https://sportsbook.draftkings.com/",
        "Origin": "https://sportsbook.draftkings.com"
    }

    dk_cats = {"PTS": 12488, "AST": 12495, "REB": 12492, "STL": 13508, "BLK": 13780, "STL_BLK": 13781, "TPM": 12497, 
               "PA": 9973, "PR": 9976, "RA": 9974, "PRA": 5001}
    df_lines = pd.DataFrame()
    for key, value in dk_cats.items():
        response = requests.get(f"https://sportsbook-nash.draftkings.com/sites/US-SB/api/sportscontent/controldata/league/leagueSubcategory/v1/markets?isBatchable=false&templateVars=42648%2C{value}&eventsQuery=%24filter%3DleagueId%20eq%20%2742648%27%20AND%20clientMetadata%2FSubcategories%2Fany%28s%3A%20s%2FId%20eq%20%27{value}%27%29&marketsQuery=%24filter%3DclientMetadata%2FsubCategoryId%20eq%20%27{value}%27%20AND%20tags%2Fall%28t%3A%20t%20ne%20%27SportcastBetBuilder%27%29&include=Events&entity=events", headers=headers)
        if response.status_code != 200:
            raise Exception('Bad Request')

        plyr_names = []
        pnt_lines = []
        for i in response.json()['selections']:
            plyr_names.append(i['participants'][0]['name'])
            pnt_lines.append(i['points'])
        df_dk = pd.DataFrame({"Player": plyr_names, f"{key}_line": pnt_lines}).drop_duplicates().reset_index(drop=True)

        if df_lines.empty:
            df_lines = df_dk
        else:
            df_lines = pd.merge(df_lines, df_dk, on="Player", how="outer")

    df_lines = pd.merge(pd.read_csv(f"../tables/{YEAR}/plyr_pos_xref.csv"), df_lines, on='Player', how='right')
    df_lines = pd.merge(df_lines, get_game_odds(), on='Team')
    df_lines.insert(0, 'Date', pd.to_datetime(str((datetime.now() + timedelta(hours=time_offset[RUN_LOCATION])).date())))

    partition_save_df(df_lines, f"../tables/{YEAR}/parlay_lines.csv") 
    display(df_lines)
get_sportsbook()
# Out:
# ../tables/2025/parlay_lines.csv saved!
#           Date Team             Player Pos  PTS_line  AST_line  REB_line  \
# 0   2026-01-10  IND      Aaron Nesmith  SF      16.5       NaN       4.5
# 1   2026-01-10  IND    Andrew Nembhard  PG      17.5       7.5       2.5
# 2   2026-01-10  MIA     Andrew Wiggins  SF      14.5       2.5       4.5
# 3   2026-01-10  BOS    Anfernee Simons  SG      13.5       2.5       NaN
# 4   2026-01-10  DET     Ausar Thompson  SF      12.5       2.5       5.5
# 5   2026-01-10  MIA        Bam Adebayo   C      16.5       2.5       9.5
# 6   2026-01-10  IND       Ben Sheppard  SG       6.5       NaN       NaN
# 7   2026-01-10  CHO     Brandon Miller  SF      20.5       3.5       4.5
# 8   2026-01-10  UTA   Brice Sensabaugh  SF      16.5       2.5       3.5
# 9   2026-01-10  LAC        Brook Lopez   C       5.5       NaN       3.5
# 10  2026-01-10  DET    Cade Cunningham  PG      27.5       9.5       5.5
# 11  2026-01-10  CHI         Coby White  SG      16.5       4.5       3.5
# 12  2026-01-10  UTA      Cody Williams  SG       6.5       NaN       2.5
# 13  2026-01-10  CHO      Collin Sexton  SG      13.5       3.5       1.5
# 14  2026-01-10  DAL       Cooper Flagg  SF      23.5       5.5       7.5
# 15  2026-01-10  DAL     Daniel Gafford   C      11.5       NaN       8.5
# 16  2026-01-10  MIA    Davion Mitchell  PG       7.5       6.5       2.5
# 17  2026-01-10  SAS       De'Aaron Fox  PG      19.5       5.5       3.5
# 18  2026-01-10  BOS      Derrick White  SG      17.5       5.5       4.5
# 19  2026-01-10  DET    Duncan Robinson  SF      11.5       1.5       2.5
# 20  2026-01-10  SAS       Dylan Harper  SG       8.5       3.5       2.5
# 21  2026-01-10  SAS    Harrison Barnes  PF       9.5       1.5       3.5
# 22  2026-01-10  CHI        Isaac Okoro  SG       7.5       NaN       3.5
# 23  2026-01-10  UTA     Isaiah Collier  PG       9.5       6.5       2.5
# 24  2026-01-10  DET     Isaiah Stewart   C      13.5       1.5       6.5
# 25  2026-01-10  LAC        Ivica Zubac   C      12.5       NaN      10.5
# 26  2026-01-10  DET         Jaden Ivey  SG      12.5       3.5       3.5
# 27  2026-01-10  MIA   Jaime Jaquez Jr.  SF      11.5       3.5       3.5
# 28  2026-01-10  CHI        Jalen Smith   C      10.5       NaN       7.5
# 29  2026-01-10  LAC       James Harden  PG      23.5       7.5       4.5
# 30  2026-01-10  IND           Jay Huff   C       9.5       NaN       4.5
# 31  2026-01-10  BOS       Jaylen Brown  SF      28.5       5.5       6.5
# 32  2026-01-10  LAC       John Collins  PF      13.5       NaN       5.5
# 33  2026-01-10  IND      Johnny Furphy  SG       6.5       NaN       4.5
# 34  2026-01-10  SAS  Julian Champagnie  SF      11.5       1.5       5.5
# 35  2026-01-10  LAC      Kawhi Leonard  SF      25.5       3.5       5.5
# 36  2026-01-10  MIA        Kel'el Ware   C      10.5       NaN       9.5
# 37  2026-01-10  SAS     Keldon Johnson  SF      12.5       NaN       5.5
# 38  2026-01-10  UTA     Keyonte George  PG      27.5       6.5       4.5
# 39  2026-01-10  DAL      Klay Thompson  SF      14.5       NaN       3.5
# 40  2026-01-10  CHO       Kon Knueppel  SF      19.5       3.5       4.5
# 41  2026-01-10  LAC          Kris Dunn  PG       7.5       3.5       2.5
# 42  2026-01-10  UTA    Kyle Filipowski   C      13.5       NaN       8.5
# 43  2026-01-10  CHO        LaMelo Ball  PG      19.5       7.5       4.5
# 44  2026-01-10  BOS         Luka Garza   C       8.5       NaN       4.5
# 45  2026-01-10  SAS        Luke Kornet   C       6.5       1.5       5.5
# 46  2026-01-10  CHI      Matas Buzelis  PF      17.5       1.5       6.5
# 47  2026-01-10  DAL       Max Christie  SG      15.5       2.5       4.5
# 48  2026-01-10  CHO      Miles Bridges  PF      18.5       3.5       6.5
# 49  2026-01-10  CHO     Moussa Diabate   C       NaN       NaN       7.5
# 50  2026-01-10  DAL      Naji Marshall  SF      16.5       3.5       5.5
# 51  2026-01-10  BOS      Neemias Queta   C       9.5       NaN       7.5
# 52  2026-01-10  LAC      Nicolas Batum  PF       5.5       NaN       NaN
# 53  2026-01-10  CHI     Nikola Vucevic   C      18.5       3.5      10.5
# 54  2026-01-10  MIA      Norman Powell  SG      21.5       2.5       3.5
# 55  2026-01-10  IND      Pascal Siakam  PF      25.5       3.5       6.5
# 56  2026-01-10  DET          Paul Reed   C      10.5       2.5       8.5
# 57  2026-01-10  BOS   Payton Pritchard  PG      16.5       4.5       4.5
# 58  2026-01-10  CHO   Ryan Kalkbrenner   C       6.5       NaN       5.5
# 59  2026-01-10  BOS         Sam Hauser  PF       8.5       NaN       3.5
# 60  2026-01-10  SAS     Stephon Castle  PG      17.5       6.5       4.5
# 61  2026-01-10  UTA     Svi Mykhailiuk  SF       NaN       NaN       NaN
# 62  2026-01-10  IND     T.J. McConnell  PG      10.5       5.5       NaN
# 63  2026-01-10  UTA   Taylor Hendricks  PF       6.5       NaN       3.5
# 64  2026-01-10  CHI          Tre Jones  PG      10.5       6.5       3.5
# 65  2026-01-10  MIA        Tyler Herro  SG      21.5       3.5       5.5
# 66  2026-01-10  SAS  Victor Wembanyama   C      20.5       2.5       9.5
#
#     STL_line  BLK_line  STL_BLK_line  TPM_line  PA_line  PR_line  RA_line  \
# 0        NaN       NaN           NaN       2.5      NaN     22.5      NaN
# 1        NaN       NaN           NaN       1.5     25.5     20.5     10.5
# 2        1.5       NaN           NaN       1.5     16.5     19.5      7.5
# 3        NaN       NaN           NaN       2.5     15.5     15.5      4.5
# 4        1.5       NaN           NaN       NaN     15.5     18.5      8.5
# 5        NaN       NaN           NaN       NaN     20.5     26.5     12.5
# 6        NaN       NaN           NaN       1.5      NaN      NaN      NaN
# 7        NaN       NaN           NaN       3.5     23.5     24.5      7.5
# 8        NaN       NaN           NaN       2.5     18.5     20.5      6.5
# 9        NaN       NaN           NaN       1.5      NaN      9.5      NaN
# 10       NaN       NaN           NaN       1.5     37.5     33.5     15.5
# 11       NaN       NaN           NaN       2.5     21.5     20.5      7.5
# 12       NaN       NaN           NaN       NaN      NaN      8.5      NaN
# 13       NaN       NaN           NaN       1.5     17.5     15.5      6.5
# 14       NaN       NaN           NaN       1.5     29.5     31.5     12.5
# 15       NaN       NaN           NaN       NaN      NaN     19.5      NaN
# 16       1.5       NaN           NaN       0.5     14.5      9.5      9.5
# 17       1.5       NaN           NaN       2.5     25.5     22.5      9.5
# 18       1.5       1.5           2.5       3.5     23.5     22.5      9.5
# 19       NaN       NaN           NaN       2.5     13.5     14.5      NaN
# 20       NaN       NaN           NaN       NaN     12.5     12.5      6.5
# 21       NaN       NaN           NaN       1.5     10.5     12.5      4.5
# 22       NaN       NaN           NaN       0.5      NaN     11.5      NaN
# 23       NaN       NaN           NaN       NaN     16.5     12.5      9.5
# 24       NaN       NaN           NaN       1.5     14.5     20.5      8.5
# 25       NaN       NaN           NaN       NaN      NaN     23.5      NaN
# 26       NaN       NaN           NaN       1.5     16.5     15.5      6.5
# 27       NaN       NaN           NaN       NaN     15.5     16.5      7.5
# 28       NaN       NaN           NaN       1.5      NaN     17.5      NaN
# 29       NaN       NaN           NaN       2.5     31.5     28.5     11.5
# 30       NaN       NaN           NaN       1.5      NaN     14.5      NaN
# 31       NaN       NaN           1.5       1.5     33.5     35.5     11.5
# 32       NaN       NaN           NaN       1.5      NaN     19.5      NaN
# 33       NaN       NaN           NaN       0.5      NaN      NaN      NaN
# 34       NaN       NaN           NaN       2.5     13.5     18.5      7.5
# 35       NaN       NaN           NaN       2.5     29.5     31.5      9.5
# 36       NaN       NaN           NaN       NaN      NaN     19.5      NaN
# 37       NaN       NaN           NaN       1.5      NaN     18.5      NaN
# 38       1.5       NaN           NaN       2.5     34.5     31.5     10.5
# 39       NaN       NaN           NaN       3.5      NaN     17.5      NaN
# 40       NaN       NaN           NaN       3.5     22.5     24.5      8.5
# 41       NaN       NaN           NaN       1.5     11.5     10.5      6.5
# 42       NaN       NaN           NaN       1.5      NaN     21.5      NaN
# 43       1.5       NaN           NaN       3.5     27.5     23.5     12.5
# 44       NaN       NaN           NaN       NaN      NaN      NaN      NaN
# 45       NaN       NaN           NaN       NaN      8.5     12.5      7.5
# 46       NaN       1.5           NaN       1.5     19.5     23.5      8.5
# 47       NaN       NaN           NaN       2.5     18.5     19.5      6.5
# 48       NaN       NaN           NaN       2.5     22.5     25.5     10.5
# 49       NaN       NaN           NaN       NaN      NaN      NaN      NaN
# 50       NaN       NaN           NaN       1.5     20.5     22.5      9.5
# 51       NaN       NaN           NaN       NaN      NaN     17.5      NaN
# 52       NaN       NaN           NaN       1.5      NaN      NaN      NaN
# 53       NaN       NaN           NaN       1.5     22.5     28.5     14.5
# 54       NaN       NaN           NaN       2.5     23.5     24.5      5.5
# 55       1.5       NaN           NaN       1.5     30.5     33.5     11.5
# 56       NaN       NaN           NaN       NaN     13.5     19.5     11.5
# 57       NaN       NaN           NaN       2.5     21.5     20.5      9.5
# 58       NaN       1.5           NaN       NaN      NaN     12.5      NaN
# 59       NaN       NaN           NaN       2.5      NaN      NaN      NaN
# 60       1.5       NaN           NaN       1.5     24.5     22.5     11.5
# 61       NaN       NaN           NaN       1.5      NaN      NaN      NaN
# 62       NaN       NaN           NaN       NaN     15.5      NaN      NaN
# 63       NaN       NaN           NaN       NaN      NaN      9.5      NaN
# 64       0.5       NaN           NaN       NaN     17.5     14.5      9.5
# 65       NaN       NaN           NaN       2.5     25.5     26.5      8.5
# 66       NaN       2.5           2.5       1.5     23.5     30.5     12.5
#
#     PRA_line  Spread  Total
# 0        NaN     6.5  235.5
# 1       28.5     6.5  235.5
# 2       21.5    -6.5  235.5
# 3       18.5     1.5  230.5
# 4       21.5    -3.5  214.5
# 5       29.5    -6.5  235.5
# 6        NaN     6.5  235.5
# 7       28.5    -5.5  238.5
# 8       22.5     5.5  238.5
# 9        NaN     3.5  214.5
# 10      43.5    -3.5  214.5
# 11      24.5    -2.5  233.5
# 12       NaN     5.5  238.5
# 13      19.5    -5.5  238.5
# 14      36.5     2.5  233.5
# 15      20.5     2.5  233.5
# 16      16.5    -6.5  235.5
# 17      28.5    -1.5  230.5
# 18      27.5     1.5  230.5
# 19      16.5    -3.5  214.5
# 20      15.5    -1.5  230.5
# 21      14.5    -1.5  230.5
# 22      12.5    -2.5  233.5
# 23      19.5     5.5  238.5
# 24      21.5    -3.5  214.5
# 25       NaN     3.5  214.5
# 26      19.5    -3.5  214.5
# 27      19.5    -6.5  235.5
# 28       NaN    -2.5  233.5
# 29      35.5     3.5  214.5
# 30       NaN     6.5  235.5
# 31      40.5     1.5  230.5
# 32       NaN     3.5  214.5
# 33       NaN     6.5  235.5
# 34      19.5    -1.5  230.5
# 35      35.5     3.5  214.5
# 36       NaN    -6.5  235.5
# 37       NaN    -1.5  230.5
# 38      38.5     5.5  238.5
# 39      19.5     2.5  233.5
# 40      28.5    -5.5  238.5
# 41      13.5     3.5  214.5
# 42       NaN     5.5  238.5
# 43      31.5    -5.5  238.5
# 44       NaN     1.5  230.5
# 45      14.5    -1.5  230.5
# 46      25.5    -2.5  233.5
# 47      22.5     2.5  233.5
# 48      29.5    -5.5  238.5
# 49       NaN    -5.5  238.5
# 50      26.5     2.5  233.5
# 51       NaN     1.5  230.5
# 52       NaN     3.5  214.5
# 53      33.5    -2.5  233.5
# 54      27.5    -6.5  235.5
# 55      37.5     6.5  235.5
# 56      22.5    -3.5  214.5
# 57      26.5     1.5  230.5
# 58       NaN    -5.5  238.5
# 59       NaN     1.5  230.5
# 60      29.5    -1.5  230.5
# 61       NaN     5.5  238.5
# 62       NaN     6.5  235.5
# 63       NaN     5.5  238.5
# 64      20.5    -2.5  233.5
# 65      30.5    -6.5  235.5
# 66      33.5    -1.5  230.5

# %% [markdown]
# # Get Starting Lineups

# %%
def read_page(date=""):
    if date != "":
        date = f"?date={date}"
    url = f"https://fantasydata.com/nba/starting-lineups{date}"
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Accept-Language": "en-US,en;q=0.9"
    }

    resp = requests.get(url, headers=headers)
    resp.raise_for_status()

    html = resp.text
    
    return html

# %%
def extract_starters(team_div):
    """
    Extract starters from a team div (away/home),
    stopping at the Injuries section.
    """
    starters = []
    collecting = False

    for row in team_div.select(":scope > div.text-nowrap"):
        strong = row.find("strong")

        if strong:
            label = strong.get_text(strip=True)
            if label == "Starters":
                collecting = True
                continue
            if label == "Injuries":
                break

        if collecting:
            a = row.find("a")
            if not a:
                continue

            name = a.get_text(strip=True)
            href = a.get("href")

            # player ID is last number in URL
            player_id = href.rstrip("/").split("/")[-1]

            # position is plain text after name
            text = row.get_text(" ", strip=True)
            position = text.replace(name, "").strip()

            starters.append({
                "player_name": name,
                "player_id": player_id,
                "position": position
            })

    return starters

# %%
def parse_lineups(html):
    time.sleep(6)
    soup = BeautifulSoup(html, "lxml")
    games_data = []

    for game in soup.select("div.game"):
        # --- Game info ---
        info_div = game.select_one("div.header div.info > div")
        lines = list(info_div.stripped_strings)

        matchup = lines[0]
        game_time = lines[1]

        away_team, home_team = [t.strip() for t in matchup.split("@")]

        # --- Lineups ---
        away_div = game.select_one("div.away")
        home_div = game.select_one("div.home")

        away_starters = extract_starters(away_div)
        home_starters = extract_starters(home_div)

        for p in away_starters:
            games_data.append({
                "team_side": "away",
                "team": away_team,
                "opponent": home_team,
                "game_time": game_time,
                **p
            })

        for p in home_starters:
            games_data.append({
                "team_side": "home",
                "team": home_team,
                "opponent": away_team,
                "game_time": game_time,
                **p
            })

    return pd.DataFrame(games_data)

# %% [markdown]
# # Other functions

# %%
def email(error):
    
    # Email details
    sender_email = "rodolfoe7157@gmail.com"
    receiver_email = "rodolfoe7157@gmail.com"
    password = "cqgu bfey cnyx sfue"  # See note below

    subject = "NBA Starting Lineups error"
    body = f"ERROR: {error}"

    # Create message
    msg = MIMEMultipart()
    msg['From'] = sender_email
    msg['To'] = receiver_email
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))

    # Connect to Gmail SMTP server and send
    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as server:
        server.login(sender_email, password)
        server.send_message(msg)

    print("Email sent successfully!")

# %%
def remove_accents(text):
    if not isinstance(text, str):
        return text
    # Normalize to NFKD (decomposes characters)
    text = unicodedata.normalize('NFKD', text)
    # Encode to ASCII bytes, ignore non-ASCII characters, then decode back to str
    return text.encode('ascii', 'ignore').decode('ascii')

# %% [markdown]
# # Main

# %%
now = str(datetime.now().date() + timedelta(days=-1))
df_teams = pd.read_csv(f"../src/team_info_xref.csv")
df_teams['short_name'] = df_teams.Team.str.split(" ").str[-1]
df_teams['short_name'] = np.where(df_teams.ABV == 'POR', 'Trail Blazers', df_teams.short_name)
df = parse_lineups(read_page(now))
if df.shape[0] > 0:
    df = df.merge(df_teams, left_on=['team'], right_on=['short_name'])
    df = df[['ABV', 'player_name', 'position']].rename(columns={"ABV": "Team", "player_name": "Player", "position": "Pos"})
    df.insert(0, 'Date', pd.to_datetime(now))
    df['Player'] = df['Player'].apply(remove_accents)
    display(df)
    partition_save_df(df, f"../tables/{YEAR}/daily_lineups.csv")
else:
    email(f'Empty lineup for {now}')
# Out:
#          Date Team                    Player Pos
# 0  2026-01-09  NOP            Jeremiah Fears  PG
# 1  2026-01-09  NOP            Bryce McGowens  SG
# 2  2026-01-09  NOP           Trey Murphy III  SF
# 3  2026-01-09  NOP           Zion Williamson  PF
# 4  2026-01-09  NOP               Derik Queen   C
# 5  2026-01-09  WAS               Tre Johnson  SG
# 6  2026-01-09  WAS           Bilal Coulibaly  SG
# 7  2026-01-09  WAS           Khris Middleton  SF
# 8  2026-01-09  WAS            Kyshawn George  SF
# 9  2026-01-09  WAS            Alexandre Sarr  PF
# 10 2026-01-09  TOR         Immanuel Quickley  PG
# 11 2026-01-09  TOR                RJ Barrett  SG
# 12 2026-01-09  TOR            Ja'Kobe Walter  SG
# 13 2026-01-09  TOR     Sandro Mamukelashvili  PF
# 14 2026-01-09  TOR      Collin Murray-Boyles  PF
# 15 2026-01-09  BOS          Payton Pritchard  PG
# 16 2026-01-09  BOS              Jaylen Brown  SG
# 17 2026-01-09  BOS             Derrick White  SG
# 18 2026-01-09  BOS                Sam Hauser  SF
# 19 2026-01-09  BOS             Neemias Queta   C
# 20 2026-01-09  PHI              Tyrese Maxey  PG
# 21 2026-01-09  PHI              VJ Edgecombe  SG
# 22 2026-01-09  PHI               Paul George  SF
# 23 2026-01-09  PHI           Dominick Barlow  PF
# 24 2026-01-09  PHI               Joel Embiid   C
# 25 2026-01-09  ORL             Anthony Black  PG
# 26 2026-01-09  ORL              Desmond Bane  SG
# 27 2026-01-09  ORL                Noah Penda  SF
# 28 2026-01-09  ORL            Paolo Banchero  PF
# 29 2026-01-09  ORL        Wendell Carter Jr.   C
# 30 2026-01-09  LAC                 Kris Dunn  PG
# 31 2026-01-09  LAC              James Harden  SG
# 32 2026-01-09  LAC             Kawhi Leonard  SF
# 33 2026-01-09  LAC              John Collins  PF
# 34 2026-01-09  LAC               Ivica Zubac   C
# 35 2026-01-09  BRK                Egor Demin  PG
# 36 2026-01-09  BRK              Terance Mann  PG
# 37 2026-01-09  BRK        Michael Porter Jr.  SF
# 38 2026-01-09  BRK              Noah Clowney  PF
# 39 2026-01-09  BRK           Nicolas Claxton   C
# 40 2026-01-09  OKC             Ajay Mitchell  PG
# 41 2026-01-09  OKC             Aaron Wiggins  SG
# 42 2026-01-09  OKC            Jalen Williams  SF
# 43 2026-01-09  OKC             Luguentz Dort  SF
# 44 2026-01-09  OKC           Branden Carlson   C
# 45 2026-01-09  MEM             Cedric Coward  SG
# 46 2026-01-09  MEM               Cam Spencer  SG
# 47 2026-01-09  MEM              Jaylen Wells  SF
# 48 2026-01-09  MEM         Jaren Jackson Jr.  PF
# 49 2026-01-09  MEM              Jock Landale   C
# 50 2026-01-09  NYK             Miles McBride  PG
# 51 2026-01-09  NYK             Jalen Brunson  PG
# 52 2026-01-09  NYK                OG Anunoby  SF
# 53 2026-01-09  NYK             Mikal Bridges  SF
# 54 2026-01-09  NYK        Karl-Anthony Towns  PF
# 55 2026-01-09  PHO          Collin Gillespie  PG
# 56 2026-01-09  PHO              Devin Booker  SG
# 57 2026-01-09  PHO             Dillon Brooks  SF
# 58 2026-01-09  PHO             Royce O'Neale  PF
# 59 2026-01-09  PHO             Mark Williams   C
# 60 2026-01-09  ATL             Dyson Daniels  PG
# 61 2026-01-09  ATL                Vit Krejci  SG
# 62 2026-01-09  ATL  Nickeil Alexander-Walker  SG
# 63 2026-01-09  ATL             Jalen Johnson  PF
# 64 2026-01-09  ATL            Onyeka Okongwu   C
# 65 2026-01-09  DEN           Christian Braun  SG
# 66 2026-01-09  DEN             Jalen Pickett  SG
# 67 2026-01-09  DEN             Peyton Watson  SF
# 68 2026-01-09  DEN              Hunter Tyson  SF
# 69 2026-01-09  DEN           DaRon Holmes II  PF
# 70 2026-01-09  SAC         Russell Westbrook  PG
# 71 2026-01-09  SAC                Keon Ellis  SG
# 72 2026-01-09  SAC               Zach LaVine  SG
# 73 2026-01-09  SAC             DeMar DeRozan  SF
# 74 2026-01-09  SAC            Maxime Raynaud   C
# 75 2026-01-09  GSW             Stephen Curry  PG
# 76 2026-01-09  GSW               Moses Moody  SG
# 77 2026-01-09  GSW          Jimmy Butler III  SF
# 78 2026-01-09  GSW            Draymond Green  PF
# 79 2026-01-09  GSW              Quinten Post   C
# 80 2026-01-09  HOU             Amen Thompson  SG
# 81 2026-01-09  HOU                Tari Eason  SF
# 82 2026-01-09  HOU              Kevin Durant  PF
# 83 2026-01-09  HOU          Jabari Smith Jr.  PF
# 84 2026-01-09  HOU              Steven Adams   C
# 85 2026-01-09  POR            Shaedon Sharpe  SG
# 86 2026-01-09  POR               Deni Avdija  SF
# 87 2026-01-09  POR              Sidy Cissoko  SF
# 88 2026-01-09  POR            Toumani Camara  SF
# 89 2026-01-09  POR           Donovan Clingan   C
# 90 2026-01-09  MIL          Kevin Porter Jr.  PG
# 91 2026-01-09  MIL              Ryan Rollins  SG
# 92 2026-01-09  MIL                  AJ Green  SG
# 93 2026-01-09  MIL     Giannis Antetokounmpo  PF
# 94 2026-01-09  MIL              Myles Turner   C
# 95 2026-01-09  LAL              Marcus Smart  PG
# 96 2026-01-09  LAL               Luka Doncic  PG
# 97 2026-01-09  LAL              LeBron James  SF
# 98 2026-01-09  LAL              Jake LaRavia  PF
# 99 2026-01-09  LAL             Deandre Ayton   C
# ../tables/2025/daily_lineups.csv saved!

# %%
now = str(datetime.now().date())
df_teams = pd.read_csv(f"../src/team_info_xref.csv")
df_teams['short_name'] = df_teams.Team.str.split(" ").str[-1]
df_teams['short_name'] = np.where(df_teams.ABV == 'POR', 'Trail Blazers', df_teams.short_name)
df = parse_lineups(read_page())
if df.shape[0] > 0:
    df = df.merge(df_teams, left_on=['team'], right_on=['short_name'])
    df = df[['ABV', 'player_name', 'position']].rename(columns={"ABV": "Team", "player_name": "Player", "position": "Pos"})
    df.insert(0, 'Date', pd.to_datetime(now))
    df['Player'] = df['Player'].apply(remove_accents)
    display(df)
    partition_save_df(df, f"../tables/{YEAR}/daily_lineups.csv")
else:
    email(f'Empty lineup for {now}')
# Out:
#          Date Team             Player Pos
# 0  2026-01-10  MIN   Donte DiVincenzo  SG
# 1  2026-01-10  MIN    Anthony Edwards  SG
# 2  2026-01-10  MIN    Jaden McDaniels  PF
# 3  2026-01-10  MIN      Julius Randle  PF
# 4  2026-01-10  MIN        Rudy Gobert   C
# 5  2026-01-10  CLE     Darius Garland  PG
# 6  2026-01-10  CLE        Sam Merrill  SG
# 7  2026-01-10  CLE   Donovan Mitchell  SG
# 8  2026-01-10  CLE        Evan Mobley  PF
# 9  2026-01-10  CLE      Jarrett Allen   C
# 10 2026-01-10  MIA    Davion Mitchell  PG
# 11 2026-01-10  MIA      Norman Powell  SG
# 12 2026-01-10  MIA        Tyler Herro  SG
# 13 2026-01-10  MIA     Andrew Wiggins  SF
# 14 2026-01-10  MIA        Bam Adebayo   C
# 15 2026-01-10  IND    Andrew Nembhard  PG
# 16 2026-01-10  IND      Johnny Furphy  SF
# 17 2026-01-10  IND      Pascal Siakam  PF
# 18 2026-01-10  IND      Aaron Nesmith  PF
# 19 2026-01-10  IND           Jay Huff   C
# 20 2026-01-10  LAC          Kris Dunn  PG
# 21 2026-01-10  LAC       James Harden  SG
# 22 2026-01-10  LAC      Kawhi Leonard  SF
# 23 2026-01-10  LAC       John Collins  PF
# 24 2026-01-10  LAC        Ivica Zubac   C
# 25 2026-01-10  DET    Cade Cunningham  PG
# 26 2026-01-10  DET    Duncan Robinson  SG
# 27 2026-01-10  DET     Ausar Thompson  SG
# 28 2026-01-10  DET          Paul Reed  PF
# 29 2026-01-10  DET     Isaiah Stewart  PF
# 30 2026-01-10  DAL      Ryan Nembhard  PG
# 31 2026-01-10  DAL       Max Christie  SG
# 32 2026-01-10  DAL      Naji Marshall  SF
# 33 2026-01-10  DAL       Cooper Flagg  PF
# 34 2026-01-10  DAL     Daniel Gafford   C
# 35 2026-01-10  CHI          Tre Jones  PG
# 36 2026-01-10  CHI         Coby White  SG
# 37 2026-01-10  CHI      Matas Buzelis  SF
# 38 2026-01-10  CHI        Isaac Okoro  SF
# 39 2026-01-10  CHI     Nikola Vucevic   C
# 40 2026-01-10  SAS       De'Aaron Fox  PG
# 41 2026-01-10  SAS     Stephon Castle  SG
# 42 2026-01-10  SAS  Julian Champagnie  SF
# 43 2026-01-10  SAS    Harrison Barnes  SF
# 44 2026-01-10  SAS  Victor Wembanyama  PF
# 45 2026-01-10  BOS   Payton Pritchard  PG
# 46 2026-01-10  BOS       Jaylen Brown  SG
# 47 2026-01-10  BOS      Derrick White  SG
# 48 2026-01-10  BOS         Sam Hauser  SF
# 49 2026-01-10  BOS      Neemias Queta   C
# 50 2026-01-10  CHO        LaMelo Ball  PG
# 51 2026-01-10  CHO       Kon Knueppel  SG
# 52 2026-01-10  CHO      Miles Bridges  SF
# 53 2026-01-10  CHO     Brandon Miller  SF
# 54 2026-01-10  CHO   Ryan Kalkbrenner   C
# 55 2026-01-10  UTA     Keyonte George  SG
# 56 2026-01-10  UTA     Svi Mykhailiuk  SF
# 57 2026-01-10  UTA   Brice Sensabaugh  SF
# 58 2026-01-10  UTA   Taylor Hendricks  PF
# 59 2026-01-10  UTA    Kyle Filipowski   C
# ../tables/2025/daily_lineups.csv saved!
