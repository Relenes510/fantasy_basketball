# %%
import requests
from bs4 import BeautifulSoup
from nbainjuries import injury
import duckdb
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time
import os
import unicodedata
import warnings

pd.set_option('display.max_rows', None)
warnings.filterwarnings("ignore")

cwd = os.path.abspath(os.getcwd()).replace("\\", "/")
if cwd.startswith("C:/Users/Rodolfo/"):
    RUN_LOCATION = "local"
else:
    RUN_LOCATION = "cloud"
time_offset = {"local": 3, "cloud": -5}

print("Current working dir:", cwd)
print("RUN_LOCATION =", RUN_LOCATION)
# Out:
# Current working dir: C:/Users/Rodolfo/Jupyter_files/FantasyBasketball/notebooks
# RUN_LOCATION = local

# %%
# %run ./common_utils.ipynb

# %% [markdown]
# # Get Injuries Report

# %%
def get_injuries():
    con = duckdb.connect(database=":memory:")
    df_teams = pd.read_csv("../src/team_info_xref.csv")

    df_inj = injury.get_reportdata(datetime.now() + timedelta(hours=time_offset[RUN_LOCATION]), return_df=True)
    df_inj = df_inj.rename(columns={"Game Date": "Date", "Player Name": "Player", "Current Status": "Status"})
    df_inj['Player'] = df_inj.Player.str.split(",").str[1] + " " + df_inj.Player.str.split(",").str[0]
    df_inj['Player'] = df_inj['Player'].str.strip()
    df_inj['Date'] = pd.to_datetime(df_inj['Date'])
    df_inj = remap_plyr_names(df_inj)
    df_inj = con.execute(f"""SELECT Date, ABV as Team, Player, Status, Reason FROM df_inj 
                             JOIN df_teams ON df_inj.Team = df_teams.Team
                             WHERE Date = '{str((datetime.now() + timedelta(hours=time_offset[RUN_LOCATION])).date())}' AND Status != 'Available'""").fetchdf()
    partition_save_df(df_inj, f"../tables/{YEAR}/injuries.csv")
    display(df_inj[df_inj.Status == 'Out'])
get_injuries()
# Out:
# Validated Injury-Report_2026-01-23_12_30AM.
# ../tables/2025/injuries.csv saved!
#           Date Team              Player Status  \
# 0   2026-01-23  ATL  Zaccharie Risacher    Out
# 1   2026-01-23  BOS      Amari Williams    Out
# 2   2026-01-23  BRK           Ben Saraf    Out
# 3   2026-01-23  CLE        Luke Travers    Out
# 4   2026-01-23  DET          Tolu Smith    Out
# 5   2026-01-23  IND          Obi Toppin    Out
# 6   2026-01-23  MEM   Scotty Pippen Jr.    Out
# 8   2026-01-23  NOP     Dejounte Murray    Out
# 10  2026-01-23  SAC      Isaiah Stevens    Out
# 11  2026-01-23  TOR      Ja'Kobe Walter    Out
# 12  2026-01-23  ATL  Kristaps Porzingis    Out
# 13  2026-01-23  BOS        Jayson Tatum    Out
# 14  2026-01-23  BRK        E.J. Liddell    Out
# 15  2026-01-23  CLE           Max Strus    Out
# 18  2026-01-23  MEM           Ja Morant    Out
# 19  2026-01-23  MIL      Taurean Prince    Out
# 21  2026-01-23  OKC      Jalen Williams    Out
# 22  2026-01-23  SAC     Daeqwon Plowden    Out
# 23  2026-01-23  TOR        Jakob Poeltl    Out
# 25  2026-01-23  BOS          Max Shulga    Out
# 26  2026-01-23  BRK      Chaney Johnson    Out
# 27  2026-01-23  CLE         Sam Merrill    Out
# 28  2026-01-23  DET   Wendell Moore Jr.    Out
# 30  2026-01-23  MEM      Jahmai Mashack    Out
# 31  2026-01-23  MIL    Kevin Porter Jr.    Out
# 32  2026-01-23  NOP    Hunter Dickinson    Out
# 34  2026-01-23  SAC       Keegan Murray    Out
# 37  2026-01-23  BOS         Josh Minott    Out
# 38  2026-01-23  BRK   Haywood Highsmith    Out
# 39  2026-01-23  CLE    Chris Livingston    Out
# 41  2026-01-23  IND  Bennedict Mathurin    Out
# 42  2026-01-23  MEM           Ty Jerome    Out
# 43  2026-01-23  MIL  Alex Antetokounmpo    Out
# 44  2026-01-23  NOP       Jose Alvarado    Out
# 45  2026-01-23  OKC        Nikola Topic    Out
# 46  2026-01-23  TOR      Chucky Hepburn    Out
# 48  2026-01-23  BRK       Tyson Etienne    Out
# 49  2026-01-23  CLE      Darius Garland    Out
# 52  2026-01-23  MEM           Zach Edey    Out
# 53  2026-01-23  NOP      Trey Alexander    Out
# 54  2026-01-23  OKC       Thomas Sorber    Out
# 56  2026-01-23  ATL        N'Faly Dante    Out
# 57  2026-01-23  DET       Bobi Klintman    Out
# 58  2026-01-23  IND   Tyrese Haliburton    Out
# 59  2026-01-23  MEM      Brandon Clarke    Out
# 60  2026-01-23  OKC       Ajay Mitchell    Out
# 61  2026-01-23  DET         Isaac Jones    Out
# 62  2026-01-23  MEM        Santi Aldama    Out
# 63  2026-01-23  OKC  Isaiah Hartenstein    Out
# 65  2026-01-23  OKC         Alex Caruso    Out
#
#                                                Reason
# 0          Injury/Illness - Left Knee; Bone Contusion
# 1                                  G League - Two-Way
# 2                            G League - On Assignment
# 3                                  G League - Two-Way
# 4                                  G League - Two-Way
# 5        Injury/Illness - Right Foot; Stress Fracture
# 6   Injury/Illness - Left Great Toe; Surgery Recovery
# 8            Injury/Illness - Right Achilles; Rupture
# 10                                 G League - Two-Way
# 11                Injury/Illness - Right Hip; Pointer
# 12         Injury/Illness - Left Achilles; Tendinitis
# 13            Injury/Illness - Right Achilles; Repair
# 14                                 G League - Two-Way
# 15  Injury/Illness - Left Foot; Surgery - Jones Fr...
# 18            Injury/Illness - Left Elbow; UCL Sprain
# 19                     Injury/Illness - Neck; Surgery
# 21           Injury/Illness - Right Hamstring; Strain
# 22                                 G League - Two-Way
# 23                Injury/Illness - Lower Back; Strain
# 25                                 G League - Two-Way
# 26                                 G League - Two-Way
# 27                Injury/Illness - Right Hand; Sprain
# 28                                 G League - Two-Way
# 30                                 G League - Two-Way
# 31            Injury/Illness - Oblique Muscle; Strain
# 32                                 G League - Two-Way
# 34                Injury/Illness - Left Ankle; Sprain
# 37                Injury/Illness - Left Ankle; Sprain
# 38  Injury/Illness - Right Knee; Surgery, Injury R...
# 39                                 G League - Two-Way
# 41               Injury/Illness - Right Thumb; Sprain
# 42                Injury/Illness - Right Calf; Strain
# 43                                 G League - Two-Way
# 44              Injury/Illness - Left Oblique; Strain
# 45            Injury/Illness - N/a; Surgical Recovery
# 46                                 G League - Two-Way
# 48                                 G League - Two-Way
# 49           Injury/Illness - Right Great Toe; Sprain
# 52       Injury/Illness - Left Ankle; Stress Reaction
# 53                                 G League - Two-Way
# 54      Injury/Illness - Right ACL; Surgical Recovery
# 56              Injury/Illness - Right Knee; Torn ACL
# 57                           G League - On Assignment
# 58       Injury/Illness - Right Achilles Tendon; Tear
# 59                Injury/Illness - Right Calf; Strain
# 60                 Injury/Illness - Abdominal; Strain
# 61                           G League - On Assignment
# 62              Injury/Illness - Right Knee; Soreness
# 63              Injury/Illness - Right Soleus; Strain
# 65            Injury/Illness - Right Adductor; Strain

# %% [markdown]
# # Get Betting Odds

# %%
def get_game_odds():

    df_gms = pd.read_csv(f"../tables/{YEAR}/nba_schedule.csv")
    df_gms['Date'] = pd.to_datetime(df_gms.Date)
    df_gms_td = df_gms[(df_gms.Date == str((datetime.now() + timedelta(hours=time_offset[RUN_LOCATION])).date()))]
    df_gms_td['gm_id'] = df_gms_td.AwayABV + "_" + df_gms_td.HomeABV
    df_gms_td['gm_id2'] = df_gms_td.HomeABV + "_" + df_gms_td.AwayABV
    gms_today = df_gms_td.gm_id.tolist() + df_gms_td.gm_id2.tolist()    

    dk_tm_mapping = {
                    "ATL Hawks": "ATL", "BKN Nets": "BRK", "BOS Celtics": "BOS", "CHA Hornets": "CHO", "CHI Bulls": "CHI",
                    "CLE Cavaliers": "CLE", "DAL Mavericks": "DAL", "DEN Nuggets": "DEN", "DET Pistons": "DET", 
                    "GS Warriors": "GSW", "HOU Rockets": "HOU", "IND Pacers": "IND", "LA Clippers": "LAC", 
                    "LA Lakers": "LAL", "MEM Grizzlies": "MEM", "MIA Heat": "MIA", "MIL Bucks": "MIL", "MIN Timberwolves": "MIN",
                    "NO Pelicans": "NOP", "NY Knicks": "NYK", "OKC Thunder": "OKC", "ORL Magic": "ORL", "PHI 76ers": "PHI",
                    "PHO Suns": "PHO", "POR Trail Blazers": "POR", "SA Spurs": "SAS", "SAC Kings": "SAC", "TOR Raptors": "TOR",
                    "UTA Jazz": "UTA", "WAS Wizards": "WAS", "GSW Warriors": "GSW", "LAL Lakers": "LAL", "NOP Pelicans": "NOP",
                    "NYK Knicks": "NYK", "PHX Suns": "PHO", "SAS Spurs": "SAS"
                    }

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Accept": "*/*",
        "Accept-Language": "en-US,en;q=0.9",
        "Referer": "https://sportsbook.draftkings.com/",
        "Origin": "https://sportsbook.draftkings.com"
    }
    response = requests.get(f"https://sportsbook-nash.draftkings.com/sites/US-SB/api/sportscontent/controldata/league/leagueSubcategory/v1/markets?isBatchable=false&templateVars=42648%2C4511&eventsQuery=%24filter%3DleagueId%20eq%20%2742648%27%20AND%20clientMetadata%2FSubcategories%2Fany%28s%3A%20s%2FId%20eq%20%274511%27%29&marketsQuery=%24filter%3DclientMetadata%2FsubCategoryId%20eq%20%274511%27%20AND%20tags%2Fall%28t%3A%20t%20ne%20%27SportcastBetBuilder%27%29&include=Events&entity=events", headers=headers)
    if response.status_code != 200:
        raise Exception('Bad Request')

    ids = []
    rows = []
    for i in range(len(response.json()['selections'])):
        if 'HC' in response.json()['selections'][i]['id'] or 'OU' in response.json()['selections'][i]['id']:
            ids.append(response.json()['selections'][i])
    for i in range(0, len(ids) - 1, 4):
        team1 = ids[i]['label']
        spread1 = ids[i]['points']
        team2 = ids[i+1]['label']
        spread2 = ids[i+1]['points']
        total = ids[i+2]['points']
        rows.append({"Team": team1, "Opp": team2, "Spread": spread1, "Total": total})
        rows.append({"Team": team2, "Opp": team1, "Spread": spread2, "Total": total})
    df_tm_bets = pd.DataFrame(rows)
    
    for key, value in dk_tm_mapping.items():
        df_tm_bets['Team'] = np.where(df_tm_bets.Team == key, value, df_tm_bets.Team)
        df_tm_bets['Opp'] = np.where(df_tm_bets.Opp == key, value, df_tm_bets.Opp)

    df_tm_bets['gm_id'] = df_tm_bets.Team + "_" + df_tm_bets.Opp
    df_tm_bets = df_tm_bets[(df_tm_bets.gm_id.isin(gms_today))].drop(['Opp', 'gm_id'], axis=1)
    
    return df_tm_bets

def get_sportsbook():
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Accept": "*/*",
        "Accept-Language": "en-US,en;q=0.9",
        "Referer": "https://sportsbook.draftkings.com/",
        "Origin": "https://sportsbook.draftkings.com"
    }

    dk_cats = {"PTS": 12488, "AST": 12495, "REB": 12492, "STL": 13508, "BLK": 13780, "STL_BLK": 13781, "TPM": 12497, 
               "PA": 9973, "PR": 9976, "RA": 9974, "PRA": 5001}
    df_lines = pd.DataFrame()
    for key, value in dk_cats.items():
        response = requests.get(f"https://sportsbook-nash.draftkings.com/sites/US-SB/api/sportscontent/controldata/league/leagueSubcategory/v1/markets?isBatchable=false&templateVars=42648%2C{value}&eventsQuery=%24filter%3DleagueId%20eq%20%2742648%27%20AND%20clientMetadata%2FSubcategories%2Fany%28s%3A%20s%2FId%20eq%20%27{value}%27%29&marketsQuery=%24filter%3DclientMetadata%2FsubCategoryId%20eq%20%27{value}%27%20AND%20tags%2Fall%28t%3A%20t%20ne%20%27SportcastBetBuilder%27%29&include=Events&entity=events", headers=headers)
        if response.status_code != 200:
            raise Exception('Bad Request')

        plyr_names = []
        pnt_lines = []
        for i in response.json()['selections']:
            plyr_names.append(i['participants'][0]['name'])
            pnt_lines.append(i['points'])
        df_dk = pd.DataFrame({"Player": plyr_names, f"{key}_line": pnt_lines}).drop_duplicates().reset_index(drop=True)

        if df_lines.empty:
            df_lines = df_dk
        else:
            df_lines = pd.merge(df_lines, df_dk, on="Player", how="outer")

    df_lines = pd.merge(pd.read_csv(f"../tables/{YEAR}/plyr_pos_xref.csv"), df_lines, on='Player', how='right')
    df_lines = pd.merge(df_lines, get_game_odds(), on='Team')
    df_lines.insert(0, 'Date', pd.to_datetime(str((datetime.now() + timedelta(hours=time_offset[RUN_LOCATION])).date())))

    partition_save_df(df_lines, f"../tables/{YEAR}/parlay_lines.csv") 
    display(df_lines)
get_sportsbook()
# Out:
# ../tables/2025/parlay_lines.csv saved!
#           Date Team                 Player Pos  PTS_line  AST_line  REB_line  \
# 0   2026-01-18  DEN           Aaron Gordon  PF      18.5       3.5       6.5
# 1   2026-01-18  HOU         Alperen Sengun   C      22.5       6.5       8.5
# 2   2026-01-18  HOU          Amen Thompson  PG      19.5       5.5       7.5
# 3   2026-01-18  CHI            Ayo Dosunmu  SG      12.5       3.5       2.5
# 4   2026-01-18  TOR         Brandon Ingram  SF      23.5       3.5       5.5
# 5   2026-01-18  CHO         Brandon Miller  SF      20.5       3.5       4.5
# 6   2026-01-18  DEN            Bruce Brown  SG       6.5       2.5       4.5
# 7   2026-01-18  CHI             Coby White  SG      18.5       4.5       3.5
# 8   2026-01-18  TOR   Collin Murray-Boyles  PF      10.5       2.5       6.5
# 9   2026-01-18  CHO          Collin Sexton  SG      11.5       3.5       NaN
# 10  2026-01-18  BRK             Danny Wolf  PF      10.5       2.5       5.5
# 11  2026-01-18  BRK         Day'Ron Sharpe   C       8.5       2.5       7.5
# 12  2026-01-18  SAC          DeMar DeRozan  PF      19.5       3.5       3.5
# 13  2026-01-18  LAL          Deandre Ayton   C      13.5       NaN       9.5
# 14  2026-01-18  POR            Deni Avdija  SF      25.5       7.5       6.5
# 15  2026-01-18  SAC        Dennis Schroder  PG      11.5       4.5       2.5
# 16  2026-01-18  NOP            Derik Queen   C      10.5       3.5       6.5
# 17  2026-01-18  SAC       Domantas Sabonis   C      13.5       3.5       8.5
# 18  2026-01-18  POR        Donovan Clingan   C      12.5       1.5      12.5
# 19  2026-01-18  TOR      Immanuel Quickley  PG      16.5       5.5       3.5
# 20  2026-01-18  CHI            Isaac Okoro  SG       9.5       NaN       3.5
# 21  2026-01-18  HOU       Jabari Smith Jr.  PF      15.5       1.5       6.5
# 22  2026-01-18  LAL           Jake LaRavia  PF      12.5       2.5       5.5
# 23  2026-01-18  DEN          Jalen Pickett  SG       8.5       3.5       3.5
# 24  2026-01-18  CHI            Jalen Smith   C      12.5       1.5       8.5
# 25  2026-01-18  DEN           Jamal Murray  PG      27.5       8.5       4.5
# 26  2026-01-18  TOR            Jamal Shead  PG      11.5       6.5       2.5
# 27  2026-01-18  NOP         Jeremiah Fears  PG      12.5       3.5       3.5
# 28  2026-01-18  NOP           Jordan Poole  PG      10.5       2.5       1.5
# 29  2026-01-18  HOU           Kevin Durant  SF      25.5       4.5       5.5
# 30  2026-01-18  CHI          Kevin Huerter  SF       9.5       NaN       2.5
# 31  2026-01-18  CHO           Kon Knueppel  SF      17.5       3.5       4.5
# 32  2026-01-18  CHO            LaMelo Ball  PG      17.5       6.5       4.5
# 33  2026-01-18  LAL           LeBron James  SF      23.5       6.5       6.5
# 34  2026-01-18  LAL            Luka Doncic  PG      33.5       8.5       7.5
# 35  2026-01-18  SAC             Malik Monk  SG       8.5       NaN       NaN
# 36  2026-01-18  LAL           Marcus Smart  SG      10.5       3.5       3.5
# 37  2026-01-18  CHI          Matas Buzelis  PF      15.5       1.5       5.5
# 38  2026-01-18  SAC         Maxime Raynaud   C       8.5       NaN       5.5
# 39  2026-01-18  CHO          Miles Bridges  PF      17.5       3.5       6.5
# 40  2026-01-18  CHO         Moussa Diabate   C       7.5       NaN       8.5
# 41  2026-01-18  CHI         Nikola Vucevic   C      17.5       3.5       9.5
# 42  2026-01-18  BRK           Noah Clowney  PF      15.5       1.5       4.5
# 43  2026-01-18  DEN          Peyton Watson  SF      19.5       2.5       6.5
# 44  2026-01-18  SAC       Precious Achiuwa   C       9.5       NaN       6.5
# 45  2026-01-18  POR           Rayan Rupert  SG       5.5       NaN       2.5
# 46  2026-01-18  HOU          Reed Sheppard  SG      10.5       2.5       2.5
# 47  2026-01-18  LAL          Rui Hachimura  PF       7.5       NaN       2.5
# 48  2026-01-18  SAC      Russell Westbrook  SF      14.5       6.5       5.5
# 49  2026-01-18  NOP             Saddiq Bey  SF      12.5       1.5       4.5
# 50  2026-01-18  TOR  Sandro Mamukelashvili   C       9.5       1.5       4.5
# 51  2026-01-18  TOR         Scottie Barnes  PF      20.5       5.5       7.5
# 52  2026-01-18  POR         Shaedon Sharpe  SG      24.5       3.5       4.5
# 53  2026-01-18  CHO             Sion James  SG       5.5       2.5       3.5
# 54  2026-01-18  HOU           Steven Adams   C       6.5       1.5       8.5
# 55  2026-01-18  BRK           Terance Mann  SG       7.5       2.5       3.5
# 56  2026-01-18  DEN       Tim Hardaway Jr.  SG      14.5       NaN       2.5
# 57  2026-01-18  POR         Toumani Camara  PF      13.5       2.5       4.5
# 58  2026-01-18  CHI              Tre Jones  PG      10.5       6.5       3.5
# 59  2026-01-18  NOP        Trey Murphy III  SF      20.5       3.5       4.5
# 60  2026-01-18  BRK          Tyrese Martin  SG       8.5       NaN       NaN
# 61  2026-01-18  NOP             Yves Missi   C       5.5       NaN       5.5
# 62  2026-01-18  SAC            Zach LaVine  SG      20.5       2.5       3.5
# 63  2026-01-18  DEN             Zeke Nnaji  PF       6.5       NaN       4.5
# 64  2026-01-18  NOP        Zion Williamson  PF      20.5       3.5       5.5
#
#     STL_line  BLK_line  STL_BLK_line  TPM_line  PA_line  PR_line  RA_line  \
# 0        NaN       NaN           NaN       1.5     21.5     25.5     10.5
# 1        1.5       NaN           NaN       0.5     29.5     31.5     15.5
# 2        1.5       NaN           NaN       NaN     25.5     27.5     12.5
# 3        NaN       NaN           NaN       1.5     16.5     15.5      6.5
# 4        NaN       NaN           NaN       1.5     27.5     30.5      9.5
# 5        NaN       NaN           NaN       2.5     24.5     25.5      7.5
# 6        NaN       NaN           NaN       0.5      9.5     11.5      6.5
# 7        NaN       NaN           NaN       2.5     24.5     22.5      8.5
# 8        NaN       NaN           NaN       NaN     13.5     17.5      9.5
# 9        NaN       NaN           NaN       1.5     14.5      NaN      NaN
# 10       NaN       NaN           NaN       1.5     13.5     16.5      8.5
# 11       NaN       NaN           NaN       NaN     11.5     16.5      9.5
# 12       1.5       NaN           NaN       0.5     22.5     22.5      6.5
# 13       NaN       NaN           NaN       NaN      NaN     22.5      NaN
# 14       NaN       NaN           NaN       2.5     33.5     32.5     14.5
# 15       NaN       NaN           NaN       1.5     15.5     13.5      6.5
# 16       0.5       0.5           1.5       NaN     15.5     17.5     10.5
# 17       NaN       NaN           NaN       NaN     17.5     22.5     12.5
# 18       NaN       1.5           NaN       0.5     14.5     24.5     14.5
# 19       NaN       NaN           NaN       2.5     22.5     20.5      9.5
# 20       NaN       NaN           NaN       1.5      NaN     12.5      NaN
# 21       NaN       NaN           NaN       2.5     17.5     22.5      8.5
# 22       NaN       NaN           NaN       1.5     15.5     17.5      7.5
# 23       NaN       NaN           NaN       1.5     12.5     12.5      7.5
# 24       NaN       NaN           NaN       1.5     14.5     21.5     10.5
# 25       NaN       NaN           NaN       3.5     36.5     32.5     13.5
# 26       NaN       NaN           NaN       1.5     18.5     13.5      9.5
# 27       NaN       NaN           NaN       0.5     15.5     15.5      6.5
# 28       0.5       NaN           NaN       1.5     13.5     12.5      NaN
# 29       0.5       NaN           NaN       2.5     30.5     31.5     10.5
# 30       NaN       NaN           NaN       1.5      NaN     12.5      NaN
# 31       NaN       NaN           NaN       2.5     21.5     22.5      8.5
# 32       1.5       NaN           NaN       3.5     23.5     21.5     10.5
# 33       NaN       NaN           NaN       1.5     30.5     30.5     12.5
# 34       1.5       NaN           NaN       3.5     42.5     41.5     16.5
# 35       NaN       NaN           NaN       NaN      NaN      NaN      NaN
# 36       1.5       NaN           NaN       1.5     13.5     14.5      6.5
# 37       NaN       1.5           NaN       1.5     17.5     21.5      7.5
# 38       NaN       NaN           NaN       NaN      NaN     13.5      NaN
# 39       NaN       NaN           NaN       2.5     21.5     24.5      9.5
# 40       NaN       0.5           NaN       NaN      NaN     17.5      NaN
# 41       NaN       0.5           NaN       1.5     21.5     26.5     13.5
# 42       NaN       NaN           NaN       2.5     17.5     19.5      6.5
# 43       1.5       1.5           2.5       1.5     21.5     25.5      8.5
# 44       NaN       NaN           NaN       0.5      NaN     15.5      NaN
# 45       NaN       NaN           NaN       NaN      NaN      7.5      NaN
# 46       NaN       NaN           NaN       1.5     13.5     13.5      5.5
# 47       NaN       NaN           NaN       0.5      NaN      9.5      NaN
# 48       1.5       NaN           NaN       1.5     21.5     19.5     11.5
# 49       NaN       NaN           NaN       1.5     14.5     17.5      6.5
# 50       NaN       NaN           NaN       NaN     11.5     14.5      6.5
# 51       1.5       1.5           NaN       NaN     26.5     28.5     13.5
# 52       1.5       NaN           NaN       2.5     28.5     29.5      7.5
# 53       NaN       NaN           NaN       0.5      7.5      8.5      5.5
# 54       NaN       NaN           NaN       NaN      8.5     15.5     10.5
# 55       NaN       NaN           NaN       0.5     10.5     11.5      6.5
# 56       NaN       NaN           NaN       2.5      NaN     16.5      NaN
# 57       0.5       0.5           1.5       2.5     15.5     18.5      7.5
# 58       NaN       NaN           NaN       0.5     17.5     14.5      9.5
# 59       1.5       NaN           1.5       2.5     23.5     25.5      8.5
# 60       NaN       NaN           NaN       1.5      NaN      NaN      NaN
# 61       NaN       NaN           NaN       NaN      NaN     10.5      NaN
# 62       NaN       NaN           NaN       2.5     22.5     23.5      5.5
# 63       NaN       NaN           NaN       0.5      NaN     11.5      NaN
# 64       0.5       0.5           1.5       NaN     23.5     25.5      8.5
#
#     PRA_line  Spread  Total
# 0       28.5     1.5  226.5
# 1       38.5   -13.5  232.5
# 2       32.5   -13.5  232.5
# 3       19.5    -6.5  223.5
# 4       34.5     1.5  223.5
# 5       28.5    -1.5  226.5
# 6       13.5     1.5  226.5
# 7       27.5    -6.5  223.5
# 8       20.5     1.5  223.5
# 9        NaN    -1.5  226.5
# 10      19.5     6.5  223.5
# 11      18.5     6.5  223.5
# 12      26.5    -2.5  229.5
# 13       NaN    -1.5  223.5
# 14      40.5     2.5  229.5
# 15      17.5    -2.5  229.5
# 16      22.5    13.5  232.5
# 17      26.5    -2.5  229.5
# 18      26.5     2.5  229.5
# 19      26.5     1.5  223.5
# 20       NaN    -6.5  223.5
# 21      24.5   -13.5  232.5
# 22      20.5    -1.5  223.5
# 23      16.5     1.5  226.5
# 24      23.5    -6.5  223.5
# 25      41.5     1.5  226.5
# 26      20.5     1.5  223.5
# 27      18.5    13.5  232.5
# 28      14.5    13.5  232.5
# 29      36.5   -13.5  232.5
# 30       NaN    -6.5  223.5
# 31      26.5    -1.5  226.5
# 32      28.5    -1.5  226.5
# 33      36.5    -1.5  223.5
# 34      50.5    -1.5  223.5
# 35       NaN    -2.5  229.5
# 36      17.5    -1.5  223.5
# 37      23.5    -6.5  223.5
# 38       NaN    -2.5  229.5
# 39      28.5    -1.5  226.5
# 40       NaN    -1.5  226.5
# 41      31.5    -6.5  223.5
# 42      21.5     6.5  223.5
# 43      28.5     1.5  226.5
# 44       NaN    -2.5  229.5
# 45       NaN     2.5  229.5
# 46      16.5   -13.5  232.5
# 47       NaN    -1.5  223.5
# 48      26.5    -2.5  229.5
# 49      19.5    13.5  232.5
# 50      16.5     1.5  223.5
# 51      34.5     1.5  223.5
# 52      32.5     2.5  229.5
# 53      11.5    -1.5  226.5
# 54      17.5   -13.5  232.5
# 55      14.5     6.5  223.5
# 56       NaN     1.5  226.5
# 57      21.5     2.5  229.5
# 58      20.5    -6.5  223.5
# 59      28.5    13.5  232.5
# 60       NaN     6.5  223.5
# 61       NaN    13.5  232.5
# 62      26.5    -2.5  229.5
# 63       NaN     1.5  226.5
# 64      28.5    13.5  232.5

# %% [markdown]
# # Get Starting Lineups

# %%
def read_page(date=""):
    if date != "":
        date = f"?date={date}"
    url = f"https://fantasydata.com/nba/starting-lineups{date}"
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Accept-Language": "en-US,en;q=0.9"
    }

    resp = requests.get(url, headers=headers)
    resp.raise_for_status()

    html = resp.text
    
    return html

# %%
def extract_starters(team_div):
    """
    Extract starters from a team div (away/home),
    stopping at the Injuries section.
    """
    starters = []
    collecting = False

    for row in team_div.select(":scope > div.text-nowrap"):
        strong = row.find("strong")

        if strong:
            label = strong.get_text(strip=True)
            if label == "Starters":
                collecting = True
                continue
            if label == "Injuries":
                break

        if collecting:
            a = row.find("a")
            if not a:
                continue

            name = a.get_text(strip=True)
            href = a.get("href")

            # player ID is last number in URL
            player_id = href.rstrip("/").split("/")[-1]

            # position is plain text after name
            text = row.get_text(" ", strip=True)
            position = text.replace(name, "").strip()

            starters.append({
                "player_name": name,
                "player_id": player_id,
                "position": position
            })

    return starters

# %%
def parse_lineups(html):
    time.sleep(6)
    soup = BeautifulSoup(html, "lxml")
    games_data = []

    for game in soup.select("div.game"):
        # --- Game info ---
        info_div = game.select_one("div.header div.info > div")
        lines = list(info_div.stripped_strings)

        matchup = lines[0]
        game_time = lines[1]

        away_team, home_team = [t.strip() for t in matchup.split("@")]

        # --- Lineups ---
        away_div = game.select_one("div.away")
        home_div = game.select_one("div.home")

        away_starters = extract_starters(away_div)
        home_starters = extract_starters(home_div)

        for p in away_starters:
            games_data.append({
                "team_side": "away",
                "team": away_team,
                "opponent": home_team,
                "game_time": game_time,
                **p
            })

        for p in home_starters:
            games_data.append({
                "team_side": "home",
                "team": home_team,
                "opponent": away_team,
                "game_time": game_time,
                **p
            })

    return pd.DataFrame(games_data)

# %% [markdown]
# # Other functions

# %%
def email(error):
    
    # Email details
    sender_email = "rodolfoe7157@gmail.com"
    receiver_email = "rodolfoe7157@gmail.com"
    password = "cqgu bfey cnyx sfue"  # See note below

    subject = "NBA Starting Lineups error"
    body = f"ERROR: {error}"

    # Create message
    msg = MIMEMultipart()
    msg['From'] = sender_email
    msg['To'] = receiver_email
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))

    # Connect to Gmail SMTP server and send
    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as server:
        server.login(sender_email, password)
        server.send_message(msg)

    print("Email sent successfully!")

# %%
def remove_accents(text):
    if not isinstance(text, str):
        return text
    # Normalize to NFKD (decomposes characters)
    text = unicodedata.normalize('NFKD', text)
    # Encode to ASCII bytes, ignore non-ASCII characters, then decode back to str
    return text.encode('ascii', 'ignore').decode('ascii')

# %% [markdown]
# # Main

# %%
now = str(datetime.now().date() + timedelta(days=-1))
df_teams = pd.read_csv(f"../src/team_info_xref.csv")
df_teams['short_name'] = df_teams.Team.str.split(" ").str[-1]
df_teams['short_name'] = np.where(df_teams.ABV == 'POR', 'Trail Blazers', df_teams.short_name)
df = parse_lineups(read_page(now))
if df.shape[0] > 0:
    df = df.merge(df_teams, left_on=['team'], right_on=['short_name'])
    df = df[['ABV', 'player_name', 'position']].rename(columns={"ABV": "Team", "player_name": "Player", "position": "Pos"})
    df.insert(0, 'Date', pd.to_datetime(now))
    df['Player'] = df['Player'].apply(remove_accents)
    df = remap_plyr_names(df)
    display(df)
    partition_save_df(df, f"../tables/{YEAR}/daily_lineups.csv")
else:
    email(f'Empty lineup for {now}')
# Out:
#          Date Team               Player Pos
# 0  2026-01-22  HOU        Amen Thompson  SG
# 1  2026-01-22  HOU          Josh Okogie  SG
# 2  2026-01-22  HOU     Jabari Smith Jr.  PF
# 3  2026-01-22  HOU         Kevin Durant  PF
# 4  2026-01-22  HOU       Alperen Sengun   C
# 5  2026-01-22  PHI         Tyrese Maxey  PG
# 6  2026-01-22  PHI         VJ Edgecombe  SG
# 7  2026-01-22  PHI          Paul George  SF
# 8  2026-01-22  PHI      Kelly Oubre Jr.  SF
# 9  2026-01-22  PHI          Joel Embiid   C
# 10 2026-01-22  CHO          LaMelo Ball  PG
# 11 2026-01-22  CHO         Kon Knueppel  SG
# 12 2026-01-22  CHO       Brandon Miller  SF
# 13 2026-01-22  CHO        Miles Bridges  SF
# 14 2026-01-22  CHO       Moussa Diabate  PF
# 15 2026-01-22  ORL        Anthony Black  PG
# 16 2026-01-22  ORL         Desmond Bane  SG
# 17 2026-01-22  ORL       Paolo Banchero  PF
# 18 2026-01-22  ORL     Tristan da Silva  PF
# 19 2026-01-22  ORL   Wendell Carter Jr.   C
# 20 2026-01-22  DEN         Jamal Murray  PG
# 21 2026-01-22  DEN        Jalen Pickett  SG
# 22 2026-01-22  DEN        Peyton Watson  SF
# 23 2026-01-22  DEN         Aaron Gordon  PF
# 24 2026-01-22  DEN    Jonas Valanciunas   C
# 25 2026-01-22  WAS       Bub Carrington  PG
# 26 2026-01-22  WAS          Tre Johnson  SG
# 27 2026-01-22  WAS      Khris Middleton  SF
# 28 2026-01-22  WAS       Kyshawn George  SF
# 29 2026-01-22  WAS       Alexandre Sarr  PF
# 30 2026-01-22  GSW        Stephen Curry  PG
# 31 2026-01-22  GSW   Brandin Podziemski  SG
# 32 2026-01-22  GSW          Moses Moody  SG
# 33 2026-01-22  GSW           Gui Santos  SF
# 34 2026-01-22  GSW       Draymond Green  PF
# 35 2026-01-22  DAL         Max Christie  SG
# 36 2026-01-22  DAL        Naji Marshall  SF
# 37 2026-01-22  DAL         Cooper Flagg  PF
# 38 2026-01-22  DAL         Caleb Martin  PF
# 39 2026-01-22  DAL        Dwight Powell   C
# 40 2026-01-22  CHI           Coby White  SG
# 41 2026-01-22  CHI          Isaac Okoro  SF
# 42 2026-01-22  CHI        Matas Buzelis  SF
# 43 2026-01-22  CHI          Jalen Smith  PF
# 44 2026-01-22  CHI       Nikola Vucevic   C
# 45 2026-01-22  MIN      Anthony Edwards  SG
# 46 2026-01-22  MIN     Donte DiVincenzo  SG
# 47 2026-01-22  MIN        Julius Randle  PF
# 48 2026-01-22  MIN      Jaden McDaniels  PF
# 49 2026-01-22  MIN          Rudy Gobert   C
# 50 2026-01-22  SAS         De'Aaron Fox  PG
# 51 2026-01-22  SAS       Stephon Castle  SG
# 52 2026-01-22  SAS    Julian Champagnie  SF
# 53 2026-01-22  SAS      Harrison Barnes  SF
# 54 2026-01-22  SAS    Victor Wembanyama  PF
# 55 2026-01-22  UTA       Keyonte George  SG
# 56 2026-01-22  UTA        Cody Williams  SF
# 57 2026-01-22  UTA           Ace Bailey  SF
# 58 2026-01-22  UTA       Svi Mykhailiuk  SF
# 59 2026-01-22  UTA         Jusuf Nurkic   C
# 60 2026-01-22  LAL          Luka Doncic  PG
# 61 2026-01-22  LAL         Marcus Smart  PG
# 62 2026-01-22  LAL         LeBron James  SF
# 63 2026-01-22  LAL         Jake LaRavia  PF
# 64 2026-01-22  LAL        Deandre Ayton   C
# 65 2026-01-22  LAC            Kris Dunn  PG
# 66 2026-01-22  LAC         James Harden  SG
# 67 2026-01-22  LAC        Kawhi Leonard  SF
# 68 2026-01-22  LAC         John Collins  PF
# 69 2026-01-22  LAC          Ivica Zubac   C
# 70 2026-01-22  MIA  Kasparas Jakucionis  PG
# 71 2026-01-22  MIA        Norman Powell  SG
# 72 2026-01-22  MIA        Pelle Larsson  SG
# 73 2026-01-22  MIA       Andrew Wiggins  SF
# 74 2026-01-22  MIA          Bam Adebayo   C
# 75 2026-01-22  POR         Jrue Holiday  PG
# 76 2026-01-22  POR       Shaedon Sharpe  SG
# 77 2026-01-22  POR       Toumani Camara  SF
# 78 2026-01-22  POR          Deni Avdija  SF
# 79 2026-01-22  POR      Donovan Clingan   C

# %%
now = str(datetime.now().date())
df_teams = pd.read_csv(f"../src/team_info_xref.csv")
df_teams['short_name'] = df_teams.Team.str.split(" ").str[-1]
df_teams['short_name'] = np.where(df_teams.ABV == 'POR', 'Trail Blazers', df_teams.short_name)
df = parse_lineups(read_page())
if df.shape[0] > 0:
    df = df.merge(df_teams, left_on=['team'], right_on=['short_name'])
    df = df[['ABV', 'player_name', 'position']].rename(columns={"ABV": "Team", "player_name": "Player", "position": "Pos"})
    df.insert(0, 'Date', pd.to_datetime(now))
    df['Player'] = df['Player'].apply(remove_accents)
    df = remap_plyr_names(df)
    display(df)
    partition_save_df(df, f"../tables/{YEAR}/daily_lineups.csv")
else:
    email(f'Empty lineup for {now}')
# Out:
#          Date Team                    Player Pos
# 0  2026-01-23  HOU             Amen Thompson  SG
# 1  2026-01-23  HOU               Josh Okogie  SG
# 2  2026-01-23  HOU              Kevin Durant  PF
# 3  2026-01-23  HOU          Jabari Smith Jr.  PF
# 4  2026-01-23  HOU            Alperen Sengun   C
# 5  2026-01-23  DET           Cade Cunningham  PG
# 6  2026-01-23  DET            Ausar Thompson  SG
# 7  2026-01-23  DET           Duncan Robinson  SG
# 8  2026-01-23  DET             Tobias Harris  SF
# 9  2026-01-23  DET               Jalen Duren   C
# 10 2026-01-23  SAC         Russell Westbrook  PG
# 11 2026-01-23  SAC               Zach LaVine  SG
# 12 2026-01-23  SAC             DeMar DeRozan  SF
# 13 2026-01-23  SAC          Precious Achiuwa  PF
# 14 2026-01-23  SAC          Domantas Sabonis   C
# 15 2026-01-23  CLE          Donovan Mitchell  SG
# 16 2026-01-23  CLE              Jaylon Tyson  SF
# 17 2026-01-23  CLE               Evan Mobley  PF
# 18 2026-01-23  CLE                 Dean Wade  PF
# 19 2026-01-23  CLE             Jarrett Allen   C
# 20 2026-01-23  PHO              Devin Booker  SG
# 21 2026-01-23  PHO               Jalen Green  SG
# 22 2026-01-23  PHO             Dillon Brooks  SF
# 23 2026-01-23  PHO             Royce O'Neale  PF
# 24 2026-01-23  PHO             Mark Williams   C
# 25 2026-01-23  ATL             Dyson Daniels  PG
# 26 2026-01-23  ATL  Nickeil Alexander-Walker  SG
# 27 2026-01-23  ATL              Luke Kennard  SG
# 28 2026-01-23  ATL             Jalen Johnson  PF
# 29 2026-01-23  ATL            Onyeka Okongwu   C
# 30 2026-01-23  BOS          Payton Pritchard  PG
# 31 2026-01-23  BOS             Derrick White  SG
# 32 2026-01-23  BOS              Jaylen Brown  SG
# 33 2026-01-23  BOS                Sam Hauser  SF
# 34 2026-01-23  BOS             Neemias Queta   C
# 35 2026-01-23  BRK                Egor Demin  PG
# 36 2026-01-23  BRK              Terance Mann  PG
# 37 2026-01-23  BRK        Michael Porter Jr.  SF
# 38 2026-01-23  BRK              Noah Clowney  PF
# 39 2026-01-23  BRK           Nicolas Claxton   C
# 40 2026-01-23  NOP            Jeremiah Fears  PG
# 41 2026-01-23  NOP           Trey Murphy III  SF
# 42 2026-01-23  NOP             Herbert Jones  SF
# 43 2026-01-23  NOP           Zion Williamson  PF
# 44 2026-01-23  NOP               Derik Queen   C
# 45 2026-01-23  MEM               Cam Spencer  SG
# 46 2026-01-23  MEM             Cedric Coward  SG
# 47 2026-01-23  MEM              Jaylen Wells  SF
# 48 2026-01-23  MEM         Jaren Jackson Jr.  PF
# 49 2026-01-23  MEM              Jock Landale   C
# 50 2026-01-23  IND           Andrew Nembhard  PG
# 51 2026-01-23  IND              Ben Sheppard  SF
# 52 2026-01-23  IND             Aaron Nesmith  PF
# 53 2026-01-23  IND             Pascal Siakam  PF
# 54 2026-01-23  IND                  Jay Huff   C
# 55 2026-01-23  OKC   Shai Gilgeous-Alexander  PG
# 56 2026-01-23  OKC             Cason Wallace  PG
# 57 2026-01-23  OKC             Luguentz Dort  SF
# 58 2026-01-23  OKC           Jaylin Williams  PF
# 59 2026-01-23  OKC             Chet Holmgren   C
# 60 2026-01-23  DEN              Jamal Murray  PG
# 61 2026-01-23  DEN           Christian Braun  SG
# 62 2026-01-23  DEN             Peyton Watson  SF
# 63 2026-01-23  DEN             Spencer Jones  PF
# 64 2026-01-23  DEN              Aaron Gordon  PF
# 65 2026-01-23  MIL              Ryan Rollins  SG
# 66 2026-01-23  MIL                  AJ Green  SG
# 67 2026-01-23  MIL               Gary Harris  SG
# 68 2026-01-23  MIL     Giannis Antetokounmpo  PF
# 69 2026-01-23  MIL              Myles Turner   C
# 70 2026-01-23  TOR         Immanuel Quickley  PG
# 71 2026-01-23  TOR                RJ Barrett  SG
# 72 2026-01-23  TOR            Brandon Ingram  SF
# 73 2026-01-23  TOR            Scottie Barnes  SF
# 74 2026-01-23  TOR      Collin Murray-Boyles  PF
# 75 2026-01-23  POR            Shaedon Sharpe  SG
# 76 2026-01-23  POR              Sidy Cissoko  SF
# 77 2026-01-23  POR               Deni Avdija  SF
# 78 2026-01-23  POR            Toumani Camara  SF
# 79 2026-01-23  POR           Donovan Clingan   C
# ../tables/2025/daily_lineups.csv saved!
