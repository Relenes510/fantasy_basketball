# %%
import requests
from bs4 import BeautifulSoup
from nbainjuries import injury
import duckdb
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time
import os
import unicodedata
import warnings
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

pd.set_option('display.max_rows', None)
warnings.filterwarnings("ignore")

cwd = os.path.abspath(os.getcwd()).replace("\\", "/")
if cwd.startswith("C:/Users/Rodolfo/"):
    RUN_LOCATION = "local"
else:
    RUN_LOCATION = "cloud"
time_offset = {"local": 3, "cloud": -5}

print("Current working dir:", cwd)
print("RUN_LOCATION =", RUN_LOCATION)
# Out:
# Current working dir: C:/Users/Rodolfo/Jupyter_files/FantasyBasketball/notebooks
# RUN_LOCATION = local

# %%
# %run ./common_utils.ipynb

# %% [markdown]
# # Get Injuries Report

# %%
def get_injuries():
    con = duckdb.connect(database=":memory:")
    df_teams = pd.read_csv("../src/team_info_xref.csv")

    df_inj = injury.get_reportdata(datetime.now() + timedelta(hours=time_offset[RUN_LOCATION]), return_df=True)
    df_inj = df_inj.rename(columns={"Game Date": "Date", "Player Name": "Player", "Current Status": "Status"})
    df_inj['Player'] = df_inj.Player.str.split(",").str[1] + " " + df_inj.Player.str.split(",").str[0]
    df_inj['Player'] = df_inj['Player'].str.strip()
    df_inj['Date'] = pd.to_datetime(df_inj['Date'])
    df_inj = remap_plyr_names(df_inj)
    df_inj = con.execute(f"""SELECT Date, ABV as Team, Player, Status, Reason FROM df_inj 
                             JOIN df_teams ON df_inj.Team = df_teams.Team
                             WHERE Date = '{str((datetime.now() + timedelta(hours=time_offset[RUN_LOCATION])).date())}' AND Status != 'Available'""").fetchdf()
    partition_save_df(df_inj, f"../tables/{YEAR}/injuries.csv")
    display(df_inj[df_inj.Status == 'Out'])
get_injuries()
# Out:
# Validated Injury-Report_2026-02-19_04_00PM.
# ../tables/2025/injuries.csv saved!
#           Date Team              Player Status  \
# 0   2026-02-19  ATL         RayJ Dennis    Out
# 1   2026-02-19  ATL       Caleb Houstan    Out
# 2   2026-02-19  ATL    Jonathan Kuminga    Out
# 3   2026-02-19  PHI    MarJon Beauchamp    Out
# 4   2026-02-19  PHI        Johni Broome    Out
# 5   2026-02-19  PHI         Joel Embiid    Out
# 6   2026-02-19  PHI         Paul George    Out
# 7   2026-02-19  BRK         Nic Claxton    Out
# 8   2026-02-19  BRK       Tyson Etienne    Out
# 9   2026-02-19  BRK      Chaney Johnson    Out
# 10  2026-02-19  BRK        E.J. Liddell    Out
# 11  2026-02-19  BRK         Josh Minott    Out
# 12  2026-02-19  BRK           Ben Saraf    Out
# 13  2026-02-19  CLE      Emanuel Miller    Out
# 14  2026-02-19  CLE         Riley Minix    Out
# 15  2026-02-19  CLE           Max Strus    Out
# 16  2026-02-19  CLE     Nae'Qwan Tomlin    Out
# 17  2026-02-19  HOU        Steven Adams    Out
# 18  2026-02-19  HOU      Tristen Newton    Out
# 19  2026-02-19  HOU       Fred VanVleet    Out
# 20  2026-02-19  CHO       Miles Bridges    Out
# 21  2026-02-19  CHO      Moussa Diabate    Out
# 22  2026-02-19  CHO       Liam McNeeley    Out
# 23  2026-02-19  CHO          Coby White    Out
# 24  2026-02-19  IND       Johnny Furphy    Out
# 25  2026-02-19  IND   Tyrese Haliburton    Out
# 31  2026-02-19  IND       Pascal Siakam    Out
# 33  2026-02-19  IND          Obi Toppin    Out
# 34  2026-02-19  IND         Ivica Zubac    Out
# 35  2026-02-19  WAS       Anthony Davis    Out
# 36  2026-02-19  WAS    D'Angelo Russell    Out
# 37  2026-02-19  WAS           Alex Sarr    Out
# 38  2026-02-19  WAS        Cam Whitmore    Out
# 39  2026-02-19  WAS          Trae Young    Out
# 40  2026-02-19  DET         Jalen Duren    Out
# 41  2026-02-19  DET       Bobi Klintman    Out
# 42  2026-02-19  DET   Wendell Moore Jr.    Out
# 43  2026-02-19  DET      Isaiah Stewart    Out
# 48  2026-02-19  NYK       Miles McBride    Out
# 50  2026-02-19  TOR      Chucky Hepburn    Out
# 51  2026-02-19  TOR         A.J. Lawson    Out
# 53  2026-02-19  TOR       Alijah Martin    Out
# 55  2026-02-19  CHI        Zach Collins    Out
# 56  2026-02-19  CHI        Noa Essengue    Out
# 59  2026-02-19  CHI       Yuki Kawamura    Out
# 60  2026-02-19  CHI         Mac McClung    Out
# 63  2026-02-19  PHO        Cole Anthony    Out
# 64  2026-02-19  PHO       Dillon Brooks    Out
# 65  2026-02-19  PHO   Haywood Highsmith    Out
# 66  2026-02-19  SAS     Harrison Ingram    Out
# 67  2026-02-19  SAS  David Jones Garcia    Out
# 68  2026-02-19  SAS       Mason Plumlee    Out
# 69  2026-02-19  SAS       Stanley Umude    Out
# 70  2026-02-19  SAS    Lindy Waters III    Out
# 71  2026-02-19  BOS        Jayson Tatum    Out
# 72  2026-02-19  GSW        Jimmy Butler    Out
# 73  2026-02-19  GSW            LJ Cryer    Out
# 74  2026-02-19  GSW          Seth Curry    Out
# 75  2026-02-19  GSW       Stephen Curry    Out
# 77  2026-02-19  ORL     Colin Castleton    Out
# 78  2026-02-19  ORL        Alex Morales    Out
# 79  2026-02-19  ORL        Franz Wagner    Out
# 80  2026-02-19  SAC      Dylan Cardwell    Out
# 81  2026-02-19  SAC     De'Andre Hunter    Out
# 82  2026-02-19  SAC         Zach LaVine    Out
# 83  2026-02-19  SAC    Domantas Sabonis    Out
# 84  2026-02-19  SAC      Isaiah Stevens    Out
# 85  2026-02-19  DEN         Tamar Bates    Out
# 86  2026-02-19  DEN        Aaron Gordon    Out
# 87  2026-02-19  DEN        Curtis Jones    Out
# 89  2026-02-19  DEN       Peyton Watson    Out
#
#                                                Reason
# 0                                  G League - Two-Way
# 1                                       Not With Team
# 2             Injury/Illness - Left Knee; Bone Bruise
# 3                                  G League - Two-Way
# 4                            G League - On Assignment
# 5   Injury/Illness - Right Knee; Injury Management...
# 6                                   League Suspension
# 7                Injury/Illness - Right Ankle; Sprain
# 8                                  G League - Two-Way
# 9                                  G League - Two-Way
# 10                                 G League - Two-Way
# 11                           G League - On Assignment
# 12                           G League - On Assignment
# 13                                 G League - Two-Way
# 14                                 G League - Two-Way
# 15  Injury/Illness - Left Foot; Surgery - Jones Fr...
# 16               Injury/Illness - Left Calf; Soreness
# 17               Injury/Illness - Left Ankle; Surgery
# 18                                 G League - Two-Way
# 19            Injury/Illness - Right Knee; ACL Repair
# 20                                  League Suspension
# 21                                  League Suspension
# 22                Injury/Illness - Left Ankle; Sprain
# 23                 Injury/Illness - Left Calf; Strain
# 24                   Injury/Illness - Right ACL; Tear
# 25       Injury/Illness - Right Achilles Tendon; Tear
# 31                                   Personal Reasons
# 33       Injury/Illness - Right Foot; Stress Fracture
# 34                Injury/Illness - Left Ankle; Sprain
# 35               Injury/Illness - Left Finger; Sprain
# 36                                      Not With Team
# 37           Injury/Illness - Right Hamstring; Strain
# 38  Injury/Illness - Right Shoulder; Deep Vein Thr...
# 39  Injury/Illness - Right Knee; MCL Sprain; Quad ...
# 40                                  League Suspension
# 41                           G League - On Assignment
# 42                                 G League - Two-Way
# 43                                  League Suspension
# 48       Injury/Illness - Pelvic; Core Muscle Surgery
# 50                                 G League - Two-Way
# 51                                 G League - Two-Way
# 53                                 G League - Two-Way
# 55             Injury/Illness - Right 1st Toe; Sprain
# 56            Injury/Illness - Left Shoulder; Surgery
# 59                                 G League - Two-Way
# 60                                 G League - Two-Way
# 63                                      Not With Team
# 64                                  League Suspension
# 65     Injury/Illness - Right Knee; Injury Management
# 66                                 G League - Two-Way
# 67                                 G League - Two-Way
# 68               Return to Competition Reconditioning
# 69                                 G League - Two-Way
# 70         Injury/Illness - Left Knee; Hyperextension
# 71            Injury/Illness - Right Achilles; Repair
# 72                Injury/Illness - Right ACL; Surgery
# 73                                 G League - Two-Way
# 74    Injury/Illness - Left Sciatic Nerve; Irritation
# 75  Injury/Illness - Right Patellofemoral; Pain Sy...
# 77                                 G League - Two-Way
# 78                                 G League - Two-Way
# 79  Injury/Illness - Left Ankle; High Ankle Sprain...
# 80                Injury/Illness - Left Ankle; Sprain
# 81                  Injury/Illness - Left Eye; Iritis
# 82   Injury/Illness - Right 5th Finger; Tendon Repair
# 83        Injury/Illness - Left Knee; Meniscus Repair
# 84                                 G League - Two-Way
# 85                Injury/Illness - Left Foot; Surgery
# 86           Injury/Illness - Right Hamstring; Strain
# 87                                 G League - Two-Way
# 89           Injury/Illness - Right Hamstring; Strain

# %% [markdown]
# # Get Betting Odds

# %%
def get_game_odds():

    df_gms = pd.read_csv(f"../tables/{YEAR}/nba_schedule.csv")
    df_gms['Date'] = pd.to_datetime(df_gms.Date)
    df_gms_td = df_gms[(df_gms.Date == str((datetime.now() + timedelta(hours=time_offset[RUN_LOCATION])).date()))]
    df_gms_td['gm_id'] = df_gms_td.AwayABV + "_" + df_gms_td.HomeABV
    df_gms_td['gm_id2'] = df_gms_td.HomeABV + "_" + df_gms_td.AwayABV
    gms_today = df_gms_td.gm_id.tolist() + df_gms_td.gm_id2.tolist()    

    dk_tm_mapping = {
                    "ATL Hawks": "ATL", "BKN Nets": "BRK", "BOS Celtics": "BOS", "CHA Hornets": "CHO", "CHI Bulls": "CHI",
                    "CLE Cavaliers": "CLE", "DAL Mavericks": "DAL", "DEN Nuggets": "DEN", "DET Pistons": "DET", 
                    "GS Warriors": "GSW", "HOU Rockets": "HOU", "IND Pacers": "IND", "LA Clippers": "LAC", 
                    "LA Lakers": "LAL", "MEM Grizzlies": "MEM", "MIA Heat": "MIA", "MIL Bucks": "MIL", "MIN Timberwolves": "MIN",
                    "NO Pelicans": "NOP", "NY Knicks": "NYK", "OKC Thunder": "OKC", "ORL Magic": "ORL", "PHI 76ers": "PHI",
                    "PHO Suns": "PHO", "POR Trail Blazers": "POR", "SA Spurs": "SAS", "SAC Kings": "SAC", "TOR Raptors": "TOR",
                    "UTA Jazz": "UTA", "WAS Wizards": "WAS", "GSW Warriors": "GSW", "LAL Lakers": "LAL", "NOP Pelicans": "NOP",
                    "NYK Knicks": "NYK", "PHX Suns": "PHO", "SAS Spurs": "SAS"
                    }

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Accept": "*/*",
        "Accept-Language": "en-US,en;q=0.9",
        "Referer": "https://sportsbook.draftkings.com/",
        "Origin": "https://sportsbook.draftkings.com"
    }
    response = requests.get(f"https://sportsbook-nash.draftkings.com/sites/US-SB/api/sportscontent/controldata/league/leagueSubcategory/v1/markets?isBatchable=false&templateVars=42648%2C4511&eventsQuery=%24filter%3DleagueId%20eq%20%2742648%27%20AND%20clientMetadata%2FSubcategories%2Fany%28s%3A%20s%2FId%20eq%20%274511%27%29&marketsQuery=%24filter%3DclientMetadata%2FsubCategoryId%20eq%20%274511%27%20AND%20tags%2Fall%28t%3A%20t%20ne%20%27SportcastBetBuilder%27%29&include=Events&entity=events", headers=headers)
    if response.status_code != 200:
        raise Exception('Bad Request')

    ids = []
    rows = []
    for i in range(len(response.json()['selections'])):
        if 'HC' in response.json()['selections'][i]['id'] or 'OU' in response.json()['selections'][i]['id']:
            ids.append(response.json()['selections'][i])
    for i in range(0, len(ids) - 1, 4):
        team1 = ids[i]['label']
        spread1 = ids[i]['points']
        team2 = ids[i+1]['label']
        spread2 = ids[i+1]['points']
        total = ids[i+2]['points']
        rows.append({"Team": team1, "Opp": team2, "Spread": spread1, "Total": total})
        rows.append({"Team": team2, "Opp": team1, "Spread": spread2, "Total": total})
    df_tm_bets = pd.DataFrame(rows)
    
    for key, value in dk_tm_mapping.items():
        df_tm_bets['Team'] = np.where(df_tm_bets.Team == key, value, df_tm_bets.Team)
        df_tm_bets['Opp'] = np.where(df_tm_bets.Opp == key, value, df_tm_bets.Opp)

    df_tm_bets['gm_id'] = df_tm_bets.Team + "_" + df_tm_bets.Opp
    df_tm_bets = df_tm_bets[(df_tm_bets.gm_id.isin(gms_today))].drop(['Opp', 'gm_id'], axis=1)
    
    return df_tm_bets

def get_sportsbook():
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Accept": "*/*",
        "Accept-Language": "en-US,en;q=0.9",
        "Referer": "https://sportsbook.draftkings.com/",
        "Origin": "https://sportsbook.draftkings.com"
    }

    dk_cats = {"PTS": 12488, "AST": 12495, "REB": 12492, "STL": 13508, "BLK": 13780, "STL_BLK": 13781, "TPM": 12497, 
               "PA": 9973, "PR": 9976, "RA": 9974, "PRA": 5001}
    df_lines = pd.DataFrame()
    for key, value in dk_cats.items():
        response = requests.get(f"https://sportsbook-nash.draftkings.com/sites/US-SB/api/sportscontent/controldata/league/leagueSubcategory/v1/markets?isBatchable=false&templateVars=42648%2C{value}&eventsQuery=%24filter%3DleagueId%20eq%20%2742648%27%20AND%20clientMetadata%2FSubcategories%2Fany%28s%3A%20s%2FId%20eq%20%27{value}%27%29&marketsQuery=%24filter%3DclientMetadata%2FsubCategoryId%20eq%20%27{value}%27%20AND%20tags%2Fall%28t%3A%20t%20ne%20%27SportcastBetBuilder%27%29&include=Events&entity=events", headers=headers)
        if response.status_code != 200:
            raise Exception('Bad Request')

        plyr_names = []
        pnt_lines = []
        for i in response.json()['selections']:
            plyr_names.append(i['participants'][0]['name'])
            pnt_lines.append(i['points'])
        df_dk = pd.DataFrame({"Player": plyr_names, f"{key}_line": pnt_lines}).drop_duplicates().reset_index(drop=True)

        if df_lines.empty:
            df_lines = df_dk
        else:
            df_lines = pd.merge(df_lines, df_dk, on="Player", how="outer")

    df_lines = pd.merge(pd.read_csv(f"../tables/{YEAR}/plyr_pos_xref.csv"), df_lines, on='Player', how='right')
    df_lines = pd.merge(df_lines, get_game_odds(), on='Team')
    df_lines.insert(0, 'Date', pd.to_datetime(str((datetime.now() + timedelta(hours=time_offset[RUN_LOCATION])).date())))

    partition_save_df(df_lines, f"../tables/{YEAR}/parlay_lines.csv") 
    display(df_lines)
get_sportsbook()
# Out:
# ../tables/2025/parlay_lines.csv saved!
#            Date Team                    Player Pos  PTS_line  AST_line  \
# 0    2026-02-19  IND             Aaron Nesmith  SF      14.5       2.5
# 1    2026-02-19  PHI                 Adem Bona   C       7.5       NaN
# 2    2026-02-19  GSW                Al Horford   C       7.5       2.5
# 3    2026-02-19  HOU            Alperen Sengun   C      18.5       5.5
# 4    2026-02-19  HOU             Amen Thompson  PG      15.5       4.5
# 5    2026-02-19  IND           Andrew Nembhard  PG      18.5       7.5
# 6    2026-02-19  CHI           Anfernee Simons  SG      15.5       3.5
# 7    2026-02-19  ORL             Anthony Black  PG      17.5       4.5
# 8    2026-02-19  DET            Ausar Thompson  SF       8.5       NaN
# 9    2026-02-19  BOS         Baylor Scheierman  SG       5.5       1.5
# 10   2026-02-19  IND              Ben Sheppard  SG       6.5       NaN
# 11   2026-02-19  LAC        Bennedict Mathurin  SF      15.5       2.5
# 12   2026-02-19  WAS           Bilal Coulibaly  SG       9.5       NaN
# 13   2026-02-19  GSW        Brandin Podziemski  SG      13.5       3.5
# 14   2026-02-19  TOR            Brandon Ingram  SF      22.5       3.5
# 15   2026-02-19  CHO            Brandon Miller  SF      22.5       3.5
# 16   2026-02-19  LAC               Brook Lopez   C       9.5       1.5
# 17   2026-02-19  DEN               Bruce Brown  SG       7.5       1.5
# 18   2026-02-19  ATL               CJ McCollum  PG      16.5       3.5
# 19   2026-02-19  DET           Cade Cunningham  PG      25.5       8.5
# 20   2026-02-19  DEN           Cameron Johnson  SF       9.5       NaN
# 21   2026-02-19  DET              Caris LeVert  SG       6.5       NaN
# 22   2026-02-19  DEN           Christian Braun  SG      10.5       NaN
# 23   2026-02-19  HOU              Clint Capela   C       3.5       NaN
# 24   2026-02-19  PHO          Collin Gillespie  PG      13.5       4.5
# 25   2026-02-19  CHI             Collin Sexton  SG      14.5       NaN
# 26   2026-02-19  ATL             Corey Kispert  SF       9.5       NaN
# 27   2026-02-19  DET            Daniss Jenkins  PG       8.5       NaN
# 28   2026-02-19  BRK                Danny Wolf  PF      10.5       2.5
# 29   2026-02-19  BRK            Day'Ron Sharpe   C      12.5       3.5
# 30   2026-02-19  SAS              De'Aaron Fox  PG      17.5       6.5
# 31   2026-02-19  GSW         De'Anthony Melton  PG      13.5       2.5
# 32   2026-02-19  SAC             DeMar DeRozan  PF      16.5       3.5
# 33   2026-02-19  CLE           Dennis Schroder  PG       8.5       3.5
# 34   2026-02-19  LAC         Derrick Jones Jr.  SF       8.5       1.5
# 35   2026-02-19  BOS             Derrick White  SG      16.5       5.5
# 36   2026-02-19  ORL              Desmond Bane  SG      20.5       3.5
# 37   2026-02-19  PHO              Devin Booker  SG      26.5       6.5
# 38   2026-02-19  SAC              Devin Carter  PG      11.5       3.5
# 39   2026-02-19  SAS             Devin Vassell  SG      11.5       NaN
# 40   2026-02-19  PHI           Dominick Barlow  PF       9.5       NaN
# 41   2026-02-19  CLE          Donovan Mitchell  SG      27.5       5.5
# 42   2026-02-19  GSW            Draymond Green  PF       8.5       4.5
# 43   2026-02-19  DET           Duncan Robinson  SF      11.5       NaN
# 44   2026-02-19  SAS              Dylan Harper  SG      10.5       3.5
# 45   2026-02-19  ATL             Dyson Daniels  SG      10.5       5.5
# 46   2026-02-19  CLE               Evan Mobley  PF      14.5       2.5
# 47   2026-02-19  GSW            Gary Payton II  SG       6.5       NaN
# 48   2026-02-19  CHO            Grant Williams  PF       9.5       NaN
# 49   2026-02-19  PHO             Grayson Allen  SG      13.5       3.5
# 50   2026-02-19  GSW                Gui Santos  PF      10.5       2.5
# 51   2026-02-19  SAS           Harrison Barnes  PF       8.5       NaN
# 52   2026-02-19  TOR         Immanuel Quickley  PG      16.5       5.5
# 53   2026-02-19  CHI               Isaac Okoro  SG       8.5       NaN
# 54   2026-02-19  HOU          Jabari Smith Jr.  PF      13.5       NaN
# 55   2026-02-19  CHI                Jaden Ivey  SG       8.5       NaN
# 56   2026-02-19  TOR              Jakob Poeltl   C       8.5       NaN
# 57   2026-02-19  NYK             Jalen Brunson  PG      26.5       5.5
# 58   2026-02-19  PHO               Jalen Green  SG      13.5       2.5
# 59   2026-02-19  ATL             Jalen Johnson  SF      22.5       8.5
# 60   2026-02-19  CHI               Jalen Smith   C      11.5       NaN
# 61   2026-02-19  ORL               Jalen Suggs  PG      14.5       6.5
# 62   2026-02-19  DEN              Jamal Murray  PG      23.5       7.5
# 63   2026-02-19  TOR               Jamal Shead  PG       5.5       4.5
# 64   2026-02-19  CLE              James Harden  PG      20.5       8.5
# 65   2026-02-19  IND             Jarace Walker  PF      16.5       NaN
# 66   2026-02-19  CLE             Jarrett Allen   C      14.5       NaN
# 67   2026-02-19  IND                  Jay Huff   C      12.5       NaN
# 68   2026-02-19  BOS              Jaylen Brown  SF      28.5       4.5
# 69   2026-02-19  CLE              Jaylon Tyson  SG      10.5       NaN
# 70   2026-02-19  ATL              Jock Landale   C       7.5       NaN
# 71   2026-02-19  LAC              John Collins  PF      14.5       1.5
# 72   2026-02-19  DEN         Jonas Valanciunas   C       7.5       NaN
# 73   2026-02-19  PHO            Jordan Goodwin  PG       8.5       2.5
# 74   2026-02-19  CHI               Josh Giddey  PG      12.5       5.5
# 75   2026-02-19  CHO                Josh Green  SG       4.5       NaN
# 76   2026-02-19  NYK                 Josh Hart  SF      10.5       5.5
# 77   2026-02-19  SAS         Julian Champagnie  SF       6.5       NaN
# 78   2026-02-19  DEN          Julian Strawther  SG       8.5       NaN
# 79   2026-02-19  WAS         Justin Champagnie  SF      10.5       NaN
# 80   2026-02-19  NYK        Karl-Anthony Towns   C      18.5       2.5
# 81   2026-02-19  LAC             Kawhi Leonard  SF      27.5       4.5
# 82   2026-02-19  SAC             Keegan Murray  PF      12.5       NaN
# 83   2026-02-19  SAS            Keldon Johnson  SF      11.5       NaN
# 84   2026-02-19  PHI           Kelly Oubre Jr.  SF      16.5       NaN
# 85   2026-02-19  HOU              Kevin Durant  SF      24.5       4.5
# 86   2026-02-19  CHO              Kon Knueppel  SF      18.5       3.5
# 87   2026-02-19  LAC                 Kris Dunn  PG       8.5       4.5
# 88   2026-02-19  GSW        Kristaps Porzingis   C      12.5       1.5
# 89   2026-02-19  WAS            Kyshawn George  SF      14.5       3.5
# 90   2026-02-19  CHO               LaMelo Ball  PG      20.5       6.5
# 91   2026-02-19  NYK             Landry Shamet  SG       8.5       NaN
# 92   2026-02-19  PHO             Mark Williams   C      11.5       NaN
# 93   2026-02-19  CHI             Matas Buzelis  PF      14.5       NaN
# 94   2026-02-19  SAC            Maxime Raynaud   C      12.5       NaN
# 95   2026-02-19  BRK        Michael Porter Jr.  SF      24.5       2.5
# 96   2026-02-19  NYK             Mikal Bridges  SF      14.5       3.5
# 97   2026-02-19  NYK         Mitchell Robinson   C       4.5       NaN
# 98   2026-02-19  ORL             Moritz Wagner   C       9.5       NaN
# 99   2026-02-19  GSW               Moses Moody  SG      13.5       1.5
# 100  2026-02-19  BOS             Neemias Queta   C       6.5       1.5
# 101  2026-02-19  ATL  Nickeil Alexander-Walker  SG      18.5       3.5
# 102  2026-02-19  DEN              Nikola Jokic   C      26.5      10.5
# 103  2026-02-19  BOS            Nikola Vucevic   C      12.5       2.5
# 104  2026-02-19  SAC            Nique Clifford  SG      10.5       2.5
# 105  2026-02-19  BRK              Noah Clowney  PF      12.5       NaN
# 106  2026-02-19  BRK              Nolan Traore  PG      10.5       5.5
# 107  2026-02-19  NYK                OG Anunoby  PF      14.5       NaN
# 108  2026-02-19  ATL            Onyeka Okongwu   C      15.5       2.5
# 109  2026-02-19  PHO              Oso Ighodaro  PF       5.5       NaN
# 110  2026-02-19  ORL            Paolo Banchero  PF      23.5       5.5
# 111  2026-02-19  GSW               Pat Spencer  PG      11.5       5.5
# 112  2026-02-19  DET                 Paul Reed   C      13.5       NaN
# 113  2026-02-19  BOS          Payton Pritchard  PG      17.5       5.5
# 114  2026-02-19  SAC          Precious Achiuwa   C       7.5       NaN
# 115  2026-02-19  PHI            Quentin Grimes  SG      12.5       3.5
# 116  2026-02-19  TOR                RJ Barrett  SF      18.5       3.5
# 117  2026-02-19  HOU             Reed Sheppard  SG      11.5       2.5
# 118  2026-02-19  PHO             Royce O'Neale  SF      10.5       NaN
# 119  2026-02-19  SAC         Russell Westbrook  SF      14.5       6.5
# 120  2026-02-19  CHO          Ryan Kalkbrenner   C       7.5       NaN
# 121  2026-02-19  BOS                Sam Hauser  PF       9.5       1.5
# 122  2026-02-19  CLE               Sam Merrill  SG      10.5       NaN
# 123  2026-02-19  TOR            Scottie Barnes  PF      18.5       5.5
# 124  2026-02-19  CHO                Sion James  SG       4.5       2.5
# 125  2026-02-19  SAS            Stephon Castle  PG      15.5       6.5
# 126  2026-02-19  IND            T.J. McConnell  PG       8.5       4.5
# 127  2026-02-19  HOU                Tari Eason  PF      12.5       NaN
# 128  2026-02-19  CHO            Tidjane Salaun  PF       5.5       NaN
# 129  2026-02-19  DEN          Tim Hardaway Jr.  SG      11.5       NaN
# 130  2026-02-19  DET             Tobias Harris  PF      13.5       NaN
# 131  2026-02-19  WAS               Tre Johnson  SG      14.5       NaN
# 132  2026-02-19  PHI           Trendon Watford  PF       8.5       3.5
# 133  2026-02-19  PHI              Tyrese Maxey  PG      30.5       6.5
# 134  2026-02-19  PHI              VJ Edgecombe  SG      16.5       3.5
# 135  2026-02-19  SAS         Victor Wembanyama   C      22.5       2.5
# 136  2026-02-19  ORL        Wendell Carter Jr.   C      10.5       NaN
# 137  2026-02-19  WAS                Will Riley  SF      11.5       NaN
# 138  2026-02-19  ATL        Zaccharie Risacher  SF       8.5       NaN
#
#      REB_line  STL_line  BLK_line  STL_BLK_line  TPM_line  PA_line  PR_line  \
# 0         4.5       NaN       NaN           NaN       2.5     16.5     19.5
# 1         5.5       NaN       NaN           NaN       NaN      NaN     13.5
# 2         4.5       NaN       NaN           NaN       1.5     10.5     13.5
# 3         8.5       1.5       NaN           NaN       NaN     24.5     27.5
# 4         6.5       1.5       NaN           NaN       NaN     21.5     22.5
# 5         2.5       0.5       NaN           NaN       1.5     27.5     22.5
# 6         2.5       NaN       NaN           NaN       2.5      NaN     18.5
# 7         3.5       NaN       NaN           NaN       1.5     22.5     21.5
# 8         5.5       1.5       NaN           NaN       NaN      NaN     14.5
# 9         4.5       NaN       NaN           NaN       1.5      7.5     10.5
# 10        2.5       NaN       NaN           NaN       1.5      NaN      9.5
# 11        4.5       NaN       NaN           NaN       1.5     17.5     19.5
# 12        4.5       1.5       NaN           NaN       NaN      NaN     14.5
# 13        4.5       NaN       NaN           NaN       1.5     16.5     18.5
# 14        5.5       NaN       NaN           NaN       1.5     25.5     27.5
# 15        5.5       1.5       NaN           NaN       2.5     26.5     28.5
# 16        3.5       NaN       1.5           NaN       1.5     10.5     13.5
# 17        3.5       NaN       NaN           NaN       0.5      9.5     11.5
# 18        2.5       NaN       NaN           NaN       2.5     20.5     19.5
# 19        5.5       1.5       NaN           NaN       1.5     34.5     31.5
# 20        3.5       NaN       NaN           NaN       1.5     11.5     13.5
# 21        NaN       NaN       NaN           NaN       NaN      NaN      NaN
# 22        4.5       NaN       NaN           NaN       NaN     12.5     14.5
# 23        4.5       NaN       NaN           NaN       NaN      NaN      8.5
# 24        4.5       1.5       NaN           NaN       2.5     18.5     17.5
# 25        NaN       NaN       NaN           NaN       NaN      NaN     17.5
# 26        2.5       NaN       NaN           NaN       1.5      NaN     11.5
# 27        NaN       NaN       NaN           NaN       0.5      NaN      NaN
# 28        5.5       NaN       NaN           NaN       NaN     12.5     15.5
# 29        9.5       NaN       NaN           NaN       NaN     15.5     22.5
# 30        3.5       1.5       NaN           NaN       1.5     23.5     20.5
# 31        3.5       NaN       NaN           NaN       1.5     16.5     16.5
# 32        2.5       NaN       NaN           NaN       NaN     20.5     19.5
# 33        NaN       NaN       NaN           NaN       NaN     11.5      NaN
# 34        3.5       NaN       NaN           NaN       1.5     10.5     12.5
# 35        4.5       NaN       NaN           NaN       2.5     22.5     20.5
# 36        4.5       0.5       NaN           NaN       2.5     24.5     24.5
# 37        3.5       NaN       NaN           NaN       1.5     32.5     30.5
# 38        4.5       NaN       NaN           NaN       1.5     15.5     15.5
# 39        3.5       NaN       NaN           NaN       1.5      NaN     15.5
# 40        5.5       NaN       NaN           NaN       NaN      NaN     15.5
# 41        3.5       1.5       NaN           NaN       3.5     32.5     31.5
# 42        5.5       NaN       NaN           NaN       1.5     12.5     14.5
# 43        2.5       NaN       NaN           NaN       2.5      NaN     13.5
# 44        3.5       NaN       NaN           NaN       NaN     13.5     13.5
# 45        5.5       1.5       NaN           NaN       NaN     16.5     16.5
# 46        7.5       NaN       1.5           NaN       NaN     17.5     22.5
# 47        3.5       NaN       NaN           NaN       0.5      NaN     10.5
# 48        5.5       NaN       NaN           NaN       1.5      NaN     14.5
# 49        2.5       NaN       NaN           NaN       2.5     17.5     16.5
# 50        5.5       NaN       NaN           NaN       1.5     12.5     15.5
# 51        2.5       NaN       NaN           NaN       1.5      NaN     11.5
# 52        4.5       1.5       NaN           NaN       2.5     22.5     21.5
# 53        2.5       NaN       NaN           NaN       1.5      NaN     10.5
# 54        6.5       NaN       NaN           NaN       1.5      NaN     20.5
# 55        NaN       NaN       NaN           NaN       NaN      NaN      NaN
# 56        6.5       NaN       NaN           NaN       NaN      NaN     15.5
# 57        3.5       NaN       NaN           NaN       2.5     32.5     29.5
# 58        NaN       NaN       NaN           NaN       1.5     16.5      NaN
# 59       10.5       NaN       NaN           NaN       1.5     31.5     33.5
# 60        7.5       NaN       NaN           NaN       1.5      NaN     18.5
# 61        4.5       2.5       NaN           NaN       2.5     21.5     19.5
# 62        3.5       NaN       NaN           NaN       2.5     31.5     27.5
# 63        NaN       NaN       NaN           NaN       0.5     10.5      NaN
# 64        4.5       NaN       NaN           NaN       2.5     28.5     24.5
# 65        6.5       1.5       NaN           NaN       2.5     19.5     23.5
# 66        8.5       NaN       NaN           NaN       NaN      NaN     23.5
# 67        5.5       NaN       2.5           NaN       1.5     14.5     18.5
# 68        6.5       NaN       NaN           NaN       2.5     32.5     34.5
# 69        4.5       NaN       NaN           NaN       1.5      NaN     15.5
# 70        4.5       NaN       NaN           NaN       NaN      NaN     12.5
# 71        5.5       NaN       NaN           NaN       0.5     15.5     19.5
# 72        4.5       NaN       NaN           NaN       NaN      8.5     12.5
# 73        5.5       NaN       NaN           NaN       1.5     11.5     13.5
# 74        5.5       NaN       NaN           NaN       1.5      NaN     18.5
# 75        2.5       NaN       NaN           NaN       NaN      NaN      6.5
# 76        7.5       NaN       NaN           NaN       1.5     16.5     18.5
# 77        3.5       NaN       NaN           NaN       1.5      NaN     10.5
# 78        NaN       NaN       NaN           NaN       1.5      NaN     11.5
# 79        6.5       NaN       NaN           NaN       0.5      NaN     16.5
# 80       11.5       NaN       NaN           NaN       1.5     21.5     29.5
# 81        6.5       1.5       NaN           NaN       2.5     32.5     34.5
# 82        4.5       NaN       NaN           NaN       1.5      NaN     17.5
# 83        4.5       NaN       NaN           NaN       0.5      NaN     16.5
# 84        5.5       1.5       0.5           NaN       1.5      NaN     22.5
# 85        4.5       NaN       NaN           NaN       2.5     29.5     29.5
# 86        5.5       NaN       NaN           NaN       3.5     22.5     24.5
# 87        2.5       NaN       NaN           NaN       1.5     13.5     11.5
# 88        3.5       NaN       NaN           NaN       1.5     13.5     16.5
# 89        5.5       NaN       NaN           NaN       1.5     18.5     19.5
# 90        4.5       NaN       NaN           NaN       3.5     27.5     25.5
# 91        NaN       NaN       NaN           NaN       1.5      NaN      NaN
# 92        8.5       NaN       NaN           NaN       NaN      NaN     20.5
# 93        4.5       NaN       1.5           NaN       2.5      NaN     19.5
# 94        9.5       NaN       NaN           NaN       NaN      NaN     21.5
# 95        6.5       1.5       NaN           NaN       3.5     27.5     30.5
# 96        3.5       NaN       NaN           NaN       1.5     18.5     18.5
# 97        7.5       NaN       1.5           NaN       NaN      NaN     12.5
# 98        3.5       NaN       NaN           NaN       NaN      NaN     13.5
# 99        3.5       NaN       NaN           NaN       2.5     14.5     16.5
# 100       6.5       NaN       NaN           NaN       NaN      8.5     13.5
# 101       3.5       0.5       NaN           NaN       3.5     23.5     22.5
# 102      12.5       1.5       NaN           NaN       1.5     36.5     38.5
# 103       7.5       NaN       NaN           NaN       1.5     14.5     20.5
# 104       4.5       NaN       NaN           NaN       1.5     14.5     15.5
# 105       4.5       NaN       NaN           NaN       1.5      NaN     16.5
# 106       2.5       NaN       NaN           NaN       0.5     16.5     13.5
# 107       4.5       NaN       NaN           NaN       1.5     16.5     19.5
# 108       7.5       0.5       NaN           NaN       1.5     17.5     22.5
# 109       4.5       NaN       NaN           NaN       NaN      NaN     10.5
# 110       8.5       NaN       NaN           NaN       1.5     28.5     31.5
# 111       4.5       NaN       NaN           NaN       1.5     17.5     15.5
# 112       8.5       1.5       1.5           NaN       NaN      NaN     21.5
# 113       3.5       NaN       NaN           NaN       2.5     22.5     20.5
# 114       5.5       NaN       NaN           NaN       NaN      NaN     12.5
# 115       3.5       NaN       NaN           NaN       1.5     15.5     15.5
# 116       4.5       NaN       NaN           NaN       1.5     22.5     23.5
# 117       NaN       1.5       NaN           NaN       2.5     14.5      NaN
# 118       4.5       NaN       NaN           NaN       2.5     13.5     14.5
# 119       5.5       NaN       NaN           NaN       1.5     20.5     19.5
# 120       6.5       NaN       1.5           NaN       NaN      NaN     14.5
# 121       3.5       NaN       NaN           NaN       2.5     10.5     13.5
# 122       NaN       NaN       NaN           NaN       2.5      NaN     13.5
# 123       7.5       NaN       1.5           NaN       NaN     23.5     26.5
# 124       3.5       NaN       NaN           NaN       NaN      7.5      8.5
# 125       4.5       NaN       NaN           NaN       NaN     22.5     20.5
# 126       NaN       NaN       NaN           NaN       NaN     13.5      NaN
# 127       5.5       1.5       NaN           NaN       1.5      NaN     18.5
# 128       3.5       NaN       NaN           NaN       NaN      NaN      9.5
# 129       2.5       NaN       NaN           NaN       2.5      NaN     14.5
# 130       5.5       NaN       NaN           NaN       1.5      NaN     19.5
# 131       2.5       NaN       NaN           NaN       1.5     16.5     17.5
# 132       3.5       NaN       NaN           NaN       NaN     11.5     12.5
# 133       3.5       1.5       0.5           NaN       3.5     37.5     34.5
# 134       5.5       NaN       NaN           NaN       1.5     20.5     22.5
# 135      11.5       0.5       2.5           3.5       1.5     25.5     34.5
# 136       7.5       0.5       NaN           NaN       0.5      NaN     17.5
# 137       3.5       NaN       NaN           NaN       1.5      NaN      NaN
# 138       3.5       NaN       NaN           NaN       1.5      NaN     12.5
#
#      RA_line  PRA_line  Spread  Total
# 0        6.5      21.5    -2.5  232.5
# 1        NaN       NaN    -1.5  240.5
# 2        7.5      15.5     6.5  212.5
# 3       14.5      33.5    -4.5  217.5
# 4       11.5      27.5    -4.5  217.5
# 5       11.5      30.5    -2.5  232.5
# 6        NaN       NaN     6.5  233.5
# 7        8.5      26.5    -8.5  226.5
# 8        NaN      16.5     4.5  219.5
# 9        6.5      12.5    -6.5  212.5
# 10       NaN       NaN    -2.5  232.5
# 11       6.5      22.5     4.5  225.5
# 12       NaN      17.5     2.5  232.5
# 13       8.5      22.5     6.5  212.5
# 14       9.5      31.5    -6.5  233.5
# 15       8.5      31.5     4.5  217.5
# 16       5.5      14.5     4.5  225.5
# 17       5.5      13.5    -4.5  225.5
# 18       6.5      23.5     1.5  240.5
# 19      14.5      40.5     4.5  219.5
# 20       5.5      15.5    -4.5  225.5
# 21       NaN       NaN     4.5  219.5
# 22       6.5      17.5    -4.5  225.5
# 23       NaN       NaN    -4.5  217.5
# 24       9.5      22.5     8.5  230.5
# 25       NaN       NaN     6.5  233.5
# 26       NaN       NaN     1.5  240.5
# 27       NaN       NaN     4.5  219.5
# 28       7.5      18.5    15.5  229.5
# 29      13.5      25.5    15.5  229.5
# 30       9.5      26.5    -8.5  230.5
# 31       5.5      19.5     6.5  212.5
# 32       5.5      22.5     8.5  226.5
# 33       NaN      13.5   -15.5  229.5
# 34       4.5      13.5     4.5  225.5
# 35       9.5      26.5    -6.5  212.5
# 36       8.5      29.5    -8.5  226.5
# 37      10.5      36.5     8.5  230.5
# 38       8.5      19.5     8.5  226.5
# 39       NaN      17.5    -8.5  230.5
# 40       NaN       NaN    -1.5  240.5
# 41       9.5      37.5   -15.5  229.5
# 42      10.5      18.5     6.5  212.5
# 43       NaN       NaN     4.5  219.5
# 44       6.5      17.5    -8.5  230.5
# 45      11.5      22.5     1.5  240.5
# 46      10.5      25.5   -15.5  229.5
# 47       NaN       NaN     6.5  212.5
# 48       NaN      17.5     4.5  217.5
# 49       6.5      20.5     8.5  230.5
# 50       8.5      18.5     6.5  212.5
# 51       NaN       NaN    -8.5  230.5
# 52       9.5      26.5    -6.5  233.5
# 53       NaN       NaN     6.5  233.5
# 54       NaN       NaN    -4.5  217.5
# 55       NaN       NaN     6.5  233.5
# 56       NaN       NaN    -6.5  233.5
# 57       8.5      35.5    -4.5  219.5
# 58       NaN      19.5     8.5  230.5
# 59      19.5      42.5     1.5  240.5
# 60       NaN       NaN     6.5  233.5
# 61      10.5      25.5    -8.5  226.5
# 62      11.5      35.5    -4.5  225.5
# 63       NaN       NaN    -6.5  233.5
# 64      12.5      33.5   -15.5  229.5
# 65       9.5      26.5    -2.5  232.5
# 66       NaN       NaN   -15.5  229.5
# 67       NaN       NaN    -2.5  232.5
# 68      10.5      39.5    -6.5  212.5
# 69       NaN       NaN   -15.5  229.5
# 70       NaN       NaN     1.5  240.5
# 71       7.5      21.5     4.5  225.5
# 72       6.5      13.5    -4.5  225.5
# 73       NaN      16.5     8.5  230.5
# 74       NaN       NaN     6.5  233.5
# 75       NaN       NaN     4.5  217.5
# 76      12.5      23.5    -4.5  219.5
# 77       NaN       NaN    -8.5  230.5
# 78       NaN       NaN    -4.5  225.5
# 79       NaN      18.5     2.5  232.5
# 80      13.5      32.5    -4.5  219.5
# 81      11.5      39.5     4.5  225.5
# 82       NaN      18.5     8.5  226.5
# 83       NaN       NaN    -8.5  230.5
# 84       NaN       NaN    -1.5  240.5
# 85       9.5      34.5    -4.5  217.5
# 86       9.5      28.5     4.5  217.5
# 87       7.5      16.5     4.5  225.5
# 88       5.5      17.5     6.5  212.5
# 89       9.5      23.5     2.5  232.5
# 90      11.5      32.5     4.5  217.5
# 91       NaN       NaN    -4.5  219.5
# 92       NaN       NaN     8.5  230.5
# 93       NaN       NaN     6.5  233.5
# 94       NaN      23.5     8.5  226.5
# 95       9.5      33.5    15.5  229.5
# 96       6.5      21.5    -4.5  219.5
# 97       NaN       NaN    -4.5  219.5
# 98       NaN       NaN    -8.5  226.5
# 99       4.5      17.5     6.5  212.5
# 100      7.5      14.5    -6.5  212.5
# 101      7.5      26.5     1.5  240.5
# 102     22.5      49.5    -4.5  225.5
# 103     10.5      22.5    -6.5  212.5
# 104      7.5      19.5     8.5  226.5
# 105      NaN       NaN    15.5  229.5
# 106      7.5      18.5    15.5  229.5
# 107      NaN      21.5    -4.5  219.5
# 108     10.5      25.5     1.5  240.5
# 109      NaN       NaN     8.5  230.5
# 110     13.5      37.5    -8.5  226.5
# 111      9.5      21.5     6.5  212.5
# 112      NaN      24.5     4.5  219.5
# 113      8.5      26.5    -6.5  212.5
# 114      NaN       NaN     8.5  226.5
# 115      6.5      19.5    -1.5  240.5
# 116      8.5      27.5    -6.5  233.5
# 117      NaN      16.5    -4.5  217.5
# 118      7.5      17.5     8.5  230.5
# 119     11.5      26.5     8.5  226.5
# 120      NaN       NaN     4.5  217.5
# 121      4.5      14.5    -6.5  212.5
# 122      NaN       NaN   -15.5  229.5
# 123     13.5      31.5    -6.5  233.5
# 124      5.5      10.5     4.5  217.5
# 125     11.5      27.5    -8.5  230.5
# 126      NaN      15.5    -2.5  232.5
# 127      NaN       NaN    -4.5  217.5
# 128      NaN       NaN     4.5  217.5
# 129      NaN       NaN    -4.5  225.5
# 130      NaN      21.5     4.5  219.5
# 131      5.5      19.5     2.5  232.5
# 132      7.5      15.5    -1.5  240.5
# 133     10.5      42.5    -1.5  240.5
# 134      9.5      26.5    -1.5  240.5
# 135     14.5      37.5    -8.5  230.5
# 136      NaN      19.5    -8.5  226.5
# 137      NaN       NaN     2.5  232.5
# 138      NaN       NaN     1.5  240.5

# %% [markdown]
# # Get Starting Lineups

# %%
def read_page(date=""):
    if date != "":
        date = f"?date={date}"
    url = f"https://fantasydata.com/nba/starting-lineups{date}"
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Accept-Language": "en-US,en;q=0.9"
    }

    resp = requests.get(url, headers=headers)
    resp.raise_for_status()

    html = resp.text
    
    return html

# %%
def extract_starters(team_div):
    """
    Extract starters from a team div (away/home),
    stopping at the Injuries section.
    """
    starters = []
    collecting = False

    for row in team_div.select(":scope > div.text-nowrap"):
        strong = row.find("strong")

        if strong:
            label = strong.get_text(strip=True)
            if label == "Starters":
                collecting = True
                continue
            if label == "Injuries":
                break

        if collecting:
            a = row.find("a")
            if not a:
                continue

            name = a.get_text(strip=True)
            href = a.get("href")

            # player ID is last number in URL
            player_id = href.rstrip("/").split("/")[-1]

            # position is plain text after name
            text = row.get_text(" ", strip=True)
            position = text.replace(name, "").strip()

            starters.append({
                "player_name": name,
                "player_id": player_id,
                "position": position
            })

    return starters

# %%
def parse_lineups(html):
    time.sleep(6)
    soup = BeautifulSoup(html, "lxml")
    games_data = []

    for game in soup.select("div.game"):
        # --- Game info ---
        info_div = game.select_one("div.header div.info > div")
        lines = list(info_div.stripped_strings)

        matchup = lines[0]
        game_time = lines[1]

        away_team, home_team = [t.strip() for t in matchup.split("@")]

        # --- Lineups ---
        away_div = game.select_one("div.away")
        home_div = game.select_one("div.home")

        away_starters = extract_starters(away_div)
        home_starters = extract_starters(home_div)

        for p in away_starters:
            games_data.append({
                "team_side": "away",
                "team": away_team,
                "opponent": home_team,
                "game_time": game_time,
                **p
            })

        for p in home_starters:
            games_data.append({
                "team_side": "home",
                "team": home_team,
                "opponent": away_team,
                "game_time": game_time,
                **p
            })

    return pd.DataFrame(games_data)

# %% [markdown]
# # Other functions

# %%
def email(error):
    
    # Email details
    sender_email = "rodolfoe7157@gmail.com"
    receiver_email = "rodolfoe7157@gmail.com"
    password = "cqgu bfey cnyx sfue"  # See note below

    subject = "NBA Starting Lineups error"
    body = f"ERROR: {error}"

    # Create message
    msg = MIMEMultipart()
    msg['From'] = sender_email
    msg['To'] = receiver_email
    msg['Subject'] = subject
    msg.attach(MIMEText(body, 'plain'))

    # Connect to Gmail SMTP server and send
    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as server:
        server.login(sender_email, password)
        server.send_message(msg)

    print("Email sent successfully!")

# %%
def remove_accents(text):
    if not isinstance(text, str):
        return text
    # Normalize to NFKD (decomposes characters)
    text = unicodedata.normalize('NFKD', text)
    # Encode to ASCII bytes, ignore non-ASCII characters, then decode back to str
    return text.encode('ascii', 'ignore').decode('ascii')

# %% [markdown]
# # Main

# %%
now = str(datetime.now().date() + timedelta(days=-1))
df_teams = pd.read_csv(f"../src/team_info_xref.csv")
df_teams['short_name'] = df_teams.Team.str.split(" ").str[-1]
df_teams['short_name'] = np.where(df_teams.ABV == 'POR', 'Trail Blazers', df_teams.short_name)
df = parse_lineups(read_page(now))
if df.shape[0] > 0:
    df = df.merge(df_teams, left_on=['team'], right_on=['short_name'])
    df = df[['ABV', 'player_name', 'position']].rename(columns={"ABV": "Team", "player_name": "Player", "position": "Pos"})
    df.insert(0, 'Date', pd.to_datetime(now))
    df['Player'] = df['Player'].apply(remove_accents)
    df = remap_plyr_names(df)
    display(df)
    partition_save_df(df, f"../tables/{YEAR}/daily_lineups.csv")
else:
    email(f'Empty lineup for {now}')
# Out:
# Email sent successfully!

# %%
now = str(datetime.now().date())
df_teams = pd.read_csv(f"../src/team_info_xref.csv")
df_teams['short_name'] = df_teams.Team.str.split(" ").str[-1]
df_teams['short_name'] = np.where(df_teams.ABV == 'POR', 'Trail Blazers', df_teams.short_name)
df = parse_lineups(read_page())
if df.shape[0] > 0:
    df = df.merge(df_teams, left_on=['team'], right_on=['short_name'])
    df = df[['ABV', 'player_name', 'position']].rename(columns={"ABV": "Team", "player_name": "Player", "position": "Pos"})
    df.insert(0, 'Date', pd.to_datetime(now))
    df['Player'] = df['Player'].apply(remove_accents)
    df = remap_plyr_names(df)
    display(df)
    partition_save_df(df, f"../tables/{YEAR}/daily_lineups.csv")
else:
    email(f'Empty lineup for {now}')
# Out:
#          Date Team                    Player Pos
# 0  2026-02-19  BRK              Nolan Traore  PG
# 1  2026-02-19  BRK                Egor Demin  PG
# 2  2026-02-19  BRK        Michael Porter Jr.  SF
# 3  2026-02-19  BRK              Noah Clowney  PF
# 4  2026-02-19  BRK            Day'Ron Sharpe   C
# 5  2026-02-19  CLE               Sam Merrill  SG
# 6  2026-02-19  CLE          Donovan Mitchell  SG
# 7  2026-02-19  CLE              James Harden  SG
# 8  2026-02-19  CLE              Jaylon Tyson  SF
# 9  2026-02-19  CLE             Jarrett Allen   C
# 10 2026-02-19  IND           Andrew Nembhard  PG
# 11 2026-02-19  IND              Ben Sheppard  SF
# 12 2026-02-19  IND             Aaron Nesmith  PF
# 13 2026-02-19  IND                Kobe Brown  PF
# 14 2026-02-19  IND                  Jay Huff   C
# 15 2026-02-19  WAS            Bub Carrington  PG
# 16 2026-02-19  WAS         Justin Champagnie  SG
# 17 2026-02-19  WAS           Bilal Coulibaly  SG
# 18 2026-02-19  WAS           Khris Middleton  SF
# 19 2026-02-19  WAS            Kyshawn George  SF
# 20 2026-02-19  ATL             Dyson Daniels  PG
# 21 2026-02-19  ATL  Nickeil Alexander-Walker  SG
# 22 2026-02-19  ATL        Zaccharie Risacher  SF
# 23 2026-02-19  ATL             Jalen Johnson  PF
# 24 2026-02-19  ATL            Onyeka Okongwu   C
# 25 2026-02-19  PHI              Tyrese Maxey  PG
# 26 2026-02-19  PHI              VJ Edgecombe  SG
# 27 2026-02-19  PHI           Kelly Oubre Jr.  SF
# 28 2026-02-19  PHI           Dominick Barlow  PF
# 29 2026-02-19  PHI            Andre Drummond   C
# 30 2026-02-19  HOU             Amen Thompson  SG
# 31 2026-02-19  HOU                Tari Eason  SF
# 32 2026-02-19  HOU          Jabari Smith Jr.  PF
# 33 2026-02-19  HOU              Kevin Durant  PF
# 34 2026-02-19  HOU            Alperen Sengun   C
# 35 2026-02-19  CHO               LaMelo Ball  PG
# 36 2026-02-19  CHO              Kon Knueppel  SG
# 37 2026-02-19  CHO            Brandon Miller  SF
# 38 2026-02-19  CHO            Grant Williams  PF
# 39 2026-02-19  CHO          Ryan Kalkbrenner   C
# 40 2026-02-19  DET           Cade Cunningham  PG
# 41 2026-02-19  DET           Duncan Robinson  SG
# 42 2026-02-19  DET            Ausar Thompson  SG
# 43 2026-02-19  DET             Tobias Harris  SF
# 44 2026-02-19  DET                 Paul Reed  PF
# 45 2026-02-19  NYK             Jalen Brunson  PG
# 46 2026-02-19  NYK                OG Anunoby  SF
# 47 2026-02-19  NYK             Mikal Bridges  SF
# 48 2026-02-19  NYK                 Josh Hart  SF
# 49 2026-02-19  NYK        Karl-Anthony Towns  PF
# 50 2026-02-19  TOR         Immanuel Quickley  PG
# 51 2026-02-19  TOR                RJ Barrett  SG
# 52 2026-02-19  TOR            Scottie Barnes  SF
# 53 2026-02-19  TOR            Brandon Ingram  SF
# 54 2026-02-19  TOR              Jakob Poeltl   C
# 55 2026-02-19  CHI                Coby White  SG
# 56 2026-02-19  CHI                Jaden Ivey  SG
# 57 2026-02-19  CHI           Anfernee Simons  SG
# 58 2026-02-19  CHI             Matas Buzelis  SF
# 59 2026-02-19  CHI               Isaac Okoro  SF
# 60 2026-02-19  PHO              Devin Booker  SG
# 61 2026-02-19  PHO               Jalen Green  SG
# 62 2026-02-19  PHO             Grayson Allen  SF
# 63 2026-02-19  PHO             Royce O'Neale  PF
# 64 2026-02-19  PHO             Mark Williams   C
# 65 2026-02-19  SAS              De'Aaron Fox  PG
# 66 2026-02-19  SAS            Stephon Castle  SG
# 67 2026-02-19  SAS             Devin Vassell  SG
# 68 2026-02-19  SAS         Julian Champagnie  SF
# 69 2026-02-19  SAS         Victor Wembanyama  PF
# 70 2026-02-19  BOS             Derrick White  SG
# 71 2026-02-19  BOS              Jaylen Brown  SG
# 72 2026-02-19  BOS         Baylor Scheierman  SG
# 73 2026-02-19  BOS                Sam Hauser  SF
# 74 2026-02-19  BOS             Neemias Queta   C
# 75 2026-02-19  GSW               Moses Moody  SG
# 76 2026-02-19  GSW               Pat Spencer  SG
# 77 2026-02-19  GSW         De'Anthony Melton  SG
# 78 2026-02-19  GSW            Draymond Green  PF
# 79 2026-02-19  GSW        Kristaps Porzingis   C
# 80 2026-02-19  ORL             Anthony Black  PG
# 81 2026-02-19  ORL               Jalen Suggs  SG
# 82 2026-02-19  ORL              Desmond Bane  SG
# 83 2026-02-19  ORL            Paolo Banchero  PF
# 84 2026-02-19  ORL        Wendell Carter Jr.   C
# 85 2026-02-19  SAC         Russell Westbrook  PG
# 86 2026-02-19  SAC             DeMar DeRozan  SF
# 87 2026-02-19  SAC            Nique Clifford  SF
# 88 2026-02-19  SAC          Precious Achiuwa  PF
# 89 2026-02-19  SAC            Maxime Raynaud   C
# 90 2026-02-19  DEN              Jamal Murray  PG
# 91 2026-02-19  DEN           Christian Braun  SG
# 92 2026-02-19  DEN           Cameron Johnson  PF
# 93 2026-02-19  DEN             Spencer Jones  PF
# 94 2026-02-19  DEN              Nikola Jokic   C
# 95 2026-02-19  LAC                 Kris Dunn  PG
# 96 2026-02-19  LAC             Kawhi Leonard  SF
# 97 2026-02-19  LAC         Derrick Jones Jr.  SF
# 98 2026-02-19  LAC              John Collins  PF
# 99 2026-02-19  LAC               Ivica Zubac   C
# ../tables/2025/daily_lineups.csv saved!
