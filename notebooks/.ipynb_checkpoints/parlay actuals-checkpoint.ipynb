# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings
import duckdb
import os

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
warnings.filterwarnings("ignore")

year = 2025
now = str(datetime.now().date() - timedelta(days=1))
print(f"Today's date:", now)

con = duckdb.connect(database=":memory:")
stats = ['PTS', 'AST', 'REB', 'PR', 'PA', 'RA', 'PRA', 'TPM', 'STL', 'BLK', 'STL_BLK']
# Out:
# Today's date: 2025-12-07

# %%
# %run ./common_utils.ipynb

# %%
def create_actuals_tbl(con):
    df_lines = pd.read_csv(f"../tables/{year}/parlay_lines.csv")
    df_lines['Date'] = pd.to_datetime(df_lines.Date)
    df_lines = df_lines[(df_lines.Date == now)]
    df_log = pd.read_csv(f"../tables/{year}/season_gamelogs.csv")
    df_log['Date'] = pd.to_datetime(df_log.Date)
    df_log = df_log[(df_log.Date == now)]
    df_log = df_log.rename(columns={"TRB": "REB", "3PM": "TPM", "3PA": "TPA"})
    df_log['PR'] = df_log.PTS + df_log.REB 
    df_log['PA'] = df_log.PTS + df_log.AST
    df_log['RA'] = df_log.REB + df_log.AST
    df_log['PRA'] = df_log.PTS + df_log.REB + df_log.AST
    df_log['STL_BLK'] = df_log.STL + df_log.BLK
    df = con.execute("""SELECT t2.*, t1.* EXCLUDE(Date, Team, Player, Pos) FROM df_log t1 JOIN df_lines t2 
                        ON t1.Team = t2.Team AND t1.Player = t2.Player""").fetchdf()
    cols = []
    for stat in stats:
        df[f'{stat}_Result'] = np.where(df[stat] > df[f'{stat}_line'], 'O', 'U')
        df[f'{stat}_Result'] = np.where(df[f'{stat}_line'].isnull(), np.nan, df[f'{stat}_Result'])
        df[f'{stat}_Diff'] = df[stat] - df[f'{stat}_line']
        cols.append(stat)
        cols.append(f'{stat}_line')
        cols.append(f'{stat}_Diff')
        cols.append(f'{stat}_Result')
    df = df[['game_id', 'Date', 'Team', 'Player', 'Pos', 'MP'] + cols]
    
    df_stats = pd.read_csv(f"../tables/{year}/parlay_stats.csv")
    df_stats['Date'] = pd.to_datetime(df_stats.Date).astype(str)
    lines = []
    diffs = []
    stats_cols = []
    
    for stat in stats:
        lines.append(f'{stat}_line')
        diffs.append(f'{stat}_Diff')
    for stat in stats:
        stats_cols.extend([
            f"Off_{stat}",
            f"Off_L5_{stat}",
            f"AVG_{stat}_H2H",
            f"Def_{stat}",
            f"Def_L5_{stat}",
            f"df_stats.{stat}_line",
            f"{stat}",
            f"df.{stat}_Diff",
            f"{stat}_Result",
            f"{stat}_P_Diff",
            f"{stat}_Hit_Pct"
        ])
    df_select = ", ".join(stats_cols)
    lines = str(lines).replace("[", "").replace("]", "")
    diffs = str(diffs).replace("[", "").replace("]", "")
    df_actuals = con.execute(f"""SELECT game_id, df.Date, df.Team, B2B, Spread, Total, df.Player, df.Pos, MP, Opp,
                                 {df_select} FROM df JOIN df_stats 
                                 ON df.Date = df_stats.Date AND df.Player = df_stats.Player
                                 """).fetchdf()
    partition_save_df(df_actuals, f"../tables/{year}/parlay_actuals.csv")
    display(df_actuals)

    return df_actuals
                      
df = create_actuals_tbl(con)
# Out:
# ../tables/2025/parlay_actuals.csv saved!
#              game_id       Date Team  B2B  Spread  Total             Player  \
# 0   20251206_ATL_WAS 2025-12-06  ATL    1    -9.5  237.5         Vit Krejci
# 1   20251206_LAC_MIN 2025-12-06  MIN    1    -8.5  227.5        Mike Conley
# 2   20251206_SAC_MIA 2025-12-06  SAC    0     8.5  242.5  Russell Westbrook
# 3   20251206_MIL_DET 2025-12-06  DET    1   -12.5  223.5    Cade Cunningham
# 4   20251206_SAC_MIA 2025-12-06  MIA    0    -8.5  242.5    Davion Mitchell
# ..               ...        ...  ...  ...     ...    ...                ...
# 79  20251206_LAC_MIN 2025-12-06  MIN    1    -8.5  227.5        Rudy Gobert
# 80  20251206_LAC_MIN 2025-12-06  MIN    1    -8.5  227.5           Naz Reid
# 81  20251206_MIL_DET 2025-12-06  MIL    1    12.5  223.5       Myles Turner
# 82  20251206_MIL_DET 2025-12-06  MIL    1    12.5  223.5       Jericho Sims
# 83  20251206_GSW_CLE 2025-12-06  GSW    0     8.5  229.5         Gui Santos
#
#    Pos     MP  Opp    Off_PTS  Off_L5_PTS  AVG_PTS_H2H    Def_PTS  Def_L5_PTS  \
# 0   PG  30.67  WAS  10.950000         8.4     7.250000  23.312500        23.4
# 1   PG  18.00  LAC   5.809524         4.0     9.857143  22.277778        22.8
# 2   PG  31.77  MIA  13.500000        11.4     7.500000  22.176471        22.4
# 3   PG  31.67  MIL  27.700000        26.4    24.750000  22.000000        19.4
# 4   PG   0.00  SAC   9.739130         7.8          NaN  21.785714        22.6
# ..  ..    ...  ...        ...         ...          ...        ...         ...
# 79   C  32.70  LAC  11.272727        13.2    10.857143  16.000000        13.2
# 80   C  27.88  LAC  13.545455        14.8     8.285714  16.000000        13.2
# 81   C  25.13  DET  12.666667        11.4    16.600000  15.250000        13.2
# 82   C  30.58  DET   3.769231         5.6     3.428571  15.250000        13.2
# 83  PF  26.50  CLE        NaN         NaN          NaN        NaN         NaN
#
#     PTS_line  PTS  PTS_Diff PTS_Result  PTS_P_Diff  PTS_Hit_Pct   Off_AST  \
# 0        8.5   14       5.5          O         2.5     0.428571  1.950000
# 1        4.5    5       0.5          O        -7.0     0.250000  3.550000
# 2       13.5   12      -1.5          U       -13.0     0.333333  6.863636
# 3       26.5   23      -3.5          U        -7.5     0.571429  9.150000
# 4        9.5    0      -9.5          U         9.5     0.666667  7.782609
# ..       ...  ...       ...        ...         ...          ...       ...
# 79       9.5    4      -5.5          U        18.5     0.800000  2.210526
# 80      13.5   19       5.5          O         8.5     0.800000  2.476190
# 81      12.5   12      -0.5          U       -14.5     0.142857  1.954545
# 82       4.5    2      -2.5          U         NaN          NaN  1.714286
# 83       NaN   14       NaN       None         NaN          NaN       NaN
#
#     Off_L5_AST  AVG_AST_H2H   Def_AST  Def_L5_AST  AST_line  AST  AST_Diff  \
# 0          1.6     2.500000  7.625000         7.0       2.5    2      -0.5
# 1          2.4     4.000000  6.111111         7.8       2.5    0      -2.5
# 2          8.0     5.500000  6.941176         5.2       7.5   10       2.5
# 3          8.6     7.500000  6.400000         7.0       8.5   12       3.5
# 4          9.4          NaN  6.857143         5.6       8.5    0      -8.5
# ..         ...          ...       ...         ...       ...  ...       ...
# 79         2.6     2.428571  2.555556         2.4       1.5    2       0.5
# 80         4.0     1.714286  2.555556         2.4       2.5    3       0.5
# 81         1.8     2.000000  2.375000         2.0       1.5    0      -1.5
# 82         1.8     1.000000  2.375000         2.0       1.5    1      -0.5
# 83         NaN          NaN       NaN         NaN       NaN    3       NaN
#
#    AST_Result  AST_P_Diff  AST_Hit_Pct    Off_REB  Off_L5_REB  AVG_REB_H2H  \
# 0           U        -0.5     0.600000   2.350000         2.8     2.250000
# 1           U         1.5     0.666667   2.000000         1.8     3.571429
# 2           O        11.0     0.666667   7.333333         7.4     2.250000
# 3           O        -4.5     0.428571   6.400000         7.2     5.250000
# 4           U         5.5     0.333333   3.000000         2.2          NaN
# ..        ...         ...          ...        ...         ...          ...
# 79          O         1.5     0.666667  10.318182        10.6    13.571429
# 80          O         3.0     0.500000   5.727273         5.4     5.857143
# 81          U         NaN          NaN   5.875000         2.8     7.000000
# 82          U         NaN          NaN   4.785714         8.0     4.428571
# 83       None         NaN          NaN   2.400000         2.6          NaN
#
#      Def_REB  Def_L5_REB  REB_line  REB  REB_Diff REB_Result  REB_P_Diff  \
# 0   5.062500         5.6       2.5    2      -0.5          U        -0.5
# 1   4.333333         5.0       1.5    2       0.5          O         NaN
# 2   6.823529         5.6       7.5    1      -6.5          U         1.0
# 3   5.350000         4.8       6.5    6      -0.5          U        13.5
# 4   4.357143         4.8       2.5    0      -2.5          U        -6.5
# ..       ...         ...       ...  ...       ...        ...         ...
# 79  9.000000         7.8      10.5    7      -3.5          U         4.5
# 80  9.000000         7.8       5.5    9       3.5          O        -1.5
# 81  9.562500        11.0       5.5    1      -4.5          U        -8.5
# 82  9.562500        11.0       6.5    3      -3.5          U         NaN
# 83  8.294118         5.4       3.5    3      -0.5          U         NaN
#
#     REB_Hit_Pct     Off_PR  Off_L5_PR  AVG_PR_H2H     Def_PR  Def_L5_PR  \
# 0      0.600000  12.666667       11.2    9.500000  28.375000       29.0
# 1           NaN   7.363636        5.4   13.428571  26.611111       27.8
# 2      0.333333  20.500000       18.8    9.750000  29.000000       28.0
# 3      0.714286  34.100000       33.6   30.000000  27.350000       24.2
# 4      0.222222        NaN        NaN         NaN        NaN        NaN
# ..          ...        ...        ...         ...        ...        ...
# 79     0.800000  21.590909       23.8   24.428571  25.000000       21.0
# 80     0.400000  19.272727       20.2   14.142857  25.000000       21.0
# 81     0.285714  18.541667       14.2   23.600000  24.812500       24.2
# 82          NaN   7.250000       13.6    7.857143  24.812500       24.2
# 83          NaN        NaN        NaN         NaN        NaN        NaN
#
#     PR_line  PR  PR_Diff PR_Result  PR_P_Diff  PR_Hit_Pct     Off_PA  \
# 0      11.5  16      4.5         O       10.5    0.600000  12.285714
# 1       5.5   7      1.5         O        NaN         NaN   8.772727
# 2      20.5  13     -7.5         U      -13.0    0.333333  20.363636
# 3      33.5  29     -4.5         U        4.5    0.428571  36.850000
# 4       NaN   0      NaN      None        NaN         NaN  17.521739
# ..      ...  ..      ...       ...        ...         ...        ...
# 79     19.5  11     -8.5         U       20.5    0.800000  13.181818
# 80     19.5  28      8.5         O        4.5    0.800000  15.909091
# 81     18.5  13     -5.5         U      -23.5    0.428571  14.458333
# 82     11.5   5     -6.5         U        NaN         NaN        NaN
# 83      NaN  17      NaN      None        NaN         NaN        NaN
#
#     Off_L5_PA  AVG_PA_H2H     Def_PA  Def_L5_PA  PA_line  PA  PA_Diff  \
# 0        10.0    9.750000  30.937500       30.4     11.5  16      4.5
# 1         6.4   13.857143  28.388889       30.6      6.5   5     -1.5
# 2        19.4   13.000000  29.117647       27.6     20.5  22      1.5
# 3        35.0   32.250000  28.400000       26.4     35.5  35     -0.5
# 4        17.2         NaN  28.642857       28.2     17.5   0    -17.5
# ..        ...         ...        ...        ...      ...  ..      ...
# 79       15.8   13.285714  18.555556       15.6     11.5   6     -5.5
# 80       18.8   10.000000  18.555556       15.6     16.5  22      5.5
# 81       13.2   18.600000  17.625000       15.2     14.5  12     -2.5
# 82        NaN         NaN        NaN        NaN      NaN   3      NaN
# 83        NaN         NaN        NaN        NaN      NaN  17      NaN
#
#    PA_Result  PA_P_Diff  PA_Hit_Pct     Off_RA  Off_L5_RA  AVG_RA_H2H  \
# 0          O       11.5    0.600000   4.095238        4.4    4.750000
# 1          U       -3.5    0.333333        NaN        NaN         NaN
# 2          O       -2.0    0.500000  13.863636       15.4    7.750000
# 3          U      -12.5    0.428571  15.550000       15.8   12.750000
# 4          U       12.5    0.777778        NaN        NaN         NaN
# ..       ...        ...         ...        ...        ...         ...
# 79         U        4.0    0.500000  12.227273       13.2   16.000000
# 80         O        6.0    0.500000   8.090909        9.4    7.571429
# 81         U        4.0    0.500000   7.666667        4.6    9.000000
# 82      None        NaN         NaN   5.642857        9.0    5.428571
# 83      None        NaN         NaN        NaN        NaN         NaN
#
#        Def_RA  Def_L5_RA  RA_line  RA  RA_Diff RA_Result  RA_P_Diff  \
# 0   12.687500       12.6      4.5   4     -0.5         U       -3.0
# 1         NaN        NaN      NaN   2      NaN      None        NaN
# 2   13.764706       10.8     14.5  11     -3.5         U       10.0
# 3   11.750000       11.8     14.5  18      3.5         O        8.5
# 4         NaN        NaN      NaN   0      NaN      None        NaN
# ..        ...        ...      ...  ..      ...       ...        ...
# 79  11.555556       10.2     11.5   9     -2.5         U        NaN
# 80  11.555556       10.2      8.5  12      3.5         O        0.0
# 81  11.937500       13.0      7.5   1     -6.5         U       -3.5
# 82  11.937500       13.0      8.5   4     -4.5         U        NaN
# 83        NaN        NaN      NaN   6      NaN      None        NaN
#
#     RA_Hit_Pct    Off_PRA  Off_L5_PRA  AVG_PRA_H2H    Def_PRA  Def_L5_PRA  \
# 0     0.500000  14.523810        12.8    12.000000  36.000000        36.0
# 1          NaN  10.590909         7.8    17.428571  32.722222        35.6
# 2     0.500000  27.363636        26.8    15.250000  35.941176        33.2
# 3     0.571429  43.250000        42.2    37.500000  33.750000        31.2
# 4          NaN  20.260870        19.4          NaN  33.000000        33.0
# ..         ...        ...         ...          ...        ...         ...
# 79         NaN  23.500000        26.4    26.857143  27.555556        23.4
# 80    0.500000  21.636364        24.2    15.857143  27.555556        23.4
# 81    0.333333  20.333333        16.0    25.600000  27.187500        26.2
# 82         NaN   8.000000        14.6     8.857143  27.187500        26.2
# 83         NaN        NaN         NaN          NaN        NaN         NaN
#
#     PRA_line  PRA  PRA_Diff PRA_Result  PRA_P_Diff  PRA_Hit_Pct   Off_TPM  \
# 0       14.5   18       3.5          O         9.5     0.600000  2.947368
# 1        8.5    7      -1.5          U         NaN          NaN  1.388889
# 2       28.5   23      -5.5          U        -3.0     0.333333  2.263158
# 3       41.5   41      -0.5          U        -0.5     0.285714  2.055556
# 4       20.5    0     -20.5          U         2.5     0.333333  1.642857
# ..       ...  ...       ...        ...         ...          ...       ...
# 79      21.5   13      -8.5          U         NaN          NaN       NaN
# 80      21.5   31       9.5          O         3.0     0.750000  2.333333
# 81      20.5   13      -7.5          U       -12.5     0.200000  2.391304
# 82      12.5    6      -6.5          U         NaN          NaN       NaN
# 83       NaN   20       NaN       None         NaN          NaN       NaN
#
#     Off_L5_TPM  AVG_TPM_H2H   Def_TPM  Def_L5_TPM  TPM_line  TPM  TPM_Diff  \
# 0          2.2     1.750000  2.625000         3.4       2.5    4       1.5
# 1          1.2     2.000000  2.944444         2.4       0.5    1       0.5
# 2          2.0     1.500000  2.470588         1.8       1.5    1      -0.5
# 3          2.4     2.125000  2.100000         1.6       1.5    3       1.5
# 4          2.0          NaN  1.928571         2.6       0.5    0      -0.5
# ..         ...          ...       ...         ...       ...  ...       ...
# 79         NaN          NaN       NaN         NaN       NaN    0       NaN
# 80         3.0     0.714286  1.111111         1.2       2.5    5       2.5
# 81         2.0     2.100000  1.625000         1.0       2.5    3       0.5
# 82         NaN          NaN       NaN         NaN       NaN    0       NaN
# 83         NaN          NaN       NaN         NaN       NaN    2       NaN
#
#    TPM_Result  TPM_P_Diff  TPM_Hit_Pct   Off_STL  Off_L5_STL  AVG_STL_H2H  \
# 0           O         5.5     0.428571       NaN         NaN          NaN
# 1           O         NaN          NaN       NaN         NaN          NaN
# 2           U         0.0     0.666667  1.800000         2.0         0.75
# 3           O        -2.5     0.428571  2.214286         2.6         0.75
# 4           U        -2.0     0.125000  1.812500         1.8          NaN
# ..        ...         ...          ...       ...         ...          ...
# 79       None         NaN          NaN       NaN         NaN          NaN
# 80          O         0.5     0.600000       NaN         NaN          NaN
# 81          O        -0.5     0.571429       NaN         NaN          NaN
# 82       None         NaN          NaN       NaN         NaN          NaN
# 83       None         NaN          NaN       NaN         NaN          NaN
#
#      Def_STL  Def_L5_STL  STL_line  STL  STL_Diff STL_Result  STL_P_Diff  \
# 0        NaN         NaN       NaN    3       NaN       None         NaN
# 1        NaN         NaN       NaN    1       NaN       None         NaN
# 2   1.941176         1.4       1.5    4       2.5          O         2.5
# 3   1.550000         1.6       1.5    0      -1.5          U         3.5
# 4   1.000000         1.2       1.5    0      -1.5          U         0.5
# ..       ...         ...       ...  ...       ...        ...         ...
# 79       NaN         NaN       NaN    0       NaN       None         NaN
# 80       NaN         NaN       NaN    0       NaN       None         NaN
# 81       NaN         NaN       NaN    1       NaN       None         NaN
# 82       NaN         NaN       NaN    1       NaN       None         NaN
# 83       NaN         NaN       NaN    0       NaN       None         NaN
#
#     STL_Hit_Pct   Off_BLK  Off_L5_BLK  AVG_BLK_H2H   Def_BLK  Def_L5_BLK  \
# 0           NaN       NaN         NaN          NaN       NaN         NaN
# 1           NaN       NaN         NaN          NaN       NaN         NaN
# 2      0.666667       NaN         NaN          NaN       NaN         NaN
# 3      0.428571  1.454545         1.4     0.750000  0.450000         0.4
# 4      0.666667       NaN         NaN          NaN       NaN         NaN
# ..          ...       ...         ...          ...       ...         ...
# 79          NaN  1.833333         1.6     2.285714  1.055556         1.0
# 80          NaN       NaN         NaN          NaN       NaN         NaN
# 81          NaN  1.904762         1.4     2.300000  1.312500         2.0
# 82          NaN       NaN         NaN          NaN       NaN         NaN
# 83          NaN       NaN         NaN          NaN       NaN         NaN
#
#     BLK_line  BLK  BLK_Diff BLK_Result  BLK_P_Diff  BLK_Hit_Pct  Off_STL_BLK  \
# 0        NaN    1       NaN       None         NaN          NaN          NaN
# 1        NaN    0       NaN       None         NaN          NaN          NaN
# 2        NaN    0       NaN       None         NaN          NaN          NaN
# 3        0.5    1       0.5          O         2.5     0.600000     2.611111
# 4        NaN    0       NaN       None         NaN          NaN          NaN
# ..       ...  ...       ...        ...         ...          ...          ...
# 79       1.5    1      -0.5          U        -2.5     0.200000          NaN
# 80       NaN    0       NaN       None         NaN          NaN          NaN
# 81       1.5    1      -0.5          U         0.5     0.428571          NaN
# 82       NaN    0       NaN       None         NaN          NaN          NaN
# 83       NaN    1       NaN       None         NaN          NaN          NaN
#
#     Off_L5_STL_BLK  AVG_STL_BLK_H2H  Def_STL_BLK  Def_L5_STL_BLK  \
# 0              NaN              NaN          NaN             NaN
# 1              NaN              NaN          NaN             NaN
# 2              NaN              NaN          NaN             NaN
# 3              3.8              1.5          2.0             2.0
# 4              NaN              NaN          NaN             NaN
# ..             ...              ...          ...             ...
# 79             NaN              NaN          NaN             NaN
# 80             NaN              NaN          NaN             NaN
# 81             NaN              NaN          NaN             NaN
# 82             NaN              NaN          NaN             NaN
# 83             NaN              NaN          NaN             NaN
#
#     STL_BLK_line  STL_BLK  STL_BLK_Diff STL_BLK_Result  STL_BLK_P_Diff  \
# 0            NaN        4           NaN           None             NaN
# 1            NaN        1           NaN           None             NaN
# 2            NaN        4           NaN           None             NaN
# 3            1.5        1          -0.5              U             7.5
# 4            NaN        0           NaN           None             NaN
# ..           ...      ...           ...            ...             ...
# 79           NaN        1           NaN           None             NaN
# 80           NaN        0           NaN           None             NaN
# 81           NaN        2           NaN           None             NaN
# 82           NaN        1           NaN           None             NaN
# 83           NaN        1           NaN           None             NaN
#
#     STL_BLK_Hit_Pct
# 0               NaN
# 1               NaN
# 2               NaN
# 3               0.6
# 4               NaN
# ..              ...
# 79              NaN
# 80              NaN
# 81              NaN
# 82              NaN
# 83              NaN
#
# [84 rows x 131 columns]

# %% [markdown]
# # Parlay Performances

# %%
for stat in ['PTS', 'AST', 'REB', 'PR', 'PA', 'RA', 'PRA']:
    print(f"==={stat}===")
    display(con.execute(f"""SELECT game_id, Date, Team, B2B, Spread, Total, Player, Pos, MP, Opp, 
                            Off_{stat}, Off_L5_{stat}, AVG_{stat}_H2H, 
                            Def_{stat}, Def_L5_{stat}, {stat}_line, {stat}, 
                            {stat}_Diff, {stat}_Result FROM df
                            WHERE {stat}_line IS NOT NULL AND {stat}_Result = 'O'
                            ORDER BY {stat}_Diff DESC
                            LIMIT 15""").fetchdf())
# Out:
# ===PTS===
#              game_id       Date Team  B2B  Spread  Total              Player  \
# 0   20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5    Kevin Porter Jr.
# 1   20251201_CHI_ORL 2025-12-01  ORL    0    -9.5  239.5        Desmond Bane
# 2   20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5        Jaylon Tyson
# 3   20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5    Collin Gillespie
# 4   20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5    Donovan Mitchell
# 5   20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5       Kawhi Leonard
# 6   20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5       Dillon Brooks
# 7   20251201_DAL_DEN 2025-12-01  DAL    0    11.5  235.5       Anthony Davis
# 8   20251201_CHO_BRK 2025-12-01  BRK    0     4.5  229.5  Michael Porter Jr.
# 9   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5         Bam Adebayo
# 10  20251201_HOU_UTA 2025-12-01  UTA    1    11.5  233.5        Jusuf Nurkic
# 11  20251201_HOU_UTA 2025-12-01  UTA    1    11.5  233.5      Keyonte George
# 12  20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5       Norman Powell
# 13  20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5      Alperen Sengun
# 14  20251201_MIL_WAS 2025-12-01  WAS    0    10.5  231.5         CJ McCollum
#
#    Pos     MP  Opp    Off_PTS  Off_L5_PTS  AVG_PTS_H2H    Def_PTS  Def_L5_PTS  \
# 0   PG  31.02  WAS  11.500000        11.5     6.500000  22.833333        20.6
# 1   SG  34.47  CHI  18.300000        22.4          NaN  13.928571        16.2
# 2   SG  30.78  IND  11.500000        12.4     5.600000  16.476190        16.4
# 3   PG  33.83  LAL  12.666667        17.6     0.750000  18.157895        18.8
# 4   SG  34.48  IND  29.947368        29.2    32.800000  16.476190        16.4
# 5   SF  30.40  MIA  25.400000        27.0    20.500000  17.555556        14.4
# 6   SF  32.93  LAL  21.533333        22.6    12.833333  20.600000        19.6
# 7   PF  32.42  DEN  19.333333        18.8    24.333333  16.500000        13.2
# 8   SF  36.05  CHO  24.250000        26.6    15.400000  20.133333        22.8
# 9    C  31.63  LAC  18.857143        17.0    13.200000  16.500000        10.6
# 10   C  24.22  HOU   8.050000         9.4    11.250000  17.250000        18.8
# 11  PG  37.07  HOU  23.526316        28.0    13.125000  16.250000        17.4
# 12  SG  31.90  LAC  24.687500        23.0          NaN  17.000000        20.6
# 13   C  38.15  UTA  21.250000        20.6    27.800000  18.142857        26.4
# 14  SG  35.57  MIL  17.833333        21.8          NaN  17.722222        16.2
#
#     PTS_line  PTS  PTS_Diff PTS_Result
# 0       13.5   30      16.5          O
# 1       21.5   37      15.5          O
# 2       11.5   27      15.5          O
# 3       12.5   28      15.5          O
# 4       29.5   43      13.5          O
# 5       22.5   36      13.5          O
# 6       19.5   33      13.5          O
# 7       20.5   32      11.5          O
# 8       23.5   35      11.5          O
# 9       16.5   27      10.5          O
# 10       8.5   18       9.5          O
# 11      18.5   28       9.5          O
# 12      20.5   30       9.5          O
# 13      21.5   31       9.5          O
# 14      19.5   28       8.5          O
# ===AST===
#              game_id       Date Team  B2B  Spread  Total              Player  \
# 0   20251201_PHO_LAL 2025-12-01  PHO    0    14.5  225.5       Royce O'Neale
# 1   20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5      Alperen Sengun
# 2   20251201_CHO_BRK 2025-12-01  CHO    0    -4.5  229.5         LaMelo Ball
# 3   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5     Davion Mitchell
# 4   20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5    Tim Hardaway Jr.
# 5   20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5         Ayo Dosunmu
# 6   20251201_MIL_WAS 2025-12-01  WAS    0    10.5  231.5     Khris Middleton
# 7   20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5        Nikola Jokic
# 8   20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5        Jamal Murray
# 9   20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5           Kris Dunn
# 10  20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5      Nikola Vucevic
# 11  20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5       Peyton Watson
# 12  20251201_MIL_WAS 2025-12-01  WAS    0    10.5  231.5         CJ McCollum
# 13  20251201_CHO_BRK 2025-12-01  BRK    0     4.5  229.5  Michael Porter Jr.
# 14  20251201_CHO_BRK 2025-12-01  CHO    0    -4.5  229.5        Kon Knueppel
#
#    Pos     MP  Opp    Off_AST  Off_L5_AST  AVG_AST_H2H   Def_AST  Def_L5_AST  \
# 0   SF  33.02  LAL   2.571429         1.6     2.833333  3.466667         2.8
# 1    C  38.15  UTA   6.937500         5.8     5.800000  2.142857         2.4
# 2   PG  29.50  BRK   8.461538         6.6     6.000000  5.615385         4.4
# 3   PG  31.03  LAC   7.550000         8.2     3.142857  5.764706         6.6
# 4   SG  30.50  DAL   1.785714         1.2          NaN  3.750000         3.2
# 5   SG  36.73  ORL   2.941176         2.4     2.428571  3.733333         2.6
# 6   SF  31.42  MIL   3.285714         4.8          NaN  3.333333         3.8
# 7    C  37.00  DAL  10.894737        10.4     9.571429  3.000000         3.6
# 8   PG  26.48  DAL   6.555556         7.6     6.714286  7.400000         6.0
# 9   PG  25.78  MIA   3.000000         2.8     4.600000  7.500000         6.2
# 10   C  34.48  ORL   3.764706         3.2     3.714286  2.125000         2.8
# 11  SF  34.52  DAL   1.941176         2.6     1.428571  3.000000         3.4
# 12  SG  35.57  MIL   3.277778         3.2          NaN  3.611111         4.0
# 13  SF  36.05  CHO   3.428571         4.4     2.400000  4.133333         5.4
# 14  SF  35.10  BRK   2.950000         2.8          NaN  4.000000         4.6
#
#     AST_line  AST  AST_Diff AST_Result
# 0        2.5   11       8.5          O
# 1        6.5   14       7.5          O
# 2        7.5   14       6.5          O
# 3        6.5   12       5.5          O
# 4        1.5    6       4.5          O
# 5        3.5    7       3.5          O
# 6        3.5    6       2.5          O
# 7       10.5   13       2.5          O
# 8        6.5    9       2.5          O
# 9        2.5    5       2.5          O
# 10       2.5    5       2.5          O
# 11       1.5    3       1.5          O
# 12       3.5    5       1.5          O
# 13       2.5    4       1.5          O
# 14       2.5    4       1.5          O
# ===REB===
#              game_id       Date Team  B2B  Spread  Total            Player  \
# 0   20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5      Nikola Jokic
# 1   20251201_CHI_ORL 2025-12-01  ORL    0    -9.5  239.5     Anthony Black
# 2   20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5      Jaylon Tyson
# 3   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5       Bam Adebayo
# 4   20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5      Kevin Durant
# 5   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5    Andrew Wiggins
# 6   20251201_DAL_DEN 2025-12-01  DAL    0    11.5  235.5     Anthony Davis
# 7   20251201_ATL_DET 2025-12-01  ATL    1     9.5  232.5     Jalen Johnson
# 8   20251201_ATL_DET 2025-12-01  DET    1    -9.5  232.5    Isaiah Stewart
# 9   20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5  Donovan Mitchell
# 10  20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5         Ryan Dunn
# 11  20251201_HOU_UTA 2025-12-01  UTA    1    11.5  233.5    Svi Mykhailiuk
# 12  20251201_CHO_BRK 2025-12-01  CHO    0    -4.5  229.5     Collin Sexton
# 13  20251201_CHO_BRK 2025-12-01  BRK    0     4.5  229.5   Ziaire Williams
# 14  20251201_DAL_DEN 2025-12-01  DAL    0    11.5  235.5      Cooper Flagg
#
#    Pos     MP  Opp    Off_REB  Off_L5_REB  AVG_REB_H2H   Def_REB  Def_L5_REB  \
# 0    C  37.00  DAL  12.421053        10.2    14.428571  9.823529        10.0
# 1   PG  33.83  CHI   3.105263         2.6     2.250000  4.647059         5.8
# 2   SG  30.78  IND   4.800000         5.6     1.800000  4.000000         4.4
# 3    C  31.63  LAC   8.500000         9.4     9.000000  9.142857         7.4
# 4   SF  40.33  UTA   4.571429         5.4     6.285714  7.473684         6.0
# 5   SF  32.02  LAC   4.823529         5.0     3.142857  5.550000         5.0
# 6   PF  32.42  DEN   9.333333         8.6    12.888889  5.333333         5.8
# 7   SF  37.68  DET  10.250000        10.4     9.000000  5.000000         7.0
# 8    C  25.07  ATL   6.352941         6.0     6.142857  9.200000         8.0
# 9   SG  34.48  IND   4.789474         5.6     5.900000  4.000000         4.4
# 10  SF  20.58  LAL   4.812500         3.4     2.750000  6.133333         6.0
# 11  SF  26.15  HOU   2.526316         2.2     0.333333  5.058824         5.0
# 12  SG  18.83  BRK   2.666667         2.4     2.000000  3.400000         2.6
# 13  SF  18.97  CHO   2.800000         3.6     2.285714  5.400000         7.8
# 14  PG  33.43  DEN   6.550000         7.2          NaN  4.466667         4.2
#
#     REB_line  REB  REB_Diff REB_Result
# 0       12.5   20       7.5          O
# 1        3.5    9       5.5          O
# 2        5.5   11       5.5          O
# 3        8.5   14       5.5          O
# 4        4.5    9       4.5          O
# 5        4.5    9       4.5          O
# 6        8.5   13       4.5          O
# 7        8.5   13       4.5          O
# 8        5.5   10       4.5          O
# 9        4.5    9       4.5          O
# 10       3.5    8       4.5          O
# 11       2.5    6       3.5          O
# 12       2.5    6       3.5          O
# 13       2.5    6       3.5          O
# 14       5.5    8       2.5          O
# ===PR===
#              game_id       Date Team  B2B  Spread  Total              Player  \
# 0   20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5        Jaylon Tyson
# 1   20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5    Donovan Mitchell
# 2   20251201_CHI_ORL 2025-12-01  ORL    0    -9.5  239.5        Desmond Bane
# 3   20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5    Collin Gillespie
# 4   20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5    Kevin Porter Jr.
# 5   20251201_DAL_DEN 2025-12-01  DAL    0    11.5  235.5       Anthony Davis
# 6   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5         Bam Adebayo
# 7   20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5       Kawhi Leonard
# 8   20251201_CHI_ORL 2025-12-01  ORL    0    -9.5  239.5       Anthony Black
# 9   20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5       Dillon Brooks
# 10  20251201_CHO_BRK 2025-12-01  BRK    0     4.5  229.5  Michael Porter Jr.
# 11  20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5      Andrew Wiggins
# 12  20251201_ATL_DET 2025-12-01  ATL    1     9.5  232.5       Jalen Johnson
# 13  20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5        Kevin Durant
# 14  20251201_HOU_UTA 2025-12-01  UTA    1    11.5  233.5      Keyonte George
#
#    Pos     MP  Opp     Off_PR  Off_L5_PR  AVG_PR_H2H     Def_PR  Def_L5_PR  \
# 0   SG  30.78  IND  16.000000       18.0    7.400000  20.476190       20.8
# 1   SG  34.48  IND  34.736842       34.8   38.700000  20.476190       20.8
# 2   SG  34.47  CHI  22.800000       27.2         NaN  18.214286       20.4
# 3   PG  33.83  LAL  16.476190       20.0    2.500000  21.315789       21.6
# 4   PG  31.02  WAS  13.500000       13.5    8.750000  28.250000       27.4
# 5   PF  32.42  DEN  28.666667       27.4   37.222222  21.833333       19.0
# 6    C  31.63  LAC  27.357143       26.4   22.200000  25.642857       18.0
# 7   SF  30.40  MIA  30.700000       31.6   27.000000  23.111111       19.4
# 8   PG  33.83  CHI  15.950000       19.4    7.750000  26.294118       28.4
# 9   SF  32.93  LAL  24.733333       25.6   16.166667  26.733333       25.6
# 10  SF  36.05  CHO  31.625000       33.2   23.000000  25.533333       30.6
# 11  SF  32.02  LAC  22.058824       21.0   19.428571  24.000000       26.2
# 12  SF  37.68  DET  33.550000       35.0   30.200000  28.933333       31.8
# 13  SF  40.33  UTA  29.285714       30.0   36.857143  24.789474       21.2
# 14  PG  37.07  HOU  26.400000       25.2   16.000000  20.416667       21.0
#
#     PR_line  PR  PR_Diff PR_Result
# 0      17.5  38     20.5         O
# 1      34.5  52     17.5         O
# 2      26.5  43     16.5         O
# 3      15.5  32     16.5         O
# 4      17.5  34     16.5         O
# 5      28.5  45     16.5         O
# 6      25.5  41     15.5         O
# 7      27.5  43     15.5         O
# 8      17.5  31     13.5         O
# 9      22.5  35     12.5         O
# 10     30.5  42     11.5         O
# 11     19.5  31     11.5         O
# 12     31.5  42     10.5         O
# 13     30.5  41     10.5         O
# 14     22.5  32      9.5         O
# ===PA===
#              game_id       Date Team  B2B  Spread  Total              Player  \
# 0   20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5      Alperen Sengun
# 1   20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5    Kevin Porter Jr.
# 2   20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5    Collin Gillespie
# 3   20251201_CHI_ORL 2025-12-01  ORL    0    -9.5  239.5        Desmond Bane
# 4   20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5    Donovan Mitchell
# 5   20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5       Kawhi Leonard
# 6   20251201_CHO_BRK 2025-12-01  BRK    0     4.5  229.5  Michael Porter Jr.
# 7   20251201_DAL_DEN 2025-12-01  DAL    0    11.5  235.5       Anthony Davis
# 8   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5     Davion Mitchell
# 9   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5         Bam Adebayo
# 10  20251201_HOU_UTA 2025-12-01  UTA    1    11.5  233.5      Keyonte George
# 11  20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5       Norman Powell
# 12  20251201_MIL_WAS 2025-12-01  WAS    0    10.5  231.5         CJ McCollum
# 13  20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5        Kevin Durant
# 14  20251201_CHI_ORL 2025-12-01  ORL    0    -9.5  239.5       Anthony Black
#
#    Pos     MP  Opp     Off_PA  Off_L5_PA  AVG_PA_H2H     Def_PA  Def_L5_PA  \
# 0    C  38.15  UTA  28.187500       26.4   33.600000  20.285714       28.8
# 1   PG  31.02  WAS  15.500000       15.5    8.250000  31.000000       28.8
# 2   PG  33.83  LAL  17.619048       22.2    1.500000  24.578947       24.4
# 3   SG  34.47  CHI  22.800000       27.0         NaN  17.285714       20.2
# 4   SG  34.48  IND  35.421053       35.2   37.000000  19.333333       19.2
# 5   SF  30.40  MIA  28.300000       29.4   24.000000  22.055556       19.2
# 6   SF  36.05  CHO  27.250000       29.6   17.800000  24.266667       28.2
# 7   PF  32.42  DEN  22.000000       21.8   27.888889  20.000000       17.2
# 8   PG  31.03  LAC  17.250000       16.4   10.428571  28.411765       34.0
# 9    C  31.63  LAC  21.428571       19.0   16.800000  19.142857       13.8
# 10  PG  37.07  HOU  29.200000       27.4   17.375000  23.166667       22.8
# 11  SG  31.90  LAC  27.062500       25.2         NaN  21.263158       24.0
# 12  SG  35.57  MIL  21.111111       25.0         NaN  21.333333       20.2
# 13  SF  40.33  UTA  28.071429       28.2   38.000000  23.210526       23.2
# 14  PG  33.83  CHI  15.800000       20.8    7.250000  28.411765       29.0
#
#     PA_line  PA  PA_Diff PA_Result
# 0      27.5  45     17.5         O
# 1      18.5  35     16.5         O
# 2      16.5  33     16.5         O
# 3      26.5  42     15.5         O
# 4      35.5  49     13.5         O
# 5      25.5  38     12.5         O
# 6      26.5  39     12.5         O
# 7      23.5  36     12.5         O
# 8      15.5  28     12.5         O
# 9      19.5  30     10.5         O
# 10     25.5  36     10.5         O
# 11     22.5  33     10.5         O
# 12     23.5  33      9.5         O
# 13     28.5  37      8.5         O
# 14     16.5  25      8.5         O
# ===RA===
#              game_id       Date Team  B2B  Spread  Total            Player  \
# 0   20251201_PHO_LAL 2025-12-01  PHO    0    14.5  225.5     Royce O'Neale
# 1   20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5      Nikola Jokic
# 2   20251201_CHO_BRK 2025-12-01  CHO    0    -4.5  229.5       LaMelo Ball
# 3   20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5    Alperen Sengun
# 4   20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5      Kevin Durant
# 5   20251201_DAL_DEN 2025-12-01  DAL    0    11.5  235.5     Anthony Davis
# 6   20251201_CHI_ORL 2025-12-01  ORL    0    -9.5  239.5     Anthony Black
# 7   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5       Bam Adebayo
# 8   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5    Andrew Wiggins
# 9   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5   Davion Mitchell
# 10  20251201_ATL_DET 2025-12-01  ATL    1     9.5  232.5     Jalen Johnson
# 11  20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5         Kris Dunn
# 12  20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5    Nikola Vucevic
# 13  20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5  Donovan Mitchell
# 14  20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5       Ayo Dosunmu
#
#    Pos     MP  Opp     Off_RA  Off_L5_RA  AVG_RA_H2H     Def_RA  Def_L5_RA  \
# 0   SF  33.02  LAL   7.904762        7.0   10.000000   9.600000        8.8
# 1    C  37.00  DAL  23.315789       20.6   24.000000  12.823529       13.6
# 2   PG  29.50  BRK  14.692308       11.8    8.000000  10.538462        9.2
# 3    C  38.15  UTA  15.937500       12.0   16.600000  12.357143       12.8
# 4   SF  40.33  UTA   7.928571        9.0   13.714286  13.368421       14.0
# 5   PF  32.42  DEN  12.000000       11.6   16.444444   8.833333        9.8
# 6   PG  33.83  CHI   5.750000        6.6    4.000000  11.411765       12.2
# 7    C  31.63  LAC  11.071429       11.4   12.600000  11.785714       10.6
# 8   SF  32.02  LAC   7.705882        8.0    4.857143   8.850000        8.4
# 9   PG  31.03  LAC  10.400000       11.4    5.428571  10.176471       11.6
# 10  SF  37.68  DET  17.850000       19.6   14.200000   7.733333       11.0
# 11  PG  25.78  MIA   5.526316        6.0    6.000000  14.571429       12.6
# 12   C  34.48  ORL  13.333333       12.4   14.285714  11.875000       14.2
# 13  SG  34.48  IND  10.263158       11.6   10.100000   6.857143        7.2
# 14  SG  36.73  ORL   5.588235        5.2    5.285714   7.600000        5.8
#
#     RA_line  RA  RA_Diff RA_Result
# 0       7.5  18     10.5         O
# 1      23.5  33      9.5         O
# 2      12.5  19      6.5         O
# 3      15.5  22      6.5         O
# 4       8.5  14      5.5         O
# 5      11.5  17      5.5         O
# 6       6.5  12      5.5         O
# 7      11.5  17      5.5         O
# 8       6.5  12      5.5         O
# 9       9.5  15      5.5         O
# 10     16.5  20      3.5         O
# 11      5.5   9      3.5         O
# 12     12.5  16      3.5         O
# 13     11.5  15      3.5         O
# 14      6.5  10      3.5         O
# ===PRA===
#              game_id       Date Team  B2B  Spread  Total              Player  \
# 0   20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5    Donovan Mitchell
# 1   20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5    Collin Gillespie
# 2   20251201_DAL_DEN 2025-12-01  DAL    0    11.5  235.5       Anthony Davis
# 3   20251201_CHI_ORL 2025-12-01  ORL    0    -9.5  239.5        Desmond Bane
# 4   20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5    Kevin Porter Jr.
# 5   20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5      Alperen Sengun
# 6   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5         Bam Adebayo
# 7   20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5       Kawhi Leonard
# 8   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5     Davion Mitchell
# 9   20251201_CHI_ORL 2025-12-01  ORL    0    -9.5  239.5       Anthony Black
# 10  20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5        Kevin Durant
# 11  20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5      Andrew Wiggins
# 12  20251201_CHO_BRK 2025-12-01  BRK    0     4.5  229.5  Michael Porter Jr.
# 13  20251201_HOU_UTA 2025-12-01  UTA    1    11.5  233.5      Keyonte George
# 14  20251201_ATL_DET 2025-12-01  ATL    1     9.5  232.5       Jalen Johnson
#
#    Pos     MP  Opp    Off_PRA  Off_L5_PRA  AVG_PRA_H2H    Def_PRA  Def_L5_PRA  \
# 0   SG  34.48  IND  40.210526        40.8    42.900000  23.333333        23.6
# 1   PG  33.83  LAL  21.428571        24.6     3.250000  27.736842        27.2
# 2   PF  32.42  DEN  31.333333        30.4    40.777778  25.333333        23.0
# 3   SG  34.47  CHI  27.300000        31.8          NaN  21.571429        24.4
# 4   PG  31.02  WAS  17.500000        17.5    10.500000  36.416667        35.6
# 5    C  38.15  UTA  37.187500        32.6    44.400000  30.500000        39.2
# 6    C  31.63  LAC  29.928571        28.4    25.800000  28.285714        21.2
# 7   SF  30.40  MIA  33.600000        34.0    30.500000  27.611111        24.2
# 8   PG  31.03  LAC  20.100000        19.6    12.714286  32.823529        39.0
# 9   PG  33.83  CHI  18.750000        23.4     9.500000  33.058824        34.8
# 10  SF  40.33  UTA  32.642857        33.6    44.285714  30.684211        29.2
# 11  SF  32.02  LAC  24.941176        24.0    21.142857  27.300000        29.6
# 12  SF  36.05  CHO  34.625000        36.2    25.400000  29.666667        36.0
# 13  PG  37.07  HOU  33.250000        31.4    20.250000  27.333333        26.4
# 14  SF  37.68  DET  41.150000        44.2    35.400000  31.666667        35.8
#
#     PRA_line  PRA  PRA_Diff PRA_Result
# 0       40.5   58      17.5          O
# 1       20.5   37      16.5          O
# 2       32.5   49      16.5          O
# 3       31.5   48      16.5          O
# 4       22.5   39      16.5          O
# 5       37.5   53      15.5          O
# 6       28.5   44      15.5          O
# 7       30.5   45      14.5          O
# 8       17.5   31      13.5          O
# 9       20.5   34      13.5          O
# 10      33.5   46      12.5          O
# 11      21.5   34      12.5          O
# 12      33.5   46      12.5          O
# 13      28.5   40      11.5          O
# 14      38.5   49      10.5          O

# %%
for stat in ['PTS', 'AST', 'REB', 'PR', 'PA', 'RA', 'PRA']:
    print(f"==={stat}===")
    display(con.execute(f"""SELECT game_id, Date, Team, B2B, Spread, Total, Player, Pos, MP, Opp, 
                            Off_{stat}, Off_L5_{stat}, AVG_{stat}_H2H, 
                            Def_{stat}, Def_L5_{stat}, {stat}_line, {stat}, 
                            {stat}_Diff, {stat}_Result FROM df
                            WHERE {stat}_line IS NOT NULL AND {stat}_Result = 'U'
                            ORDER BY {stat}_Diff
                            LIMIT 15""").fetchdf())
# Out:
# ===PTS===
#              game_id       Date Team  B2B  Spread  Total              Player  \
# 0   20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5        Devin Booker
# 1   20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5        James Harden
# 2   20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5        Jamal Murray
# 3   20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5       Kevin Huerter
# 4   20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5       Rui Hachimura
# 5   20251201_CHO_BRK 2025-12-01  CHO    0    -4.5  229.5       Miles Bridges
# 6   20251201_CLE_IND 2025-12-01  IND    1     4.5  231.5  Bennedict Mathurin
# 7   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5         Kel'el Ware
# 8   20251201_ATL_DET 2025-12-01  DET    1    -9.5  232.5     Cade Cunningham
# 9   20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5        LeBron James
# 10  20251201_HOU_UTA 2025-12-01  UTA    1    11.5  233.5    Brice Sensabaugh
# 11  20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5          Kyle Kuzma
# 12  20251201_ATL_DET 2025-12-01  DET    1    -9.5  232.5          Jaden Ivey
# 13  20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5    Jaime Jaquez Jr.
# 14  20251201_ATL_DET 2025-12-01  ATL    1     9.5  232.5  Zaccharie Risacher
#
#    Pos     MP  Opp    Off_PTS  Off_L5_PTS  AVG_PTS_H2H    Def_PTS  Def_L5_PTS  \
# 0   SG   9.92  LAL  25.666667        21.2    24.857143  17.333333        14.4
# 1   PG  19.85  MIA  27.684211        31.0    23.000000  22.857143        22.6
# 2   PG  26.48  DAL  24.000000        27.8    22.428571  20.000000        19.8
# 3   SF   5.68  ORL  12.611111         8.0          NaN  19.526316        21.4
# 4   PF  22.98  PHO  14.777778        12.0    10.714286  17.722222        16.0
# 5   PF  30.38  BRK  22.400000        22.8    17.750000  18.100000        16.0
# 6   SF  21.80  CLE  22.222222        17.8    12.727273  20.500000        25.2
# 7    C  16.38  LAC  13.000000        16.6          NaN  16.500000        10.6
# 8   PG  38.13  ATL  28.823529        32.6    24.500000  20.866667        24.2
# 9   SF  31.23  PHO  16.500000        16.5    21.500000  15.400000        14.2
# 10  SF   9.88  HOU   9.944444        11.6    11.714286  18.117647        18.0
# 11  PF  19.87  WAS  13.500000        13.4          NaN  19.076923        19.0
# 12  SG  14.25  ATL   8.200000         8.2    13.000000  17.600000        26.0
# 13  SF  20.60  LAC  16.157895        13.4     8.200000  18.450000        21.2
# 14  SF  21.78  DET  11.789474        11.2    10.750000  23.933333        24.8
#
#     PTS_line  PTS  PTS_Diff PTS_Result
# 0       26.5   11     -15.5          U
# 1       26.5   11     -15.5          U
# 2       24.5   10     -14.5          U
# 3       12.5    0     -12.5          U
# 4       11.5    0     -11.5          U
# 5       19.5    8     -11.5          U
# 6       21.5   11     -10.5          U
# 7       10.5    0     -10.5          U
# 8       27.5   18      -9.5          U
# 9       19.5   10      -9.5          U
# 10      10.5    1      -9.5          U
# 11      11.5    3      -8.5          U
# 12       8.5    0      -8.5          U
# 13      11.5    4      -7.5          U
# 14      11.5    4      -7.5          U
# ===AST===
#              game_id       Date Team  B2B  Spread  Total  \
# 0   20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5
# 1   20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5
# 2   20251201_CLE_IND 2025-12-01  IND    1     4.5  231.5
# 3   20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5
# 4   20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5
# 5   20251201_ATL_DET 2025-12-01  ATL    1     9.5  232.5
# 6   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5
# 7   20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5
# 8   20251201_CHI_ORL 2025-12-01  ORL    0    -5.5  238.5
# 9   20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5
# 10  20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5
# 11  20251201_CLE_IND 2025-12-01  IND    1     4.5  231.5
# 12  20251201_CHO_BRK 2025-12-01  CHO    0    -4.5  229.5
# 13  20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5
# 14  20251201_CHO_BRK 2025-12-01  CHO    0    -4.5  229.5
#
#                       Player Pos     MP  Opp   Off_AST  Off_L5_AST  \
# 0               James Harden  PG  19.85  MIA  8.684211        8.80
# 1               Devin Booker  SG   9.92  LAL  6.857143        6.20
# 2             T.J. McConnell  PG   5.93  CLE  4.600000        5.80
# 3               LeBron James  SF  31.23  PHO  8.250000        8.25
# 4                Luka Doncic  PG  31.55  PHO  9.200000        9.80
# 5   Nickeil Alexander-Walker  SG  35.28  DET  3.700000        3.80
# 6                Tyler Herro  SG  29.33  LAC  4.500000        4.50
# 7              Reed Sheppard  PG  23.40  UTA  3.312500        4.00
# 8               Franz Wagner  SF  32.33  CHI  3.800000        3.80
# 9              Amen Thompson  SF  37.22  UTA  5.312500        5.60
# 10             Kevin Huerter  SF   5.68  ORL  2.875000        2.20
# 11             Pascal Siakam  PF  31.25  CLE  4.368421        2.80
# 12             Collin Sexton  SG  18.83  BRK  4.473684        3.60
# 13     Giannis Antetokounmpo  PF  31.60  WAS  6.600000        7.40
# 14             Miles Bridges  PF  30.38  BRK  4.000000        3.40
#
#     AVG_AST_H2H   Def_AST  Def_L5_AST  AST_line  AST  AST_Diff AST_Result
# 0     10.200000  7.500000         6.2       8.5    3      -5.5          U
# 1      6.714286  3.750000         4.8       7.5    3      -4.5          U
# 2      4.642857  6.500000         5.8       5.5    1      -4.5          U
# 3      9.125000  3.133333         3.2       6.5    3      -3.5          U
# 4      9.000000  5.947368         4.0       8.5    5      -3.5          U
# 5      2.600000  2.956522         2.2       3.5    1      -2.5          U
# 6      5.000000  4.263158         3.4       4.5    2      -2.5          U
# 7      1.500000  7.411765         7.2       4.5    2      -2.5          U
# 8      3.750000  3.434783         3.0       4.5    2      -2.5          U
# 9      4.750000  5.894737         8.0       5.5    3      -2.5          U
# 10          NaN  3.473684         3.8       2.5    0      -2.5          U
# 11     3.153846  3.583333         2.6       4.5    2      -2.5          U
# 12     5.200000  4.200000         4.2       4.5    2      -2.5          U
# 13     6.666667  2.461538         2.6       6.5    4      -2.5          U
# 14     2.625000  5.000000         5.6       3.5    1      -2.5          U
# ===REB===
#              game_id       Date Team  B2B  Spread  Total  \
# 0   20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5
# 1   20251201_CHO_BRK 2025-12-01  CHO    0    -4.5  229.5
# 2   20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5
# 3   20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5
# 4   20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5
# 5   20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5
# 6   20251201_ATL_DET 2025-12-01  ATL    1     9.5  232.5
# 7   20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5
# 8   20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5
# 9   20251201_MIL_WAS 2025-12-01  WAS    0    10.5  231.5
# 10  20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5
# 11  20251201_CHO_BRK 2025-12-01  BRK    0     4.5  229.5
# 12  20251201_CLE_IND 2025-12-01  IND    1     4.5  231.5
# 13  20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5
# 14  20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5
#
#                    Player Pos     MP  Opp    Off_REB  Off_L5_REB  AVG_REB_H2H  \
# 0            LeBron James  SF  31.23  PHO   5.000000         5.0     7.000000
# 1           Miles Bridges  PF  30.38  BRK   6.300000         4.6     7.625000
# 2             Evan Mobley  PF  28.20  IND   9.200000        11.0     9.545455
# 3   Giannis Antetokounmpo  PF  31.60  WAS  10.933333         9.0    11.500000
# 4            Myles Turner   C  26.12  WAS   6.333333         5.8     8.285714
# 5           Kevin Huerter  SF   5.68  ORL   3.875000         2.2          NaN
# 6          Mouhamed Gueye  PF  22.55  DET   4.473684         3.8     3.250000
# 7            James Harden  PG  19.85  MIA   6.222222         5.0     6.400000
# 8         Cameron Johnson  SF  36.32  DAL   3.444444         5.2          NaN
# 9          Kyshawn George  SF  30.87  MIL   6.125000         6.2     6.000000
# 10             Kyle Kuzma  PF  19.87  WAS   4.550000         5.2          NaN
# 11           Noah Clowney  PF  30.13  CHO   3.578947         3.2     1.833333
# 12         T.J. McConnell  PG   5.93  CLE   2.800000         3.6     2.357143
# 13          Rui Hachimura  PF  22.98  PHO   3.777778         3.8     3.857143
# 14              Tre Jones  PG  29.72  ORL   3.375000         2.0     3.500000
#
#       Def_REB  Def_L5_REB  REB_line  REB  REB_Diff REB_Result
# 0    5.333333         6.0       6.5    0      -6.5          U
# 1    7.400000         7.6       6.5    2      -4.5          U
# 2    8.285714         9.8       9.5    5      -4.5          U
# 3    7.692308         6.6      11.5    7      -4.5          U
# 4   11.111111        10.6       6.5    3      -3.5          U
# 5    5.842105         4.8       3.5    0      -3.5          U
# 6    6.533333         6.0       4.5    1      -3.5          U
# 7    7.071429         6.4       5.5    2      -3.5          U
# 8    5.703704         6.2       4.5    1      -3.5          U
# 9    6.238095         5.6       5.5    3      -2.5          U
# 10   7.692308         6.6       4.5    2      -2.5          U
# 11   5.928571         6.4       4.5    2      -2.5          U
# 12   3.937500         3.0       3.5    1      -2.5          U
# 13   5.944444         5.8       3.5    1      -2.5          U
# 14   5.055556         5.4       3.5    1      -2.5          U
# ===PR===
#              game_id       Date Team  B2B  Spread  Total  \
# 0   20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5
# 1   20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5
# 2   20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5
# 3   20251201_CHO_BRK 2025-12-01  CHO    0    -4.5  229.5
# 4   20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5
# 5   20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5
# 6   20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5
# 7   20251201_CLE_IND 2025-12-01  IND    1     4.5  231.5
# 8   20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5
# 9   20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5
# 10  20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5
# 11  20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5
# 12  20251201_ATL_DET 2025-12-01  ATL    1     9.5  232.5
# 13  20251201_CLE_IND 2025-12-01  IND    1     4.5  231.5
# 14  20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5
#
#                    Player Pos     MP  Opp     Off_PR  Off_L5_PR  AVG_PR_H2H  \
# 0            James Harden  PG  19.85  MIA  33.578947       36.0   29.400000
# 1            Devin Booker  SG   9.92  LAL  30.095238       26.6   29.571429
# 2            LeBron James  SF  31.23  PHO  21.500000       21.5   28.500000
# 3           Miles Bridges  PF  30.38  BRK  28.700000       27.4   25.375000
# 4           Kevin Huerter  SF   5.68  ORL  16.055556        9.8         NaN
# 5           Rui Hachimura  PF  22.98  PHO  18.555556       15.8   14.571429
# 6            Jamal Murray  PG  26.48  DAL  28.500000       30.6   25.285714
# 7      Bennedict Mathurin  SF  21.80  CLE  27.888889       22.2   15.363636
# 8             Evan Mobley  PF  28.20  IND  28.350000       31.2   26.909091
# 9             Kel'el Ware   C  16.38  LAC  23.050000       29.4         NaN
# 10             Kyle Kuzma  PF  19.87  WAS  18.050000       18.6         NaN
# 11  Giannis Antetokounmpo  PF  31.60  WAS  41.866667       35.0   45.666667
# 12     Zaccharie Risacher  SF  21.78  DET  14.526316       14.2   14.250000
# 13         T.J. McConnell  PG   5.93  CLE  13.200000       16.4   10.500000
# 14          Austin Reaves  SG  33.37  PHO  34.625000       37.4   21.888889
#
#        Def_PR  Def_L5_PR  PR_line  PR  PR_Diff PR_Result
# 0   29.928571       29.0     32.5  13    -19.5         U
# 1   21.416667       17.6     30.5  13    -17.5         U
# 2   20.733333       20.2     26.5  10    -16.5         U
# 3   25.500000       23.6     26.5  10    -16.5         U
# 4   25.368421       26.2     15.5   0    -15.5         U
# 5   23.666667       21.8     15.5   1    -14.5         U
# 6   25.266667       25.0     28.5  14    -14.5         U
# 7   27.100000       33.4     27.5  15    -12.5         U
# 8   27.500000       28.4     29.5  18    -11.5         U
# 9   25.642857       18.0     19.5   9    -10.5         U
# 10  26.769231       25.6     15.5   5    -10.5         U
# 11  26.769231       25.6     42.5  33     -9.5         U
# 12  28.933333       31.8     14.5   5     -9.5         U
# 13  22.937500       28.6     14.5   5     -9.5         U
# 14  20.285714       16.0     28.5  20     -8.5         U
# ===PA===
#              game_id       Date Team  B2B  Spread  Total  \
# 0   20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5
# 1   20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5
# 2   20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5
# 3   20251201_CHO_BRK 2025-12-01  CHO    0    -4.5  229.5
# 4   20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5
# 5   20251201_CLE_IND 2025-12-01  IND    1     4.5  231.5
# 6   20251201_CLE_IND 2025-12-01  IND    1     4.5  231.5
# 7   20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5
# 8   20251201_ATL_DET 2025-12-01  DET    1    -9.5  232.5
# 9   20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5
# 10  20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5
# 11  20251201_CHI_ORL 2025-12-01  ORL    0    -9.5  239.5
# 12  20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5
# 13  20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5
# 14  20251201_ATL_DET 2025-12-01  DET    1    -9.5  232.5
#
#                    Player Pos     MP  Opp     Off_PA  Off_L5_PA  AVG_PA_H2H  \
# 0            James Harden  PG  19.85  MIA  36.368421      39.80   33.200000
# 1            Devin Booker  SG   9.92  LAL  32.523810      27.40   31.571429
# 2           Kevin Huerter  SF   5.68  ORL  15.166667      10.00         NaN
# 3           Miles Bridges  PF  30.38  BRK  26.000000      25.80   20.375000
# 4            LeBron James  SF  31.23  PHO  24.750000      24.75   30.625000
# 5      Bennedict Mathurin  SF  21.80  CLE  24.666667      20.40   14.181818
# 6          T.J. McConnell  PG   5.93  CLE  15.000000      18.60   12.785714
# 7            Jamal Murray  PG  26.48  DAL  30.555556      35.40   29.142857
# 8         Cade Cunningham  PG  38.13  ATL  38.176471      40.60   34.375000
# 9           Austin Reaves  SG  33.37  PHO  35.625000      33.80   22.555556
# 10          Reed Sheppard  PG  23.40  UTA  17.562500      21.20    8.250000
# 11            Jalen Suggs  PG  29.97  CHI  18.466667      21.60   18.833333
# 12  Giannis Antetokounmpo  PF  31.60  WAS  37.533333      33.40   40.833333
# 13       Jaime Jaquez Jr.  SF  20.60  LAC  21.473684      19.20   11.400000
# 14         Ausar Thompson  SF  29.62  ATL  14.750000      11.40   14.500000
#
#        Def_PA  Def_L5_PA  PA_line  PA  PA_Diff PA_Result
# 0   30.357143       28.8     35.5  14    -21.5         U
# 1   21.083333       19.2     33.5  14    -19.5         U
# 2   23.000000       25.2     14.5   0    -14.5         U
# 3   23.100000       21.6     23.5   9    -14.5         U
# 4   18.533333       17.4     27.5  13    -14.5         U
# 5   25.050000       31.2     23.5  12    -11.5         U
# 6   25.500000       31.4     16.5   5    -11.5         U
# 7   27.400000       25.8     30.5  19    -11.5         U
# 8   28.000000       32.6     36.5  26    -10.5         U
# 9   20.333333       17.6     28.5  19     -9.5         U
# 10  29.941176       31.2     19.5  11     -8.5         U
# 11  28.411765       29.0     22.5  14     -8.5         U
# 12  21.538462       21.6     37.5  30     -7.5         U
# 13  21.750000       24.6     15.5   9     -6.5         U
# 14  23.450000       23.2     14.5   9     -5.5         U
# ===RA===
#              game_id       Date Team  B2B  Spread  Total  \
# 0   20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5
# 1   20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5
# 2   20251201_CHO_BRK 2025-12-01  CHO    0    -4.5  229.5
# 3   20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5
# 4   20251201_CLE_IND 2025-12-01  IND    1     4.5  231.5
# 5   20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5
# 6   20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5
# 7   20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5
# 8   20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5
# 9   20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5
# 10  20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5
# 11  20251201_CHI_ORL 2025-12-01  ORL    0    -9.5  239.5
# 12  20251201_LAC_MIA 2025-12-01  MIA    0    -6.5  236.5
# 13  20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5
# 14  20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5
#
#                    Player Pos     MP  Opp     Off_RA  Off_L5_RA  AVG_RA_H2H  \
# 0            LeBron James  SF  31.23  PHO  13.250000  13.250000   16.125000
# 1            James Harden  PG  19.85  MIA  14.578947  13.800000   16.600000
# 2           Miles Bridges  PF  30.38  BRK   9.900000   7.600000   10.250000
# 3   Giannis Antetokounmpo  PF  31.60  WAS  17.533333  16.400000   18.166667
# 4          T.J. McConnell  PG   5.93  CLE   7.400000   9.400000    7.000000
# 5            Devin Booker  SG   9.92  LAL  11.285714  11.600000   11.428571
# 6           Kevin Huerter  SF   5.68  ORL   6.000000   3.800000         NaN
# 7             Evan Mobley  PF  28.20  IND  13.250000  15.200000   11.636364
# 8         Cameron Johnson  SF  36.32  DAL   5.611111   7.400000         NaN
# 9               Tre Jones  PG  29.72  ORL   8.375000   6.000000   10.000000
# 10          Reed Sheppard  PG  23.40  UTA   6.312500   7.600000    3.750000
# 11     Wendell Carter Jr.   C  30.30  CHI   9.631579  11.000000    8.500000
# 12            Tyler Herro  SG  29.33  LAC   8.333333   8.333333   10.750000
# 13           Ryan Rollins  PG  29.58  WAS   9.952381  10.600000    5.000000
# 14            Josh Giddey  PG  35.65  ORL  19.294118  18.800000   13.000000
#
#        Def_RA  Def_L5_RA  RA_line  RA  RA_Diff RA_Result
# 0    8.466667        9.2     13.5   3    -10.5         U
# 1   14.571429       12.6     14.5   5     -9.5         U
# 2   12.400000       13.2     10.5   3     -7.5         U
# 3   10.153846        9.2     17.5  11     -6.5         U
# 4   10.437500        8.8      8.5   2     -6.5         U
# 5    7.833333        8.0     11.5   5     -6.5         U
# 6    9.315789        8.6      5.5   0     -5.5         U
# 7   11.142857       13.4     14.5  10     -4.5         U
# 8    8.703704        9.6      7.5   3     -4.5         U
# 9   12.555556       13.8      7.5   4     -3.5         U
# 10  12.294118       14.2      7.5   4     -3.5         U
# 11  16.062500       12.2     10.5   7     -3.5         U
# 12   9.157895       10.2      8.5   5     -3.5         U
# 13  13.583333       15.0      9.5   7     -2.5         U
# 14  12.555556       13.8     17.5  15     -2.5         U
# ===PRA===
#              game_id       Date Team  B2B  Spread  Total  \
# 0   20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5
# 1   20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5
# 2   20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5
# 3   20251201_CHO_BRK 2025-12-01  CHO    0    -4.5  229.5
# 4   20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5
# 5   20251201_CLE_IND 2025-12-01  IND    1     4.5  231.5
# 6   20251201_CLE_IND 2025-12-01  IND    1     4.5  231.5
# 7   20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5
# 8   20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5
# 9   20251201_CLE_IND 2025-12-01  CLE    1    -4.5  231.5
# 10  20251201_PHO_LAL 2025-12-01  LAL    0    -4.5  235.5
# 11  20251201_CHI_ORL 2025-12-01  ORL    0    -9.5  239.5
# 12  20251201_DAL_DEN 2025-12-01  DEN    0   -11.5  235.5
# 13  20251201_HOU_UTA 2025-12-01  HOU    1   -11.5  233.5
# 14  20251201_ATL_DET 2025-12-01  DET    1    -9.5  232.5
#
#                    Player Pos     MP  Opp    Off_PRA  Off_L5_PRA  AVG_PRA_H2H  \
# 0            James Harden  PG  19.85  MIA  42.263158       44.80    39.600000
# 1            Devin Booker  SG   9.92  LAL  36.952381       32.80    36.285714
# 2            LeBron James  SF  31.23  PHO  29.750000       29.75    37.625000
# 3           Miles Bridges  PF  30.38  BRK  32.300000       30.40    28.000000
# 4           Kevin Huerter  SF   5.68  ORL  18.611111       11.80          NaN
# 5          T.J. McConnell  PG   5.93  CLE  17.800000       22.20    15.142857
# 6      Bennedict Mathurin  SF  21.80  CLE  30.333333       24.80    16.818182
# 7            Jamal Murray  PG  26.48  DAL  35.055556       38.20    32.000000
# 8   Giannis Antetokounmpo  PF  31.60  WAS  48.466667       42.40    52.333333
# 9             Evan Mobley  PF  28.20  IND  32.400000       35.40    29.000000
# 10          Austin Reaves  SG  33.37  PHO  41.437500       41.20    26.222222
# 11            Jalen Suggs  PG  29.97  CHI  22.400000       25.60    21.333333
# 12        Cameron Johnson  SF  36.32  DAL  16.833333       25.40          NaN
# 13          Reed Sheppard  PG  23.40  UTA  20.562500       24.80    10.500000
# 14        Cade Cunningham  PG  38.13  ATL  44.588235       49.40    39.875000
#
#       Def_PRA  Def_L5_PRA  PRA_line  PRA  PRA_Diff PRA_Result
# 0   37.428571        35.2      41.5   16     -25.5          U
# 1   25.166667        22.4      37.5   16     -21.5          U
# 2   23.866667        23.4      33.5   13     -20.5          U
# 3   30.500000        29.2      30.5   11     -19.5          U
# 4   28.842105        30.0      18.5    0     -18.5          U
# 5   29.437500        34.4      19.5    6     -13.5          U
# 6   31.650000        39.4      29.5   16     -13.5          U
# 7   32.666667        31.0      35.5   23     -12.5          U
# 8   29.230769        28.2      48.5   37     -11.5          U
# 9   30.357143        32.0      34.5   23     -11.5          U
# 10  23.904762        20.6      33.5   23     -10.5          U
# 11  33.058824        34.8      27.5   18      -9.5          U
# 12  25.296296        27.2      22.5   13      -9.5          U
# 13  34.823529        38.2      22.5   13      -9.5          U
# 14  34.200000        38.0      42.5   34      -8.5          U

# %% [markdown]
# # REPOPULATE DATA

# %%
def create_actuals_tbl2(con, now, season):
    stats = ['PTS'] # TEMP
    
    df_log = pd.read_csv(f"../tables/{season}/season_gamelogs.csv")
    df_log['Date'] = pd.to_datetime(df_log.Date)
    df_log = df_log[(df_log.Date == now)]
    df_log = df_log.rename(columns={"TRB": "REB", "3PM": "TPM", "3PA": "TPA"})
    df_log['PR'] = df_log.PTS + df_log.REB 
    df_log['PA'] = df_log.PTS + df_log.AST
    df_log['RA'] = df_log.REB + df_log.AST
    df_log['PRA'] = df_log.PTS + df_log.REB + df_log.AST
    df_log['STL_BLK'] = df_log.STL + df_log.BLK
    df = df_log.copy()
    cols = []
    for stat in stats:
        cols.append(stat)

    df = df[['game_id', 'Date', 'Team', 'Player', 'Pos', 'MP'] + cols]
    df_stats = pd.read_csv(f"../tables/{season}/parlay_stats.csv")
    df_stats['Date'] = pd.to_datetime(df_stats.Date).astype(str)
    lines = []
    diffs = []
    stats_cols = []
    
    for stat in stats:
        lines.append(f'{stat}_line')
        diffs.append(f'{stat}_Diff')
    for stat in stats:
        stats_cols.extend([
            f"Off_{stat}",
            f"Off_L5_{stat}",
            f"AVG_{stat}_H2H",
            f"Def_{stat}",
            f"Def_L5_{stat}",
            f"{stat}",
        ])
    df_select = ", ".join(stats_cols)
    lines = str(lines).replace("[", "").replace("]", "")
    diffs = str(diffs).replace("[", "").replace("]", "")
    df_actuals = con.execute(f"""SELECT game_id, df.Date, df.Team, B2B, df.Player, df.Pos, MP, Opp,
                                 {df_select} FROM df JOIN df_stats 
                                 ON df.Date = df_stats.Date AND df.Player = df_stats.Player
                                 """).fetchdf()
    partition_save_df(df_actuals, f"../tables/{season}/parlay_actuals.csv")
#     display(df_actuals)

    return df_actuals

# %%
def repopulate_old_szns(season):
    schd = pd.read_csv(f"../tables/{season}/nba_schedule.csv")
    schd['Date'] = pd.to_datetime(schd.Date)
    # schd = schd[(schd.Date >= '2024-12-04')]
    df_lines = pd.read_csv(f"../tables/{season}/parlay_lines.csv")
    for date in schd.Date.unique().tolist():
        dt_str = date.strftime("%Y-%m-%d")
        now = dt_str
        print(now)
        create_actuals_tbl2(con, now, season)
