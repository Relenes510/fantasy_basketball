# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings
import duckdb
import os

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
warnings.filterwarnings("ignore")

year = 2025
now = str(datetime.now().date() - timedelta(days=1))
print(f"Today's date:", now)

con = duckdb.connect(database=":memory:")
stats = ['PTS', 'AST', 'REB', 'PR', 'PA', 'RA', 'PRA', 'TPM', 'STL', 'BLK', 'STL_BLK']
# Out:
# Today's date: 2025-12-01

# %%
# %run ./common_utils.ipynb

# %%
def create_actuals_tbl(con):
    df_lines = pd.read_csv(f"../tables/{year}/parlay_lines.csv")
    df_lines['Date'] = pd.to_datetime(df_lines.Date)
    df_lines = df_lines[(df_lines.Date == now)]
    df_log = pd.read_csv(f"../tables/{year}/season_gamelogs.csv")
    df_log['Date'] = pd.to_datetime(df_log.Date)
    df_log = df_log[(df_log.Date == now)]
    df_log = df_log.rename(columns={"TRB": "REB", "3PM": "TPM", "3PA": "TPA"})
    df_log['PR'] = df_log.PTS + df_log.REB 
    df_log['PA'] = df_log.PTS + df_log.AST
    df_log['RA'] = df_log.REB + df_log.AST
    df_log['PRA'] = df_log.PTS + df_log.REB + df_log.AST
    df_log['STL_BLK'] = df_log.STL + df_log.BLK
    df = con.execute("""SELECT t2.*, t1.* EXCLUDE(Date, Team, Player, Pos) FROM df_log t1 JOIN df_lines t2 
                        ON t1.Team = t2.Team AND t1.Player = t2.Player""").fetchdf()
    cols = []
    for stat in stats:
        df[f'{stat}_Result'] = np.where(df[stat] > df[f'{stat}_line'], 'O', 'U')
        df[f'{stat}_Result'] = np.where(df[f'{stat}_line'].isnull(), np.nan, df[f'{stat}_Result'])
        df[f'{stat}_Diff'] = df[stat] - df[f'{stat}_line']
        cols.append(stat)
        cols.append(f'{stat}_line')
        cols.append(f'{stat}_Diff')
        cols.append(f'{stat}_Result')
    df = df[['game_id', 'Date', 'Team', 'Player', 'Pos', 'MP'] + cols]
    
    df_stats = pd.read_csv(f"../tables/{year}/parlay_stats.csv")
    df_stats['Date'] = pd.to_datetime(df_stats.Date).astype(str)
    lines = []
    diffs = []
    stats_cols = []
    
    for stat in stats:
        lines.append(f'{stat}_line')
        diffs.append(f'{stat}_Diff')
    for stat in stats:
        stats_cols.extend([
            f"Off_{stat}",
            f"Off_L5_{stat}",
            f"AVG_{stat}_H2H",
            f"Def_{stat}",
            f"Def_L5_{stat}",
            f"df_stats.{stat}_line",
            f"{stat}",
            f"df.{stat}_Diff",
            f"{stat}_Result"
        ])
    df_select = ", ".join(stats_cols)
    lines = str(lines).replace("[", "").replace("]", "")
    diffs = str(diffs).replace("[", "").replace("]", "")
    df_actuals = con.execute(f"""SELECT game_id, df.Date, df.Team, B2B, Spread, Total, df.Player, df.Pos, MP, Opp,
                                 {df_select} FROM df JOIN df_stats 
                                 ON df.Date = df_stats.Date AND df.Player = df_stats.Player
                                 """).fetchdf()
    partition_save_df(df_actuals, f"../tables/{year}/parlay_actuals.csv")
    display(df_actuals)

    return df_actuals
                      
df = create_actuals_tbl(con)
# Out:
# ../tables/2025/parlay_actuals.csv saved!
#               game_id       Date Team  B2B  Spread  Total          Player Pos  \
# 0    20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5       Tre Jones  PG
# 1    20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5     Josh Giddey  PG
# 2    20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5    James Harden  PG
# 3    20251201_LAC_MIA 2025-12-01  LAC    0     6.5  236.5       Kris Dunn  PG
# 4    20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5    Ryan Rollins  PG
# ..                ...        ...  ...  ...     ...    ...             ...  ..
# 134  20251201_ATL_DET 2025-12-01  DET    1    -9.5  232.5  Isaiah Stewart   C
# 135  20251201_CHI_ORL 2025-12-01  CHI    0     9.5  239.5  Nikola Vucevic   C
# 136  20251201_PHO_LAL 2025-12-01  PHO    0    14.5  225.5   Mark Williams   C
# 137  20251201_PHO_LAL 2025-12-01  PHO    0     4.5  235.5   Mark Williams   C
# 138  20251201_MIL_WAS 2025-12-01  MIL    0   -10.5  231.5  Gary Trent Jr.  SG
#
#         MP  Opp    Off_PTS  Off_L5_PTS  AVG_PTS_H2H    Def_PTS  Def_L5_PTS  \
# 0    29.72  ORL  12.812500        11.8    12.750000  24.055556        28.4
# 1    35.65  ORL  20.529412        20.0    15.833333  24.055556        28.4
# 2    19.85  MIA  27.684211        31.0    23.000000  22.857143        22.6
# 3    25.78  MIA   8.210526        10.2     3.600000  22.857143        22.6
# 4    29.58  WAS  17.904762        16.6     9.500000  22.833333        20.6
# ..     ...  ...        ...         ...          ...        ...         ...
# 134  25.07  ATL  10.117647         7.8     7.285714  14.466667        19.4
# 135  34.48  ORL  16.444444        18.0    16.142857  14.125000        18.6
# 136  24.87  LAL  12.882353        16.4          NaN  10.714286         9.8
# 137  24.87  LAL  12.882353        16.4          NaN  10.714286         9.8
# 138  30.50  WAS        NaN         NaN          NaN        NaN         NaN
#
#      PTS_line  PTS  PTS_Diff PTS_Result   Off_AST  Off_L5_AST  AVG_AST_H2H  \
# 0        11.5   20       8.5          O  5.000000         4.0     6.500000
# 1        19.5   22       2.5          O  9.294118         8.4     5.166667
# 2        26.5   11     -15.5          U  8.684211         8.8    10.200000
# 3         8.5   12       3.5          O  3.000000         2.8     4.600000
# 4        15.5   14      -1.5          U  5.857143         5.8     2.250000
# ..        ...  ...       ...        ...       ...         ...          ...
# 134       7.5    6      -1.5          U       NaN         NaN          NaN
# 135      17.5   20       2.5          O  3.764706         3.2     3.714286
# 136      12.5   13       0.5          O       NaN         NaN          NaN
# 137      12.5   13       0.5          O       NaN         NaN          NaN
# 138       NaN   14       NaN       None       NaN         NaN          NaN
#
#       Def_AST  Def_L5_AST  AST_line  AST  AST_Diff AST_Result    Off_REB  \
# 0    7.500000         8.4       4.5    3      -1.5          U   3.375000
# 1    7.500000         8.4       7.5    6      -1.5          U  10.000000
# 2    7.500000         6.2       8.5    3      -5.5          U   6.222222
# 3    7.500000         6.2       2.5    5       2.5          O   3.176471
# 4    8.166667         8.2       5.5    5      -0.5          U   4.300000
# ..        ...         ...       ...  ...       ...        ...        ...
# 134       NaN         NaN       NaN    0       NaN       None   6.352941
# 135  2.125000         2.8       2.5    5       2.5          O   9.777778
# 136       NaN         NaN       NaN    1       NaN       None   9.117647
# 137       NaN         NaN       NaN    1       NaN       None   9.117647
# 138       NaN         NaN       NaN    0       NaN       None        NaN
#
#      Off_L5_REB  AVG_REB_H2H   Def_REB  Def_L5_REB  REB_line  REB  REB_Diff  \
# 0           2.0     3.500000  5.055556         5.4       3.5    1      -2.5
# 1          10.4     7.833333  5.055556         5.4       8.5    9       0.5
# 2           5.0     6.400000  7.071429         6.4       5.5    2      -3.5
# 3           3.8     1.400000  7.071429         6.4       2.5    4       1.5
# 4           4.8     2.750000  5.416667         6.8       3.5    2      -1.5
# ..          ...          ...       ...         ...       ...  ...       ...
# 134         6.0     6.142857  9.200000         8.0       5.5   10       4.5
# 135         9.2    10.571429  9.750000        11.4       9.5   11       1.5
# 136        11.0          NaN  8.071429         9.0       8.5    6      -2.5
# 137        11.0          NaN  8.071429         9.0       8.5    6      -2.5
# 138         NaN          NaN       NaN         NaN       NaN    1       NaN
#
#     REB_Result     Off_PR  Off_L5_PR  AVG_PR_H2H     Def_PR  Def_L5_PR  \
# 0            U  16.187500       13.8   16.250000  29.111111       33.8
# 1            O  30.529412       30.4   23.666667  29.111111       33.8
# 2            U  33.578947       36.0   29.400000  29.928571       29.0
# 3            O  10.500000       13.4    5.000000  29.928571       29.0
# 4            U  22.000000       21.4   12.250000  28.250000       27.4
# ..         ...        ...        ...         ...        ...        ...
# 134          O        NaN        NaN         NaN        NaN        NaN
# 135          O  26.222222       27.2   26.714286  23.875000       30.0
# 136          U  22.000000       27.4         NaN  18.785714       18.8
# 137          U  22.000000       27.4         NaN  18.785714       18.8
# 138       None        NaN        NaN         NaN        NaN        NaN
#
#      PR_line  PR  PR_Diff PR_Result     Off_PA  Off_L5_PA  AVG_PA_H2H  \
# 0       14.5  21      6.5         O  17.812500       15.8   19.250000
# 1       28.5  31      2.5         O  29.823529       28.4   21.000000
# 2       32.5  13    -19.5         U  36.368421       39.8   33.200000
# 3       11.5  16      4.5         O  10.350000       13.0    8.200000
# 4       19.5  16     -3.5         U  23.761905       22.4   11.750000
# ..       ...  ..      ...       ...        ...        ...         ...
# 134      NaN  16      NaN      None        NaN        NaN         NaN
# 135     26.5  31      4.5         O  20.000000       21.2   19.857143
# 136     21.5  19     -2.5         U        NaN        NaN         NaN
# 137     21.5  19     -2.5         U        NaN        NaN         NaN
# 138      NaN  15      NaN      None        NaN        NaN         NaN
#
#         Def_PA  Def_L5_PA  PA_line  PA  PA_Diff PA_Result     Off_RA  \
# 0    31.555556       36.8     15.5  23      7.5         O   8.375000
# 1    31.555556       36.8     27.5  28      0.5         O  19.294118
# 2    30.357143       28.8     35.5  14    -21.5         U  14.578947
# 3    30.357143       28.8     11.5  17      5.5         O   5.526316
# 4    31.000000       28.8     21.5  19     -2.5         U   9.952381
# ..         ...        ...      ...  ..      ...       ...        ...
# 134        NaN        NaN      NaN   6      NaN      None        NaN
# 135  16.250000       21.4     20.5  25      4.5         O  13.333333
# 136        NaN        NaN      NaN  14      NaN      None        NaN
# 137        NaN        NaN      NaN  14      NaN      None        NaN
# 138        NaN        NaN      NaN  14      NaN      None        NaN
#
#      Off_L5_RA  AVG_RA_H2H     Def_RA  Def_L5_RA  RA_line  RA  RA_Diff  \
# 0          6.0   10.000000  12.555556       13.8      7.5   4     -3.5
# 1         18.8   13.000000  12.555556       13.8     17.5  15     -2.5
# 2         13.8   16.600000  14.571429       12.6     14.5   5     -9.5
# 3          6.0    6.000000  14.571429       12.6      5.5   9      3.5
# 4         10.6    5.000000  13.583333       15.0      9.5   7     -2.5
# ..         ...         ...        ...        ...      ...  ..      ...
# 134        NaN         NaN        NaN        NaN      NaN  10      NaN
# 135       12.4   14.285714  11.875000       14.2     12.5  16      3.5
# 136        NaN         NaN        NaN        NaN      NaN   7      NaN
# 137        NaN         NaN        NaN        NaN      NaN   7      NaN
# 138        NaN         NaN        NaN        NaN      NaN   1      NaN
#
#     RA_Result    Off_PRA  Off_L5_PRA  AVG_PRA_H2H    Def_PRA  Def_L5_PRA  \
# 0           U  21.187500        17.8    22.750000  36.611111        42.2
# 1           U  39.823529        38.8    28.833333  36.611111        42.2
# 2           U  42.263158        44.8    39.600000  37.428571        35.2
# 3           O  13.050000        16.2     9.600000  37.428571        35.2
# 4           U  27.857143        27.2    14.500000  36.416667        35.6
# ..        ...        ...         ...          ...        ...         ...
# 134      None        NaN         NaN          NaN        NaN         NaN
# 135         O  29.777778        30.4    30.428571  26.000000        32.8
# 136      None        NaN         NaN          NaN        NaN         NaN
# 137      None        NaN         NaN          NaN        NaN         NaN
# 138      None        NaN         NaN          NaN        NaN         NaN
#
#      PRA_line  PRA  PRA_Diff PRA_Result   Off_TPM  Off_L5_TPM  AVG_TPM_H2H  \
# 0        19.5   24       4.5          O       NaN         NaN          NaN
# 1        36.5   37       0.5          O  2.066667         2.4     1.500000
# 2        41.5   16     -25.5          U  3.944444         4.8     4.600000
# 3        14.5   21       6.5          O  1.384615         1.6     0.400000
# 4        25.5   21      -4.5          U  2.777778         2.6     1.250000
# ..        ...  ...       ...        ...       ...         ...          ...
# 134       NaN   16       NaN       None       NaN         NaN          NaN
# 135      29.5   36       6.5          O  2.400000         2.6     0.571429
# 136       NaN   20       NaN       None       NaN         NaN          NaN
# 137       NaN   20       NaN       None       NaN         NaN          NaN
# 138       NaN   15       NaN       None       NaN         NaN          NaN
#
#       Def_TPM  Def_L5_TPM  TPM_line  TPM  TPM_Diff TPM_Result   Off_STL  \
# 0         NaN         NaN       NaN    2       NaN       None       NaN
# 1    2.388889         2.8       1.5    3       1.5          O  1.454545
# 2    2.714286         2.2       3.5    1      -2.5          U  1.538462
# 3    2.714286         2.2       0.5    1       0.5          O  1.882353
# 4    2.250000         1.6       2.5    3       0.5          O  1.944444
# ..        ...         ...       ...  ...       ...        ...       ...
# 134       NaN         NaN       NaN    0       NaN       None       NaN
# 135  0.437500         0.6       1.5    1      -0.5          U  1.200000
# 136       NaN         NaN       NaN    0       NaN       None       NaN
# 137       NaN         NaN       NaN    0       NaN       None       NaN
# 138       NaN         NaN       NaN    3       NaN       None  1.538462
#
#      Off_L5_STL  AVG_STL_H2H   Def_STL  Def_L5_STL  STL_line  STL  STL_Diff  \
# 0           NaN          NaN       NaN         NaN       NaN    0       NaN
# 1           1.8     0.833333  1.611111         1.0       0.5    3       2.5
# 2           1.6     1.200000  2.071429         1.4       1.5    0      -1.5
# 3           2.0     2.000000  2.071429         1.4       1.5    1      -0.5
# 4           1.8     1.500000  1.750000         2.4       1.5    0      -1.5
# ..          ...          ...       ...         ...       ...  ...       ...
# 134         NaN          NaN       NaN         NaN       NaN    0       NaN
# 135         1.2     0.571429  0.437500         0.6       0.5    2       1.5
# 136         NaN          NaN       NaN         NaN       NaN    2       NaN
# 137         NaN          NaN       NaN         NaN       NaN    2       NaN
# 138         1.2     1.714286  1.263158         0.2       1.5    0      -1.5
#
#     STL_Result   Off_BLK  Off_L5_BLK  AVG_BLK_H2H   Def_BLK  Def_L5_BLK  \
# 0         None       NaN         NaN          NaN       NaN         NaN
# 1            O       NaN         NaN          NaN       NaN         NaN
# 2            U       NaN         NaN          NaN       NaN         NaN
# 3            U       NaN         NaN          NaN       NaN         NaN
# 4            U       NaN         NaN          NaN       NaN         NaN
# ..         ...       ...         ...          ...       ...         ...
# 134       None  2.307692         2.2     1.000000  0.733333         1.2
# 135          O  1.400000         1.4     0.571429  1.375000         1.4
# 136       None  1.500000         1.2          NaN  0.928571         0.6
# 137       None  1.500000         1.2          NaN  0.928571         0.6
# 138          U       NaN         NaN          NaN       NaN         NaN
#
#      BLK_line  BLK  BLK_Diff BLK_Result  Off_STL_BLK  Off_L5_STL_BLK  \
# 0         NaN    0       NaN       None          NaN             NaN
# 1         NaN    1       NaN       None          NaN             NaN
# 2         NaN    0       NaN       None          NaN             NaN
# 3         NaN    0       NaN       None          NaN             NaN
# 4         NaN    1       NaN       None          NaN             NaN
# ..        ...  ...       ...        ...          ...             ...
# 134       1.5    5       3.5          O          NaN             NaN
# 135       0.5    0      -0.5          U     1.461538             1.6
# 136       0.5    1       0.5          O          NaN             NaN
# 137       0.5    1       0.5          O          NaN             NaN
# 138       NaN    1       NaN       None          NaN             NaN
#
#      AVG_STL_BLK_H2H  Def_STL_BLK  Def_L5_STL_BLK  STL_BLK_line  STL_BLK  \
# 0                NaN          NaN             NaN           NaN        0
# 1                NaN          NaN             NaN           NaN        4
# 2                NaN          NaN             NaN           NaN        0
# 3                NaN          NaN             NaN           NaN        1
# 4                NaN          NaN             NaN           NaN        1
# ..               ...          ...             ...           ...      ...
# 134              NaN          NaN             NaN           NaN        5
# 135         1.142857       1.8125             2.0           1.5        2
# 136              NaN          NaN             NaN           NaN        3
# 137              NaN          NaN             NaN           NaN        3
# 138              NaN          NaN             NaN           NaN        1
#
#      STL_BLK_Diff STL_BLK_Result
# 0             NaN           None
# 1             NaN           None
# 2             NaN           None
# 3             NaN           None
# 4             NaN           None
# ..            ...            ...
# 134           NaN           None
# 135           0.5              O
# 136           NaN           None
# 137           NaN           None
# 138           NaN           None
#
# [139 rows x 109 columns]

# %% [markdown]
# # Parlay Performances

# %% [markdown]
# ##### Best Performers

# %%
df = pd.read_csv(f"../tables/{year}/parlay_actuals.csv")
for stat in ['PTS', 'AST', 'REB', 'PR', 'PA', 'RA', 'PRA']:
    print(f"==={stat}===")
    display(con.execute(f"""WITH overs AS 
                            (SELECT Player, SUM({stat}_Diff) as O_Diff, count(*) as Hits FROM df WHERE {stat}_Result = 'O' GROUP BY Player)

                            SELECT overs.Player, Hits, Misses,
                            O_Diff + U_Diff as Diff,
                            hits / (misses + hits) AS Hit_Pct, misses / (misses + hits) AS Miss_Pct FROM
                           
                           (SELECT Player, SUM({stat}_Diff) as U_Diff, count(*) as Misses FROM df 
                           WHERE {stat}_Result = 'U' AND {stat}_line IS NOT NULL
                           GROUP BY Player) unders
                           
                           JOIN overs ON overs.Player = unders.Player
                           WHERE Hit_Pct >= 0.80
                           ORDER BY Hit_Pct DESC
                           LIMIT 25""").fetchdf())
# Out:
# ===PTS===
#                       Player  Hits  Misses  Diff   Hit_Pct  Miss_Pct
# 0           Collin Gillespie     5       1  38.0  0.833333  0.166667
# 1              Jalen Johnson     5       1  36.0  0.833333  0.166667
# 2               Jaylon Tyson     5       1  28.0  0.833333  0.166667
# 3   Nickeil Alexander-Walker     5       1  48.0  0.833333  0.166667
# 4                 Saddiq Bey     4       1  19.5  0.800000  0.200000
# 5              Rui Hachimura     4       1  -3.5  0.800000  0.200000
# 6              Klay Thompson     4       1  12.5  0.800000  0.200000
# 7               Jaylen Wells     4       1  12.5  0.800000  0.200000
# 8      Sandro Mamukelashvili     4       1  21.5  0.800000  0.200000
# 9              Pascal Siakam     4       1   5.5  0.800000  0.200000
# 10            Onyeka Okongwu     4       1  -3.5  0.800000  0.200000
# 11             Kawhi Leonard     4       1  39.5  0.800000  0.200000
# 12          Tim Hardaway Jr.     4       1   5.5  0.800000  0.200000
# 13             Tobias Harris     4       1  22.5  0.800000  0.200000
# 14               Luka Doncic     4       1  17.5  0.800000  0.200000
# ===AST===
#               Player  Hits  Misses  Diff   Hit_Pct  Miss_Pct
# 0       Jamal Murray     5       1   9.0  0.833333  0.166667
# 1      Jalen Johnson     5       1  10.0  0.833333  0.166667
# 2     Keyonte George     4       1   5.5  0.800000  0.200000
# 3     T.J. McConnell     4       1  -1.5  0.800000  0.200000
# 4  Immanuel Quickley     4       1   3.5  0.800000  0.200000
# ===REB===
#               Player  Hits  Misses  Diff   Hit_Pct  Miss_Pct
# 0        Josh Giddey     5       1   7.0  0.833333  0.166667
# 1          Kris Dunn     5       1   6.0  0.833333  0.166667
# 2      Dyson Daniels     5       1  11.0  0.833333  0.166667
# 3      Jalen Johnson     5       1  12.0  0.833333  0.166667
# 4    Cade Cunningham     4       1  15.5  0.800000  0.200000
# 5     Brandon Ingram     4       1   0.5  0.800000  0.200000
# 6         Saddiq Bey     4       1  19.5  0.800000  0.200000
# 7    Lauri Markkanen     4       1   4.5  0.800000  0.200000
# 8      Austin Reaves     4       1  13.5  0.800000  0.200000
# 9    P.J. Washington     4       1  -1.5  0.800000  0.200000
# 10  Precious Achiuwa     4       1   4.5  0.800000  0.200000
# 11    Jeremiah Fears     4       1   5.5  0.800000  0.200000
# 12     Pascal Siakam     4       1   8.5  0.800000  0.200000
# ===PR===
#                      Player  Hits  Misses  Diff   Hit_Pct  Miss_Pct
# 0             Jalen Johnson     5       1  45.0  0.833333  0.166667
# 1  Nickeil Alexander-Walker     5       1  56.0  0.833333  0.166667
# 2              Noah Clowney     5       1  15.0  0.833333  0.166667
# 3             Peyton Watson     4       1  10.5  0.800000  0.200000
# 4             Anthony Black     4       1  35.5  0.800000  0.200000
# 5     Sandro Mamukelashvili     4       1  25.5  0.800000  0.200000
# 6               Luka Doncic     4       1  22.5  0.800000  0.200000
# 7             Austin Reaves     4       1  36.5  0.800000  0.200000
# 8             Kawhi Leonard     4       1  42.5  0.800000  0.200000
# ===PA===
#                      Player  Hits  Misses  Diff   Hit_Pct  Miss_Pct
# 0             Jalen Johnson     5       1  45.0  0.833333  0.166667
# 1  Nickeil Alexander-Walker     5       1  48.0  0.833333  0.166667
# 2             Kawhi Leonard     4       1  36.5  0.800000  0.200000
# 3            Onyeka Okongwu     4       1   5.5  0.800000  0.200000
# ===RA===
#             Player  Hits  Misses  Diff   Hit_Pct  Miss_Pct
# 0     Jamal Murray     5       1   2.0  0.833333  0.166667
# 1     Terance Mann     4       1   3.5  0.800000  0.200000
# 2   Jeremiah Fears     4       1   5.5  0.800000  0.200000
# 3   Keyonte George     4       1  11.5  0.800000  0.200000
# 4    Anthony Black     4       1   8.5  0.800000  0.200000
# 5   Nikola Vucevic     4       1   2.5  0.800000  0.200000
# 6    Austin Reaves     4       1   8.5  0.800000  0.200000
# 7  Cade Cunningham     4       1  12.5  0.800000  0.200000
# ===PRA===
#                      Player  Hits  Misses  Diff   Hit_Pct  Miss_Pct
# 0  Nickeil Alexander-Walker     5       1  54.0  0.833333  0.166667
# 1             Jalen Johnson     5       1  52.0  0.833333  0.166667
# 2             Austin Reaves     4       1  31.5  0.800000  0.200000

# %% [markdown]
# ##### Worst Performers

# %%
df = pd.read_csv(f"../tables/{year}/parlay_actuals.csv")
for stat in ['PTS', 'AST', 'REB', 'PR', 'PA', 'RA', 'PRA']:
    print(f"==={stat}===")
    display(con.execute(f"""WITH overs AS 
                            (SELECT Player, SUM({stat}_Diff) as O_Diff, count(*) as Hits FROM df WHERE {stat}_Result = 'O' GROUP BY Player)

                            SELECT overs.Player, Hits, Misses,
                            O_Diff + U_Diff as Diff,
                            hits / (misses + hits) AS Hit_Pct, misses / (misses + hits) AS Miss_Pct FROM
                           
                           (SELECT Player, SUM({stat}_Diff) as U_Diff, count(*) as Misses FROM df 
                           WHERE {stat}_Result = 'U' AND {stat}_line IS NOT NULL
                           GROUP BY Player) unders
                           
                           JOIN overs ON overs.Player = unders.Player
                           WHERE Hit_Pct <= 0.20
                           ORDER BY Hit_Pct
                           LIMIT 25""").fetchdf())
# Out:
# ===PTS===
#                 Player  Hits  Misses  Diff  Hit_Pct  Miss_Pct
# 0   Vince Williams Jr.     1       4 -18.5      0.2       0.8
# 1        Cedric Coward     1       4 -23.5      0.2       0.8
# 2           Kyle Kuzma     1       4 -10.5      0.2       0.8
# 3         Jake LaRavia     1       4 -12.5      0.2       0.8
# 4   Bennedict Mathurin     1       4 -24.5      0.2       0.8
# 5            Dean Wade     1       4  -9.5      0.2       0.8
# 6        Jarace Walker     1       4   2.5      0.2       0.8
# 7         Drew Eubanks     1       4 -11.5      0.2       0.8
# 8         Franz Wagner     1       4 -19.5      0.2       0.8
# 9         Terance Mann     1       4 -15.5      0.2       0.8
# 10      Ausar Thompson     1       4 -11.5      0.2       0.8
# ===AST===
#            Player  Hits  Misses  Diff   Hit_Pct  Miss_Pct
# 
['PTS', 'AST', 'REB', 'PR', 'PA', 'RA', 'PRA']:
    print(f"==={stat}===")
    display(con.execute(f"""SELECT game_id, Date, Team, B2B, Spread, Total, Player, Pos, MP, Opp, 
                            Off_{stat}, Off_L5_{stat}, AVG_{stat}_H2H, 
                            Def_{stat}, Def_L5_{stat}, {stat}_line, {stat}, 
                            {stat}_Diff, {stat}_Result FROM df
                            WHERE {stat}_line IS NOT NULL AND {stat}_Result = 'O'
                            ORDER BY {stat}_Diff DESC
                            LIMIT 15""").fetchdf())
# Out:
# ===PTS===
#              game_id        Date Team  B2B  Spread  Total  \
# 0   20251130_BOS_CLE  11/30/2025  BOS    1     7.5  234.5
# 1   20251120_PHI_MIL  11/20/2025  PHI    1     NaN    NaN
# 2   20251123_ORL_BOS  11/23/2025  ORL    1     NaN    NaN
# 3   20251120_ATL_SAS  11/20/2025  ATL    0     NaN    NaN
# 4   20251128_SAS_DEN  11/28/2025  SAS    0     7.5  238.5
# 5   20251130_MEM_SAC  11/30/2025  MEM    0    -2.5  233.5
# 6   20251125_ORL_PHI  11/25/2025  ORL    0     NaN    NaN
# 7   20251129_DAL_LAC  11/29/2025  DAL    1     8.5  223.5
# 8   20251130_ATL_PHI  11/30/2025  PHI    0    -2.5  232.5
# 9   20251123_LAC_CLE  11/23/2025  LAC    1     NaN    NaN
# 10  20251128_ORL_DET  11/28/2025  ORL    0     3.5  231.5
# 11  20251130_ATL_PHI  11/30/2025  ATL    0     2.5  232.5
# 12  20251128_DAL_LAL  11/28/2025  LAL    0    -9.5  232.5
# 13  20251123_BRK_TOR  11/23/2025  BRK    0     NaN    NaN
# 14  20251128_MEM_LAC  11/28/2025  LAC    0    -6.5  224.5
#
#                       Player Pos     MP  Opp    Off_PTS  Off_L5_PTS  \
# 0           Payton Pritchard  PG  30.73  CLE  16.210526        15.8
# 1               Tyrese Maxey  PG  46.63  MIL  31.928571        29.6
# 2                Jett Howard  SF  29.08  BOS   4.555556         5.8
# 3   Nickeil Alexander-Walker  SG  33.65  SAS  18.142857        19.2
# 4              Devin Vassell  SG  31.28  DEN  14.411765        16.2
# 5                  Zach Edey   C  29.43  SAC  11.000000        11.2
# 6              Anthony Black  PG  27.95  PHI  11.833333        15.2
# 7               Cooper Flagg  PG  37.95  LAC  15.736842        16.2
# 8               Tyrese Maxey  PG  52.30  ATL  31.666667        29.4
# 9                Ivica Zubac   C  32.92  CLE  16.000000        17.8
# 10              Desmond Bane  SG  39.28  DET  17.315789        19.6
# 11             Jalen Johnson  SF  45.12  PHI  22.368421        21.6
# 12             Austin Reaves  SG  41.32  DAL  27.857143        27.0
# 13             Tyrese Martin  SG  24.85  TOR   8.692308         9.4
# 14             Kawhi Leonard  SF  28.52  MEM  23.125000        23.6
#
#     AVG_PTS_H2H    Def_PTS  Def_L5_PTS  PTS_line  PTS  PTS_Diff PTS_Result
# 0      9.692308  17.466667        22.2      17.5   42      24.5          O
# 1     31.000000  20.642857        22.2      29.5   54      24.5          O
# 2      1.000000  17.428571        23.4       6.5   30      23.5          O
# 3      9.250000  16.363636        10.0      17.5   38      20.5          O
# 8    C  37.00  DAL  12.421053   10.200000    14.428571  9.823529        10.0
# 9    C  16.77  TOR   7.818182    6.800000          NaN  8.833333         9.6
# 10  SF  35.80  CHI   5.928571    5.400000     3.500000  5.250000         7.0
# 11   C  33.58  DAL  10.588235   14.000000          NaN  9.538462        10.4
# 12  SG  46.70  ATL   3.647059    2.800000     2.800000  3.833333         3.4
# 13  SF  37.67  CLE   5.842105    6.400000     5.250000  6.315789         7.6
# 14   C  26.47  DAL   7.333333    7.333333     6.500000  9.538462        10.4
#
#     REB_line  REB  REB_Diff REB_Result
# 0        6.5   19      12.5          O
# 1        4.5   13       8.5          O
# 2       10.5   19       8.5          O
# 3        5.5   14       8.5          O
# 4       10.5   19       8.5          O
# 5        4.5   12       7.5          O
# 6        5.5   13       7.5          O
# 7       10.5   18       7.5          O
# 8       12.5   20       7.5          O
# 9        7.5   15       7.5          O
# 10       5.5   12       6.5          O
# 11      11.5   18       6.5          O
# 12       3.5   10       6.5          O
# 13       5.5   12       6.5          O
# 14       9.5   15       5.5          O
# ===PR===
#              game_id        Date Team  B2B  Spread  Total  \
# 0   20251120_PHI_MIL  11/20/2025  PHI    1     NaN    NaN
# 1   20251130_MEM_SAC  11/30/2025  MEM    0    -2.5  233.5
# 2   20251123_LAC_CLE  11/23/2025  LAC    1     NaN    NaN
# 3   20251130_BOS_CLE  11/30/2025  BOS    1     7.5  234.5
# 4   20251120_ATL_SAS  11/20/2025  ATL    0     NaN    NaN
# 5   20251124_MIN_SAC  11/24/2025  SAC    0     NaN    NaN
# 6   20251128_ORL_DET  11/28/2025  ORL    0     3.5  231.5
# 7   20251201_CLE_IND  12/01/2025  CLE    1    -4.5  231.5
# 8   20251130_ATL_PHI  11/30/2025  ATL    0     2.5  232.5
# 9   20251130_ATL_PHI  11/30/2025  PHI    0    -2.5  232.5
# 10  20251128_DAL_LAL  11/28/2025  LAL    0    -9.5  232.5
# 11  20251130_ATL_PHI  11/30/2025  PHI    0    -2.5  232.5
# 12  20251130_OKC_POR  11/30/2025  POR    0    11.5  234.5
# 13  20251130_ATL_PHI  11/30/2025  ATL    0     2.5  232.5
# 14  20251129_DAL_LAC  11/29/2025  DAL    1     8.5  223.5
#
#                       Player Pos     MP  Opp     Off_PR  Off_L5_PR  \
# 0               Tyrese Maxey  PG  46.63  MIL  36.642857       33.8
# 1                  Zach Edey   C  29.43  SAC  21.285714       22.0
# 2                Ivica Zubac   C  32.92  CLE  27.187500       30.6
# 3           Payton Pritchard  PG  30.73  CLE  20.578947       21.4
# 4   Nickeil Alexander-Walker  SG  33.65  SAS  20.928571       22.4
# 5              Keegan Murray  PF  44.40  MIN  19.000000       19.0
# 6               Desmond Bane  SG  39.28  DET  21.631579       24.0
# 7               Jaylon Tyson  SG  30.78  IND  16.000000       18.0
# 8              Jalen Johnson  SF  45.12  PHI  32.421053       31.6
# 9               Tyrese Maxey  PG  52.30  ATL  36.333333       33.4
# 10             Austin Reaves  SG  41.32  DAL  33.571429       33.8
# 11            Quentin Grimes  SG  46.70  ATL  19.833333       17.8
# 12               Deni Avdija  SF  37.18  OKC  31.947368       32.0
# 13  Nickeil Alexander-Walker  SG  44.35  PHI  22.157895       25.6
# 14              Cooper Flagg  PG  37.95  LAC  22.210526       22.0
#
#     AVG_PR_H2H     Def_PR  Def_L5_PR  PR_line  PR  PR_Diff PR_Result
# 0    35.500000  26.214286       29.0     33.5  59     25.5         O
# 1          NaN  32.071429       32.4     24.5  49     24.5         O
# 2          NaN  25.500000       27.2     27.5  51     23.5         O
# 3    12.846154  21.466667       24.8     22.5  45     22.5         O
# 4    12.125000  20.272727       14.6     20.5  42     21.5         O
# 5    24.166667  24.600000       23.2     18.5  40     21.5         O
# 6    31.500000  19.950000       20.8     23.5  45     21.5         O
# 7     7.400000  20.476190       20.8     17.5  38     20.5         O
# 8    22.750000  24.166667       21.2     34.5  55     20.5         O
# 9    19.600000  25.357143       24.0     30.5  51     20.5         O
# 10   20.333333  22.000000       22.6     25.5  46     20.5         O
# 11   18.400000  21.555556       28.6     18.5  38     19.5         O
# 12   17.750000  23.700000       18.2     30.5  50     19.5         O
# 13   12.750000  20.909091       19.0     22.5  42     19.5         O
# 14         NaN  26.062500       30.4     23.5  43     19.5         O
# ===PA===
#              game_id        Date Team  B2B  Spread  Total  \
# 0   20251120_PHI_MIL  11/20/2025  PHI    1     NaN    NaN
# 1   20251120_ATL_SAS  11/20/2025  ATL    0     NaN    NaN
# 2   20251130_BOS_CLE  11/30/2025  BOS    1     7.5  234.5
# 3   20251120_PHI_MIL  11/20/2025  MIL    1     NaN    NaN
# 4   20251130_ATL_PHI  11/30/2025  PHI    0    -2.5  232.5
# 5   20251123_LAC_CLE  11/23/2025  LAC    1     NaN    NaN
# 6   20251125_ORL_PHI  11/25/2025  ORL    0     NaN    NaN
# 7   20251130_ATL_PHI  11/30/2025  ATL    0     2.5  232.5
# 8   20251128_SAC_UTA  11/28/2025  SAC    0     2.5  241.5
# 9   20251121_IND_CLE  11/21/2025  IND    0     NaN    NaN
# 10  20251201_HOU_UTA  12/01/2025  HOU    1   -11.5  233.5
# 11  20251128_SAS_DEN  11/28/2025  SAS    0     7.5  238.5
# 12  20251129_DET_MIA  11/29/2025  MIA    1     5.5  238.5
# 13  20251130_ATL_PHI  11/30/2025  ATL    0     2.5  232.5
# 14  20251201_MIL_WAS  12/01/2025  MIL    0   -10.5  231.5
#
#                       Player Pos     MP  Opp     Off_PA  Off_L5_PA  \
# 0               Tyrese Maxey  PG  46.63  MIL  39.714286       36.4
# 1   Nickeil Alexander-Walker  SG  33.65  SAS  21.714286       23.4
# 2           Payton Pritchard  PG  30.73  CLE  21.105263       20.4
# 3               Ryan Rollins  PG  40.45  PHI  22.733333       23.6
# 4               Tyrese Maxey  PG  52.30  ATL  39.166667       36.4
# 5                Ivica Zubac   C  32.92  CLE  18.250000       20.0
# 6              Anthony Black  PG  27.95  PHI  14.555556       19.0
# 7   Nickeil Alexander-Walker  SG  44.35  PHI  22.631579       25.2
# 8                Zach LaVine  SG  38.85  UTA  22.235294       15.8
# 3   Nickeil Alexander-Walker  SG  33.65  SAS  24.500000        26.6
# 4              Keegan Murray  PF  44.40  MIN  20.000000        20.0
# 5               Tyrese Maxey  PG  52.30  ATL  43.833333        40.4
# 6   Nickeil Alexander-Walker  SG  44.35  PHI  25.684211        29.0
# 7               Ryan Rollins  PG  40.45  PHI  26.466667        27.8
# 8            Cade Cunningham  PG  39.98  ORL  43.600000        50.6
# 9           Payton Pritchard  PG  30.73  CLE  25.473684        26.0
# 10             Austin Reaves  SG  41.32  DAL  40.571429        38.4
# 11            Andrew Wiggins  SF  36.87  DET  23.937500        22.2
# 12            Quentin Grimes  SG  46.70  ATL  24.166667        22.2
# 13             Jalen Johnson  SF  45.12  PHI  40.052632        40.8
# 14              Desmond Bane  SG  39.28  DET  26.263158        29.2
#
#     AVG_PRA_H2H    Def_PRA  Def_L5_PRA  PRA_line  PRA  PRA_Diff PRA_Result
# 0     41.166667  32.214286        35.0      40.5   68      27.5          O
# 1           NaN  28.428571        30.6      29.5   55      25.5          O
# 2     21.125000  26.400000        19.6      36.5   60      23.5          O
# 3     15.875000  24.545455        18.2      24.5   47      22.5          O
# 4     25.333333  27.466667        26.0      19.5   42      22.5          O
# 5     24.400000  32.357143        32.0      37.5   60      22.5          O
# 6     16.250000  24.818182        23.6      26.5   49      22.5          O
# 7      7.166667  29.416667        26.8      30.5   52      21.5          O
# 8     35.428571  35.058824        38.8      42.5   63      20.5          O
# 9     15.615385  28.200000        31.2      27.5   48      20.5          O
# 10    25.500000  25.800000        26.4      29.5   49      19.5          O
# 11          NaN  31.000000        32.4      21.5   41      19.5          O
# 12    21.000000  25.111111        32.2      22.5   42      19.5          O
# 13    26.500000  28.000000        25.2      42.5   62      19.5          O
# 14    36.500000  23.000000        23.6      28.5   47      18.5          O

# %%
for stat in ['PTS', 'AST', 'REB', 'PR', 'PA', 'RA', 'PRA']:
    print(f"==={stat}===")
    display(con.execute(f"""SELECT game_id, Date, Team, B2B, Spread, Total, Player, Pos, MP, Opp, 
                            Off_{stat}, Off_L5_{stat}, AVG_{stat}_H2H, 
                            Def_{stat}, Def_L5_{stat}, {stat}_line, {stat}, 
                            {stat}_Diff, {stat}_Result FROM df
                            WHERE {stat}_line IS NOT NULL AND {stat}_Result = 'U'
                            ORDER BY {stat}_Diff
                            LIMIT 15""").fetchdf())
# Out:
# ===PTS===
#              game_id        Date Team  B2B  Spread  Total            Player  \
# 0   20251129_NOP_GSW  11/29/2025  NOP    0     8.5  226.5   Trey Murphy III
# 1   20251121_POR_GSW  11/21/2025  POR    0     NaN    NaN      Jerami Grant
# 2   20251129_DAL_LAC  11/29/2025  DAL    1     8.5  223.5   P.J. Washington
# 3   20251121_DEN_HOU  11/21/2025  DEN    0     NaN    NaN      Aaron Gordon
# 4   20251201_LAC_MIA  12/01/2025  LAC    0     6.5  236.5      James Harden
# 5   20251201_PHO_LAL  12/01/2025  PHO    0     4.5  235.5      Devin Booker
# 6   20251201_DAL_DEN  12/01/2025  DEN    0   -11.5  235.5      Jamal Murray
# 7   20251121_DEN_HOU  11/21/2025  HOU    0     NaN    NaN      Kevin Durant
# 8   20251124_DEN_MEM  11/24/2025  DEN    0     NaN    NaN      Nikola Jokic
# 9   20251124_MIN_SAC  11/24/2025  SAC    0     NaN    NaN       Zach LaVine
# 10  20251124_CLE_TOR  11/24/2025  CLE    1     NaN    NaN  Donovan Mitchell
# 11  20251124_DAL_MIA  11/24/2025  DAL    0     NaN    NaN  D'Angelo Russell
# 12  20251124_POR_MIL  11/24/2025  MIL    1     NaN    NaN      Ryan Rollins
# 13  20251123_POR_OKC  11/23/2025  OKC    0     NaN    NaN     Chet Holmgren
# 14  20251123_POR_OKC  11/23/2025  POR    0     NaN    NaN       Deni Avdija
#
#    Pos     MP  Opp    Off_PTS  Off_L5_PTS  AVG_PTS_H2H    Def_PTS  Def_L5_PTS  \
# 0   SF   0.00  GSW  19.736842        19.8    21.000000  15.875000        17.2
# 1   PF  30.85  GSW  19.357143        18.2    14.166667  17.333333        13.0
# 2   PF   0.00  LAC  16.000000        18.8    11.636364  14.818182        14.8
# 3   PF   3.35  HOU  20.250000        20.0    10.400000  20.888889        19.0
# 4   PG  19.85  MIA  27.684211        31.0    23.000000  22.857143        22.6
# 5   SG   9.92  LAL  25.666667        21.2    24.857143  17.333333        14.4
# 6   PG  26.48  DAL  24.000000        27.8    22.428571  20.000000        19.8
# 7   SF  35.25  DEN  25.666667        27.8    29.000000  15.300000        16.0
# 8    C  33.72  MEM  30.375000        33.8    23.600000  18.500000        18.0
# 9   SG  31.82  MIN  21.400000        16.4          NaN  16.562500        14.6
# 10  SG  33.77  TOR  30.750000        31.4    21.428571  15.000000        20.4
# 11  PG   9.77  MIA  12.625000        15.2    12.800000  23.000000        20.6
# 12  PG  30.45  POR  18.647059        22.0          NaN  24.000000        24.8
# 13  PF  25.40  POR  18.583333        18.8    11.666667  18.769231        23.4
# 14  SF  23.77  OKC  25.937500        25.6    13.571429  19.285714        17.4
#
#     PTS_line  PTS  PTS_Diff PTS_Result
# 0       18.5    0     -18.5          U
# 1       22.5    5     -17.5          U
# 2       16.5    0     -16.5          U
# 3       16.5    1     -15.5          U
# 4       26.5   11     -15.5          U
# 5       26.5   11     -15.5          U
# 6       24.5   10     -14.5          U
# 7       26.5   13     -13.5          U
# 8       30.5   17     -13.5          U
# 9       20.5    7     -13.5          U
# 10      30.5   17     -13.5          U
# 11      12.5    0     -12.5          U
# 12      22.5   10     -12.5          U
# 13      17.5    5     -12.5          U
# 14      23.5   11     -12.5          U
# ===AST===
#              game_id        Date Team  B2B  Spread  Total  \
# 0   20251201_LAC_MIA  12/01/2025  LAC    0     6.5  236.5
# 1   20251123_POR_OKC  11/23/2025  POR    0     NaN    NaN
# 2   20251123_SAS_PHO  11/23/2025  SAS    0     NaN    NaN
# 3   20251201_PHO_LAL  12/01/2025  PHO    0     4.5  235.5
# 4   20251201_CLE_IND  12/01/2025  IND    1     4.5  231.5
# 5   20251128_ORL_DET  11/28/2025  ORL    0     3.5  231.5
# 6   20251128_WAS_IND  11/28/2025  IND    0    -6.5  238.5
# 7   20251129_BRK_MIL  11/29/2025  MIL    1   -10.5  217.5
# 8   20251120_ATL_SAS  11/20/2025  SAS    0     NaN    NaN
# 9   20251124_HOU_PHO  11/24/2025  PHO    0     NaN    NaN
# 10  20251124_UTA_GSW  11/24/2025  GSW    1     NaN    NaN
# 11  20251121_WAS_TOR  11/21/2025  TOR    0     NaN    NaN
# 12  20251124_NYK_BRK  11/24/2025  NYK    0     NaN    NaN
# 13  20251124_DET_IND  11/24/2025  DET    0     NaN    NaN
# 14  20251121_OKC_UTA  11/21/2025  UTA    0     NaN    NaN
#
#                    Player Pos     MP  Opp   Off_AST  Off_L5_AST  AVG_AST_H2H  \
# 0            James Harden  PG  19.85  MIA  8.684211         8.8    10.200000
# 1             Deni Avdija  SF  23.77  OKC  5.687500         8.0     3.714286
# 2            De'Aaron Fox  PG  33.38  PHO  6.571429         7.6     7.125000
# 3            Devin Booker  SG   9.92  LAL  6.857143         6.2     6.714286
# 4          T.J. McConnell  PG   5.93  CLE  4.600000         5.8     4.642857
# 5             Jalen Suggs  PG  33.93  DET  5.071429         6.6     3.142857
# 6           Pascal Siakam  PF  26.45  WAS  4.588235         3.4     6.166667
# 7   Giannis Antetokounmpo  PF  18.98  BRK  6.928571         8.2     5.666667
# 8            Kelly Olynyk   C  12.92  ATL  4.000000         4.0     3.250000
# 9        Collin Gillespie  PG  29.30  HOU  5.117647         4.8     2.000000
# 10          Stephen Curry  PG  29.05  UTA  4.384615         4.6     6.200000
# 11         Scottie Barnes  PF  29.90  WAS  5.266667         6.0     5.000000
# 12          Jalen Brunson  PG  32.73  BRK  6.769231         7.8     7.375000
# 13        Cade Cunningham  PG  35.80  IND  9.923077        10.4     8.375000
# 14         Isaiah Collier  PG  13.55  OKC  7.142857         8.0     4.000000
#
#      Def_AST  Def_L5_AST  AST_line  AST  AST_Diff AST_Result
# 0   7.500000         6.2       8.5    3      -5.5          U
# 1   3.428571         3.4       6.5    1      -5.5          U
# 2   6.642857         7.4       7.5    3      -4.5          U
# 3   3.750000         4.8       7.5    3      -4.5          U
# 4   6.500000         5.8       5.5    1      -4.5          U
# 5   5.437500         4.2       5.5    1      -4.5          U
# 6   2.461538         2.6       5.5    1      -4.5          U
# 7   5.000000         5.6       6.5    2      -4.5          U
# 8   3.454545         4.2       3.5    0      -3.5          U
# 9   7.600000         7.6       5.5    2      -3.5          U
# 10  7.571429         8.4       5.5    2      -3.5          U
# 11  2.636364         3.6       5.5    2      -3.5          U
# 12  5.900000         4.8       6.5    3      -3.5          U
# 13  6.000000         5.8       9.5    6      -3.5          U
# 14  5.461538         6.6       5.5    2      -3.5          U
# ===REB===
#              game_id        Date Team  B2B  Spread  Total           Player  \
# 0   20251128_PHI_BRK  11/28/2025  PHI    0    -6.5  221.5   Andre Drummond
# 1   20251123_ORL_BOS  11/23/2025  ORL    1     NaN    NaN     Goga Bitadze
# 2   20251124_DEN_MEM  11/24/2025  MEM    0     NaN    NaN        Zach Edey
# 3   20251129_DAL_LAC  11/29/2025  DAL    1     8.5  223.5  P.J. Washington
# 4   20251201_PHO_LAL  12/01/2025  LAL    0    -4.5  235.5     LeBron James
# 5   20251123_ORL_BOS  11/23/2025  BOS    1     NaN    NaN    Neemias Queta
# 6   20251121_MIA_CHI  11/21/2025  CHI    0     NaN    NaN   Nikola Vucevic
# 7   20251122_DET_MIL  11/22/2025  DET    0     NaN    NaN      Jalen Duren
# 8   20251124_HOU_PHO  11/24/2025  HOU    0     NaN    NaN   Alperen Sengun
# 9   20251121_DEN_HOU  11/21/2025  HOU    0     NaN    NaN   Alperen Sengun
# 10  20251123_LAL_UTA  11/23/2025  LAL    0     NaN    NaN    Deandre Ayton
# 11  20251130_MEM_SAC  11/30/2025  SAC    0     2.5  233.5    Keegan Murray
# 12  20251129_NOP_GSW  11/29/2025  NOP    0     8.5  226.5  Trey Murphy III
# 13  20251120_SAC_MEM  11/20/2025  MEM    1     NaN    NaN        Zach Edey
# 14  20251120_ATL_SAS  11/20/2025  SAS    0     NaN    NaN      Luke Kornet
#
#    Pos     MP  Opp    Off_REB  Off_L5_REB  AVG_REB_H2H    Def_REB  Def_L5_REB  \
# 0    C  10.52  BRK  10.687500       14.80     6.125000  10.454545        10.2
# 1    C   0.00  BOS   5.058824        5.40     4.333333  10.545455        10.2
# 2    C   5.68  DEN   9.250000        9.25          NaN   8.666667         7.6
# 3   PF   0.00  LAC   8.277778        8.80     6.454545   5.181818         5.8
# 4   SF  31.23  PHO   5.000000        5.00     7.000000   5.333333         6.0
# 5    C   5.85  ORL   8.312500        9.20     2.500000   9.600000        11.6
# 6    C  20.57  MIA   9.857143        8.60    10.875000  11.727273        11.2
# 7    C  27.35  MIL  11.923077       12.80     9.285714  10.428571         9.6
# 8    C  34.70  PHO   9.923077       10.20     8.000000  10.100000         9.6
# 9    C  36.15  DEN  10.333333       11.40     9.714286   9.125000         9.2
# 10   C  13.43  UTA   9.461538       10.20     7.500000  10.692308        10.6
# 11  PF  36.48  MEM   8.000000        8.00     6.833333   6.750000         5.6
# 12  SF   0.00  GSW   6.157895        4.40     6.000000   5.687500         6.8
# 13   C  24.83  SAC   9.000000        9.00          NaN  12.400000        13.0
# 14   C  22.98  ATL   7.166667        7.80     3.857143   9.636364         8.8
#
#     REB_line  REB  REB_Diff REB_Result
# 0       12.5    4      -8.5          U
# 1        8.5    0      -8.5          U
# 2        8.5    1      -7.5          U
# 3        7.5    0      -7.5          U
# 4        6.5    0      -6.5          U
# 5        8.5    2      -6.5          U
# 6       10.5    4      -6.5          U
# 7       12.5    6      -6.5          U
# 8       10.5    5      -5.5          U
# 9       10.5    5      -5.5          U
# 10       8.5    3      -5.5          U
# 11       7.5    2      -5.5          U
# 12       5.5    0      -5.5          U
# 13       9.5    4      -5.5          U
# 14       8.5    3      -5.5          U
# ===PR===
#              game_id        Date Team  B2B  Spread  Total            Player  \
# 0   20251129_DAL_LAC  11/29/2025  DAL    1     8.5  223.5   P.J. Washington
# 1   20251129_NOP_GSW  11/29/2025  NOP    0     8.5  226.5   Trey Murphy III
# 2   20251121_DEN_HOU  11/21/2025  DEN    0     NaN    NaN      Aaron Gordon
# 3   20251201_LAC_MIA  12/01/2025  LAC    0     6.5  236.5      James Harden
# 4   20251123_LAL_UTA  11/23/2025  LAL    0     NaN    NaN     Deandre Ayton
# 5   20251121_POR_GSW  11/21/2025  POR    0     NaN    NaN      Jerami Grant
# 6   20251121_MIA_CHI  11/21/2025  CHI    0     NaN    NaN    Nikola Vucevic
# 7   20251123_ORL_BOS  11/23/2025  ORL    1     NaN    NaN      Goga Bitadze
# 8   20251201_PHO_LAL  12/01/2025  PHO    0     4.5  235.5      Devin Booker
# 9   20251124_CLE_TOR  11/24/2025  CLE    1     NaN    NaN  Donovan Mitchell
# 10  20251201_CHO_BRK  12/01/2025  CHO    0    -4.5  229.5     Miles Bridges
# 11  20251129_BRK_MIL  11/29/2025  BRK    1    10.5  217.5      Noah Clowney
# 12  20251201_PHO_LAL  12/01/2025  LAL    0    -4.5  235.5      LeBron James
# 13  20251201_CHI_ORL  12/01/2025  CHI    0     9.5  239.5     Kevin Huerter
# 14  20251120_SAC_MEM  11/20/2025  SAC    1     NaN    NaN     DeMar DeRozan
#
#    Pos     MP  Opp     Off_PR  Off_L5_PR  AVG_PR_H2H     Def_PR  Def_L5_PR  \
# 0   PF   0.00  LAC  23.842105       27.6   18.090909  20.000000       20.6
# 1   SF   0.00  GSW  25.894737       24.2   27.000000  21.562500       24.0
# 2   PF   3.35  HOU  26.500000       27.0   16.800000  26.444444       23.0
# 3   PG  19.85  MIA  33.578947       36.0   29.400000  29.928571       29.0
# 4    C  13.43  UTA  25.285714       26.2   18.750000  28.153846       33.0
# 5   PF  30.85  GSW  22.785714       22.0   16.333333  23.083333       18.2
# 6    C  20.57  MIA  26.500000       23.2   27.500000  31.636364       38.0
# 7    C   0.00  BOS  11.235294       11.8    7.916667  28.090909       23.6
# 8   SG   9.92  LAL  30.095238       26.6   29.571429  21.416667       17.6
# 9   SG  33.77  TOR  35.750000       37.4   26.285714  18.647059       24.2
# 10  PF  30.38  BRK  28.700000       27.4   25.375000  25.500000       23.6
# 11  PF  21.37  MIL  16.166667       23.4   11.333333  25.166667       20.4
# 12  SF  31.23  PHO  21.500000       21.5   28.500000  20.733333       20.2
# 13  SF   5.68  ORL  16.055556        9.8         NaN  25.368421       26.2
# 14  PF  15.37  MEM  21.933333       16.6   29.800000  25.083333       26.4
#
#     PR_line  PR  PR_Diff PR_Result
# 0      24.5   0    -24.5         U
# 1      23.5   0    -23.5         U
# 2      23.5   3    -20.5         U
# 3      32.5  13    -19.5         U
# 4      23.5   5    -18.5         U
# 5      27.5   9    -18.5         U
# 6      27.5  10    -17.5         U
# 7      17.5   0    -17.5         U
# 8      30.5  13    -17.5         U
# 9      34.5  18    -16.5         U
# 10     26.5  10    -16.5         U
# 11     23.5   7    -16.5         U
# 12     26.5  10    -16.5         U
# 13     15.5   0    -15.5         U
# 14     22.5   7    -15.5         U
# ===PA===
#              game_id        Date Team  B2B  Spread  Total            Player  \
# 0   20251201_LAC_MIA  12/01/2025  LAC    0     6.5  236.5      James Harden
# 1   20251129_NOP_GSW  11/29/2025  NOP    0     8.5  226.5   Trey Murphy III
# 2   20251201_PHO_LAL  12/01/2025  PHO    0     4.5  235.5      Devin Booker
# 3   20251121_DEN_HOU  11/21/2025  DEN    0     NaN    NaN      Aaron Gordon
# 4   20251129_DAL_LAC  11/29/2025  DAL    1     8.5  223.5   P.J. Washington
# 5   20251121_POR_GSW  11/21/2025  POR    0     NaN    NaN      Jerami Grant
# 6   20251123_POR_OKC  11/23/2025  POR    0     NaN    NaN       Deni Avdija
# 7   20251124_DAL_MIA  11/24/2025  DAL    0     NaN    NaN  D'Angelo Russell
# 8   20251124_MIN_SAC  11/24/2025  SAC    0     NaN    NaN       Zach LaVine
# 9   20251125_ORL_PHI  11/25/2025  PHI    0     NaN    NaN      Tyrese Maxey
# 10  20251129_NOP_GSW  11/29/2025  NOP    0     8.5  226.5       Derik Queen
# 11  20251121_DEN_HOU  11/21/2025  HOU    0     NaN    NaN      Kevin Durant
# 12  20251201_CHI_ORL  12/01/2025  CHI    0     9.5  239.5     Kevin Huerter
# 13  20251201_PHO_LAL  12/01/2025  LAL    0    -4.5  235.5      LeBron James
# 14  20251201_CHO_BRK  12/01/2025  CHO    0    -4.5  229.5     Miles Bridges
#
#    Pos     MP  Opp     Off_PA  Off_L5_PA  AVG_PA_H2H     Def_PA  Def_L5_PA  \
# 0   PG  19.85  MIA  36.368421      39.80   33.200000  30.357143       28.8
# 1   SF   0.00  GSW  22.947368      23.20   24.500000  18.937500       22.4
# 2   SG   9.92  LAL  32.523810      27.40   31.571429  21.083333       19.2
# 3   PF   3.35  HOU  21.666667      21.00   14.600000  22.888889       20.4
# 4   PF   0.00  LAC  18.263158      21.00   12.818182  17.181818       16.2
# 5   PF  30.85  GSW  21.785714      21.00   16.500000  19.833333       14.8
# 6   SF  23.77  OKC  31.625000      33.60   17.285714  22.714286       20.8
# 7   PG   9.77  MIA  17.625000      20.40   16.200000  31.090909       29.4
# 8   SG  31.82  MIN  23.666667      19.00         NaN  21.000000       18.6
# 9   PG  31.97  ORL  40.750000      41.60   31.142857  30.875000       34.2
# 10   C  15.88  GSW  15.842105      23.80         NaN  23.461538       24.0
# 11  SF  35.25  DEN  29.083333      32.40   34.333333  18.200000       19.0
# 12  SF   5.68  ORL  15.166667      10.00         NaN  23.000000       25.2
# 13  SF  31.23  PHO  24.750000      24.75   30.625000  18.533333       17.4
# 14  PF  30.38  BRK  26.000000      25.80   20.375000  23.100000       21.6
#
#     PA_line  PA  PA_Diff PA_Result
# 0      35.5  14    -21.5         U
# 1      21.5   0    -21.5         U
# 2      33.5  14    -19.5         U
# 3      19.5   1    -18.5         U
# 4      18.5   0    -18.5         U
# 5      25.5   7    -18.5         U
# 6      30.5  12    -18.5         U
# 7      17.5   2    -15.5         U
# 8      23.5   8    -15.5         U
# 9      39.5  24    -15.5         U
# 10     16.5   2    -14.5         U
# 11     29.5  15    -14.5         U
# 12     14.5   0    -14.5         U
# 13     27.5  13    -14.5         U
# 14     23.5   9    -14.5         U
# ===RA===
#              game_id        Date Team  B2B  Spread  Total  \
# 0   20251123_ORL_BOS  11/23/2025  ORL    1     NaN    NaN
# 1   20251201_PHO_LAL  12/01/2025  LAL    0    -4.5  235.5
# 2   20251201_LAC_MIA  12/01/2025  LAC    0     6.5  236.5
# 3   20251129_DAL_LAC  11/29/2025  DAL    1     8.5  223.5
# 4   20251129_NOP_GSW  11/29/2025  NOP    0     8.5  226.5
# 5   20251123_ORL_BOS  11/23/2025  BOS    1     NaN    NaN
# 6   20251129_TOR_CHO  11/29/2025  CHO    0     6.5  234.5
# 7   20251124_HOU_PHO  11/24/2025  HOU    0     NaN    NaN
# 8   20251123_POR_OKC  11/23/2025  POR    0     NaN    NaN
# 9   20251129_BRK_MIL  11/29/2025  MIL    1   -10.5  217.5
# 10  20251124_CHI_NOP  11/24/2025  NOP    0     NaN    NaN
# 11  20251129_DEN_PHO  11/29/2025  PHO    1     2.5  230.5
# 12  20251129_NOP_GSW  11/29/2025  NOP    0     8.5  226.5
# 13  20251201_CHO_BRK  12/01/2025  CHO    0    -4.5  229.5
# 14  20251129_BRK_MIL  11/29/2025  BRK    1    10.5  217.5
#
#                    Player Pos     MP  Opp     Off_RA  Off_L5_RA  AVG_RA_H2H  \
# 0            Goga Bitadze   C   0.00  BOS   6.529412       7.40    5.416667
# 1            LeBron James  SF  31.23  PHO  13.250000      13.25   16.125000
# 2            James Harden  PG  19.85  MIA  14.578947      13.80   16.600000
# 3         P.J. Washington  PF   0.00  LAC  10.666667      11.00    7.636364
# 4         Trey Murphy III  SF   0.00  GSW   9.368421       7.80    9.500000
# 5           Neemias Queta   C   5.85  ORL  10.125000      11.60    3.083333
# 6           Miles Bridges  PF  41.43  TOR  10.263158       8.40   10.833333
# 7          Alperen Sengun   C  34.70  PHO  17.230769      17.40   11.714286
# 8             Deni Avdija  SF  23.77  OKC  12.375000      15.60    8.142857
# 9   Giannis Antetokounmpo  PF  18.98  BRK  18.071429      17.20   16.833333
# 10        Zion Williamson  PF  29.62  CHI  10.428571       8.40         NaN
# 11       Collin Gillespie  PG  28.65  DEN   9.100000       8.80         NaN
# 12            Derik Queen   C  15.88  GSW   9.842105      12.60         NaN
# 13          Miles Bridges  PF  30.38  BRK   9.900000       7.60   10.250000
# 14           Terance Mann  SG  21.08  MIL   7.588235       9.60    4.800000
#
#        Def_RA  Def_L5_RA  RA_line  RA  RA_Diff RA_Result
# 0   14.000000       13.8     10.5   0    -10.5         U
# 1    8.466667        9.2     13.5   3    -10.5         U
# 2   14.571429       12.6     14.5   5     -9.5         U
# 3    7.545455        7.2      9.5   0     -9.5         U
# 4    8.750000       12.0      8.5   0     -8.5         U
# 5   11.733333       14.0     10.5   2     -8.5         U
# 6   10.421053        7.0     10.5   3     -7.5         U
# 7   14.400000       13.2     17.5  10     -7.5         U
# 8   10.000000        9.0     13.5   6     -7.5         U
# 9   12.400000       13.2     17.5  10     -7.5         U
# 10  10.214286        8.8     10.5   3     -7.5         U
# 11  12.285714       11.0      9.5   2     -7.5         U
# 12  13.923077       13.2     10.5   3     -7.5         U
# 13  12.400000       13.2     10.5   3     -7.5         U
# 14   8.058824        8.4      8.5   2     -6.5         U
# ===PRA===
#              game_id        Date Team  B2B  Spread  Total           Player  \
# 0   20251129_NOP_GSW  11/29/2025  NOP    0     8.5  226.5  Trey Murphy III
# 1   20251129_DAL_LAC  11/29/2025  DAL    1     8.5  223.5  P.J. Washington
# 2   20251201_LAC_MIA  12/01/2025  LAC    0     6.5  236.5     James Harden
# 3   20251121_DEN_HOU  11/21/2025  DEN    0     NaN    NaN     Aaron Gordon
# 4   20251201_PHO_LAL  12/01/2025  PHO    0     4.5  235.5     Devin Booker
# 5   20251123_POR_OKC  11/23/2025  POR    0     NaN    NaN      Deni Avdija
# 6   20251201_PHO_LAL  12/01/2025  LAL    0    -4.5  235.5     LeBron James
# 7   20251201_CHO_BRK  12/01/2025  CHO    0    -4.5  229.5    Miles Bridges
# 8   20251123_ORL_BOS  11/23/2025  ORL    1     NaN    NaN     Goga Bitadze
# 9   20251124_DEN_MEM  11/24/2025  MEM    0     NaN    NaN        Zach Edey
# 10  20251121_POR_GSW  11/21/2025  POR    0     NaN    NaN     Jerami Grant
# 11  20251129_NOP_GSW  11/29/2025  NOP    0     8.5  226.5      Derik Queen
# 12  20251125_ORL_PHI  11/25/2025  PHI    0     NaN    NaN     Tyrese Maxey
# 13  20251201_CHI_ORL  12/01/2025  CHI    0     9.5  239.5    Kevin Huerter
# 14  20251121_MIA_CHI  11/21/2025  CHI    0     NaN    NaN   Nikola Vucevic
#
#    Pos     MP  Opp    Off_PRA  Off_L5_PRA  AVG_PRA_H2H    Def_PRA  Def_L5_PRA  \
# 0   SF   0.00  GSW  29.105263       27.60    30.500000  24.625000        29.2
# 1   PF   0.00  LAC  26.105263       29.80    19.272727  22.363636        22.0
# 2   PG  19.85  MIA  42.263158       44.80    39.600000  37.428571        35.2
# 3   PF   3.35  HOU  27.916667       28.00    21.000000  28.444444        24.4
# 4   SG   9.92  LAL  36.952381       32.80    36.285714  25.166667        22.4
# 5   SF  23.77  OKC  38.312500       41.20    21.714286  29.285714        26.4
# 6   SF  31.23  PHO  29.750000       29.75    37.625000  23.866667        23.4
# 7   PF  30.38  BRK  32.300000       30.40    28.000000  30.500000        29.2
# 8    C   0.00  BOS  12.705882       13.80     9.000000  31.545455        27.2
# 9    C   5.68  DEN  22.750000       22.75          NaN  28.111111        29.4
# 10  PF  30.85  GSW  25.214286       24.80    18.666667  25.583333        20.0
# 11   C  15.88  GSW  22.105263       30.20          NaN  33.153846        33.4
# 12  PG  31.97  ORL  45.375000       45.60    34.714286  35.687500        38.8
# 13  SF   5.68  ORL  18.611111       11.80          NaN  28.842105        30.0
# 14   C  20.57  MIA  30.071429       27.00    31.000000  35.000000        42.8
#
#     PRA_line  PRA  PRA_Diff PRA_Result
# 0       26.5    0     -26.5          U
# 1       26.5    0     -26.5          U
# 2       41.5   16     -25.5          U
# 3       25.5    3     -22.5          U
# 4       37.5   16     -21.5          U
# 5       37.5   17     -20.5          U
# 6       33.5   13     -20.5          U
# 7       30.5   11     -19.5          U
# 8       19.5    0     -19.5          U
# 9       22.5    3     -19.5          U
# 10      30.5   11     -19.5          U
# 11      23.5    5     -18.5          U
# 12      43.5   25     -18.5          U
# 13      18.5    0     -18.5          U
# 14      31.5   13     -18.5          U
