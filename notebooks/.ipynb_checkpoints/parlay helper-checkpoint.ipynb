# %%
import pandas as pd
import numpy as np
from datetime import datetime
from nbainjuries import injury
from datetime import timedelta
import warnings
import duckdb
import os
import requests

cwd = os.path.abspath(os.getcwd()).replace("\\", "/")
if cwd.startswith("C:/Users/Rodolfo/"):
    RUN_LOCATION = "local"
else:
    RUN_LOCATION = "cloud"
time_offset = {"local": 3, "cloud": -5}

print("Current working dir:", cwd)
print("RUN_LOCATION =", RUN_LOCATION)
# Out:
# Current working dir: C:/Users/Rodolfo/Jupyter_files/FantasyBasketball/notebooks
# RUN_LOCATION = local

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
warnings.filterwarnings("ignore")

year = 2025
now = str((datetime.now() + timedelta(hours=time_offset[RUN_LOCATION]) + timedelta(hours=-3)).date())
print(f"Today's date:", now)

con = duckdb.connect(database=":memory:")
categories = ['PTS', 'AST', 'REB', 'PR', 'PA', 'RA', 'PRA', 'TPM', 'STL', 'BLK', 'STL_BLK']

folders = os.listdir('../tables/')
df = pd.DataFrame()
for yr in folders:
    df_temp = pd.read_csv(f"../tables/{yr}/season_gamelogs.csv")
    df_temp.insert(0, 'Season', int(yr))
    df = pd.concat([df, df_temp])
df['Date'] = pd.to_datetime(df.Date)
df = df.rename(columns={"TRB": "REB", "3PM": "TPM", "3PA": "TPA"})
df['STL_BLK'] = df.STL + df.BLK
df['PR'] = df.PTS + df.REB 
df['PA'] = df.PTS + df.AST
df['RA'] = df.REB + df.AST
df['PRA'] = df.PTS + df.REB + df.AST

# # CONTROL DATE TO GO BACK AND RELOAD HISTORICAL DATA
# df = df[(df.Date != now)]
# Out:
# Today's date: 2025-12-29

# %%
# %run ./common_utils.ipynb

# %%
df_gms = pd.read_csv(f"../tables/{year}/nba_schedule.csv")
df_gms['Date'] = pd.to_datetime(df_gms.Date)
df_gms = df_gms[(df_gms.Date == now)]
tms_today = df_gms.AwayABV.tolist() + df_gms.HomeABV.tolist()
df_gms['gm_id'] = df_gms.AwayABV + "_" + df_gms.HomeABV
df_gms['gm_id2'] = df_gms.HomeABV + "_" + df_gms.AwayABV
gms_today = df_gms.gm_id.tolist() + df_gms.gm_id2.tolist()
df_gms = df_gms.drop(['gm_id', 'gm_id2'], axis=1)
display(df_gms)
# Out:
#           Date StartTime_ET                AwayTeam AwayABV  AwayPTS  \
# 473 2025-12-29        7:00p         Milwaukee Bucks     MIL      NaN
# 474 2025-12-29        7:00p            Phoenix Suns     PHO      NaN
# 475 2025-12-29        7:30p   Golden State Warriors     GSW      NaN
# 476 2025-12-29        7:30p          Denver Nuggets     DEN      NaN
# 477 2025-12-29        7:30p           Orlando Magic     ORL      NaN
# 478 2025-12-29        8:00p  Minnesota Timberwolves     MIN      NaN
# 479 2025-12-29        8:00p          Indiana Pacers     IND      NaN
# 480 2025-12-29        8:00p         New York Knicks     NYK      NaN
# 481 2025-12-29        8:00p           Atlanta Hawks     ATL      NaN
# 482 2025-12-29        8:00p     Cleveland Cavaliers     CLE      NaN
# 483 2025-12-29       10:30p        Dallas Mavericks     DAL      NaN
#
#                    HomeTeam HomeABV  HomePTS  is_OT                 Arena  \
# 473       Charlotte Hornets     CHO      NaN      0       Spectrum Center
# 474      Washington Wizards     WAS      NaN      0     Capital One Arena
# 475           Brooklyn Nets     BRK      NaN      0       Barclays Center
# 476              Miami Heat     MIA      NaN      0         Kaseya Center
# 477         Toronto Raptors     TOR      NaN      0      Scotiabank Arena
# 478           Chicago Bulls     CHI      NaN      0         United Center
# 479         Houston Rockets     HOU      NaN      0         Toyota Center
# 480    New Orleans Pelicans     NOP      NaN      0  Smoothie King Center
# 481   Oklahoma City Thunder     OKC      NaN      0         Paycom Center
# 482       San Antonio Spurs     SAS      NaN      0     Frost Bank Center
# 483  Portland Trail Blazers     POR      NaN      0           Moda Center
#
#      AwayB2B  HomeB2B  cup_gm  pstszn_gm  rtrvd
# 473        0        0       0          0      0
# 474        0        1       0          0      0
# 475        1        0       0          0      0
# 476        0        0       0          0      0
# 477        0        1       0          0      0
# 478        0        0       0          0      0
# 479        0        0       0          0      0
# 480        0        0       0          0      0
# 481        0        1       0          0      0
# 482        0        0       0          0      0
# 483        0        1       0          0      0

# %%
df_teams = pd.read_csv("../src/team_info_xref.csv")

df_inj = injury.get_reportdata(datetime.now() + timedelta(hours=time_offset[RUN_LOCATION]), return_df=True)
df_inj = df_inj.rename(columns={"Game Date": "Date", "Player Name": "Player", "Current Status": "Status"})
df_inj['Player'] = df_inj.Player.str.split(",").str[1] + " " + df_inj.Player.str.split(",").str[0]
df_inj['Player'] = df_inj['Player'].str.strip()
df_inj['Date'] = pd.to_datetime(df_inj['Date'])
df_inj = con.execute(f"""SELECT Date, ABV as Team, Player, Status, Reason FROM df_inj 
                         JOIN df_teams ON df_inj.Team = df_teams.Team
                         WHERE Date = '{now}' AND Status != 'Available'""").fetchdf()
partition_save_df(df_inj, f"../tables/{year}/injuries.csv")

df_best_out = con.execute(f"""SELECT *, RANK() OVER (PARTITION BY Pos ORDER BY Fpts DESC) as Off_Rk FROM
                              (SELECT Team, Player, Pos, AVG(Fpts) as Fpts FROM df 
                              WHERE Season = {year} AND Fpts > 0 AND Pos != 'None'
                              GROUP BY Team, Player, Pos)""").fetchdf()
df_best_out = con.execute(f"""SELECT * EXCLUDE(t2.Team, t2.Player) FROM df_best_out t1 
                              JOIN df_inj t2 ON t1.Team = t2.Team AND t1.Player = t2.Player
                              WHERE Status = 'Out'
                              ORDER BY Fpts DESC""").fetchdf()
display(df_best_out)
# Out:
# Validated Injury-Report_2025-12-29_06_30PM.
# ../tables/2025/injuries.csv saved!
#    Team                Player Pos       Fpts  Off_Rk       Date Status  \
# 0   ATL         Jalen Johnson  SF  33.083333       1 2025-12-29    Out
# 1   HOU        Alperen Sengun   C  30.076923       3 2025-12-29    Out
# 2   POR          Jrue Holiday  PG  24.208333      13 2025-12-29    Out
# 3   ORL          Franz Wagner  SF  23.145833       9 2025-12-29    Out
# 4   ATL    Kristaps Porzingis   C  22.500000      12 2025-12-29    Out
# 5   MIA           Tyler Herro  SG  22.000000       6 2025-12-29    Out
# 6   NYK             Josh Hart  SF  21.534483      13 2025-12-29    Out
# 7   OKC    Isaiah Hartenstein   C  20.937500      20 2025-12-29    Out
# 8   ATL            Trae Young  PG  20.850000      20 2025-12-29    Out
# 9   WAS        Kyshawn George  SF  20.129630      15 2025-12-29    Out
# 10  TOR            RJ Barrett  SF  19.666667      16 2025-12-29    Out
# 11  CHO          Kon Knueppel  SF  19.548387      17 2025-12-29    Out
# 12  PHO         Mark Williams   C  19.518519      23 2025-12-29    Out
# 13  ORL           Jalen Suggs  PG  19.333333      22 2025-12-29    Out
# 14  PHO         Grayson Allen  SG  18.888889      15 2025-12-29    Out
# 15  DEN          Aaron Gordon  PF  18.769231      19 2025-12-29    Out
# 16  POR          Jerami Grant  PF  18.423077      20 2025-12-29    Out
# 17  IND            Obi Toppin  PF  15.833333      25 2025-12-29    Out
# 18  TOR          Jakob Poeltl   C  15.809524      33 2025-12-29    Out
# 19  NYK     Mitchell Robinson   C  15.739130      34 2025-12-29    Out
# 20  CHO      Ryan Kalkbrenner   C  15.307692      37 2025-12-29    Out
# 21  NOP         Herbert Jones  SF  14.318182      35 2025-12-29    Out
# 22  PHO           Jalen Green  SG  14.250000      30 2025-12-29    Out
# 23  DEN       Christian Braun  SG  14.227273      31 2025-12-29    Out
# 24  WAS       Khris Middleton  SF  13.675000      36 2025-12-29    Out
# 25  DEN       Cameron Johnson  SF  13.589286      37 2025-12-29    Out
# 26  PHO             Ryan Dunn  SF  13.560000      38 2025-12-29    Out
# 27  GSW            Al Horford   C  13.200000      47 2025-12-29    Out
# 28  IND        Isaiah Jackson   C  13.000000      48 2025-12-29    Out
# 29  CHI          Zach Collins   C  12.700000      51 2025-12-29    Out
# 30  NOP         Jose Alvarado  PG  12.274194      40 2025-12-29    Out
# 31  DAL      Dereck Lively II   C  12.142857      53 2025-12-29    Out
# 32  OKC       Jaylin Williams  PF  11.820000      42 2025-12-29    Out
# 33  POR          Blake Wesley  SG  11.166667      53 2025-12-29    Out
# 34  WAS          Cam Whitmore  SF  10.868421      48 2025-12-29    Out
# 35  IND          Ben Sheppard  SG  10.704545      58 2025-12-29    Out
# 36  WAS         Corey Kispert  SF  10.617647      49 2025-12-29    Out
# 37  NYK         Landry Shamet  SG   9.500000      69 2025-12-29    Out
# 38  POR      Matisse Thybulle  SG   9.500000      69 2025-12-29    Out
# 39  BRK             Ben Saraf  SG   9.000000      72 2025-12-29    Out
# 40  MIL        Taurean Prince  SF   8.928571      55 2025-12-29    Out
# 41  CLE       Larry Nance Jr.  PF   8.392857      60 2025-12-29    Out
# 42  OKC         Ousmane Dieng   C   5.588235      73 2025-12-29    Out
# 43  CHO         Mason Plumlee   C   5.538462      74 2025-12-29    Out
# 44  MIN  Terrence Shannon Jr.  SG   5.342105      96 2025-12-29    Out
# 45  ATL          N'Faly Dante   C   3.833333      80 2025-12-29    Out
# 46  CHI          Noa Essengue  PF   2.000000      80 2025-12-29    Out
#
#                                                        Reason
# 0                               Injury/Illness - N/A; Illness
# 1                        Injury/Illness - Left Soleus; Strain
# 2                         Injury/Illness - Right Calf; Strain
# 3                    Injury/Illness - Left High Ankle; Sprain
# 4                               Injury/Illness - N/A; Illness
# 5                   Injury/Illness - Right Big Toe; Contusion
# 6                        Injury/Illness - Right Ankle; Sprain
# 7                       Injury/Illness - Right Soleus; Strain
# 8                      Injury/Illness - Right Quad; Contusion
# 9                    Injury/Illness - Left Hip Flexor; Strain
# 10    Injury/Illness - Right Knee; Sprain - injury management
# 11                       Injury/Illness - Right Ankle; Sprain
# 12                                          League Suspension
# 13                       Injury/Illness - Left Hip; Contusion
# 14             Injury/Illness - Right Knee; Injury management
# 15                   Injury/Illness - Right Hamstring; Strain
# 16                 Injury/Illness - Left Achilles; Tendonitis
# 17               Injury/Illness - Right Foot; Stress Fracture
# 18                       Injury/Illness - Back; Lower; strain
# 19  Injury/Illness - Left Ankle; Left Ankle Injury Management
# 20                        Injury/Illness - Left Elbow; Sprain
# 21                       Injury/Illness - Right Ankle; Sprain
# 22                   Injury/Illness - Right Hamstring; Strain
# 23                        Injury/Illness - Left Ankle; Sprain
# 24             Injury/Illness - Right Knee; Injury Management
# 25             Injury/Illness - Right Knee; Injury Management
# 26                      Injury/Illness - Right Knee; Soreness
# 27               Injury/Illness - Left Toe; Injury Management
# 28                           Injury/Illness - N/A; Concussion
# 29                   Injury/Illness - Right 1st Toe; Soreness
# 30                                          League Suspension
# 31                       Injury/Illness - Right Foot; Surgery
# 32                      Injury/Illness - Right Heel; Bursitis
# 33                      Injury/Illness - Right Foot; Fracture
# 34      Injury/Illness - Right Shoulder; Deep Vein Thrombosis
# 35                         Injury/Illness - Left Calf; Strain
# 36                    Injury/Illness - Left Hamstring; Strain
# 37                    Injury/Illness - Right Shoulder; Sprain
# 38                 Injury/Illness - Left Thumb; Ligament Tear
# 39                                   G League - On Assignment
# 40                             Injury/Illness - Neck; Surgery
# 41                        Injury/Illness - Right Calf; Strain
# 42                        Injury/Illness - Right Calf; Strain
# 43                       Injury/Illness - Right Groin; Strain
# 44       Injury/Illness - Left Foot; Abductor Hallucis Strain
# 45                      Injury/Illness - Right Knee; Torn ACL
# 46                    Injury/Illness - Left Shoulder; Surgery

# %%
def get_game_odds():

    dk_tm_mapping = {
                    "ATL Hawks": "ATL", "BKN Nets": "BRK", "BOS Celtics": "BOS", "CHA Hornets": "CHO", "CHI Bulls": "CHI",
                    "CLE Cavaliers": "CLE", "DAL Mavericks": "DAL", "DEN Nuggets": "DEN", "DET Pistons": "DET", 
                    "GS Warriors": "GSW", "HOU Rockets": "HOU", "IND Pacers": "IND", "LA Clippers": "LAC", 
                    "LA Lakers": "LAL", "MEM Grizzlies": "MEM", "MIA Heat": "MIA", "MIL Bucks": "MIL", "MIN Timberwolves": "MIN",
                    "NO Pelicans": "NOP", "NY Knicks": "NYK", "OKC Thunder": "OKC", "ORL Magic": "ORL", "PHI 76ers": "PHI",
                    "PHO Suns": "PHO", "POR Trail Blazers": "POR", "SA Spurs": "SAS", "SAC Kings": "SAC", "TOR Raptors": "TOR",
                    "UTA Jazz": "UTA", "WAS Wizards": "WAS", "GSW Warriors": "GSW", "LAL Lakers": "LAL", "NOP Pelicans": "NOP",
                    "NYK Knicks": "NYK", "PHX Suns": "PHO", "SAS Spurs": "SAS"
                    }

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Accept": "*/*",
        "Accept-Language": "en-US,en;q=0.9",
        "Referer": "https://sportsbook.draftkings.com/",
        "Origin": "https://sportsbook.draftkings.com"
    }
    response = requests.get(f"https://sportsbook-nash.draftkings.com/sites/US-SB/api/sportscontent/controldata/league/leagueSubcategory/v1/markets?isBatchable=false&templateVars=42648%2C4511&eventsQuery=%24filter%3DleagueId%20eq%20%2742648%27%20AND%20clientMetadata%2FSubcategories%2Fany%28s%3A%20s%2FId%20eq%20%274511%27%29&marketsQuery=%24filter%3DclientMetadata%2FsubCategoryId%20eq%20%274511%27%20AND%20tags%2Fall%28t%3A%20t%20ne%20%27SportcastBetBuilder%27%29&include=Events&entity=events", headers=headers)
    if response.status_code != 200:
        raise Exception('Bad Request')

    ids = []
    rows = []
    for i in range(len(response.json()['selections'])):
        if 'HC' in response.json()['selections'][i]['id'] or 'OU' in response.json()['selections'][i]['id']:
            ids.append(response.json()['selections'][i])
    for i in range(0, len(ids) - 1, 4):
        team1 = ids[i]['label']
        spread1 = ids[i]['points']
        team2 = ids[i+1]['label']
        spread2 = ids[i+1]['points']
        total = ids[i+2]['points']
        rows.append({"Team": team1, "Opp": team2, "Spread": spread1, "Total": total})
        rows.append({"Team": team2, "Opp": team1, "Spread": spread2, "Total": total})
    df_tm_bets = pd.DataFrame(rows)
    
    for key, value in dk_tm_mapping.items():
        df_tm_bets['Team'] = np.where(df_tm_bets.Team == key, value, df_tm_bets.Team)
        df_tm_bets['Opp'] = np.where(df_tm_bets.Opp == key, value, df_tm_bets.Opp)

    df_tm_bets['gm_id'] = df_tm_bets.Team + "_" + df_tm_bets.Opp
    df_tm_bets = df_tm_bets[(df_tm_bets.gm_id.isin(gms_today))].drop(['Opp', 'gm_id'], axis=1)
    
    return df_tm_bets

def get_sportsbook():
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Accept": "*/*",
        "Accept-Language": "en-US,en;q=0.9",
        "Referer": "https://sportsbook.draftkings.com/",
        "Origin": "https://sportsbook.draftkings.com"
    }

    dk_cats = {"PTS": 12488, "AST": 12495, "REB": 12492, "STL": 13508, "BLK": 13780, "STL_BLK": 13781, "TPM": 12497, 
               "PA": 9973, "PR": 9976, "RA": 9974, "PRA": 5001}
    df_lines = pd.DataFrame()
    for key, value in dk_cats.items():
        response = requests.get(f"https://sportsbook-nash.draftkings.com/sites/US-SB/api/sportscontent/controldata/league/leagueSubcategory/v1/markets?isBatchable=false&templateVars=42648%2C{value}&eventsQuery=%24filter%3DleagueId%20eq%20%2742648%27%20AND%20clientMetadata%2FSubcategories%2Fany%28s%3A%20s%2FId%20eq%20%27{value}%27%29&marketsQuery=%24filter%3DclientMetadata%2FsubCategoryId%20eq%20%27{value}%27%20AND%20tags%2Fall%28t%3A%20t%20ne%20%27SportcastBetBuilder%27%29&include=Events&entity=events", headers=headers)
        if response.status_code != 200:
            raise Exception('Bad Request')

        plyr_names = []
        pnt_lines = []
        for i in response.json()['selections']:
            plyr_names.append(i['participants'][0]['name'])
            pnt_lines.append(i['points'])
        df_dk = pd.DataFrame({"Player": plyr_names, f"{key}_line": pnt_lines}).drop_duplicates().reset_index(drop=True)

        if df_lines.empty:
            df_lines = df_dk
        else:
            df_lines = pd.merge(df_lines, df_dk, on="Player", how="outer")

    df_lines = pd.merge(pd.read_csv(f"../tables/{year}/plyr_pos_xref.csv"), df_lines, on='Player', how='right')
    df_lines = pd.merge(df_lines, get_game_odds(), on='Team')
    df_lines.insert(0, 'Date', pd.to_datetime(now))

    partition_save_df(df_lines, f"../tables/{year}/parlay_lines.csv") 
    display(df_lines)

    return df_lines

df_lines = get_sportsbook()
# Out:
# ../tables/2025/parlay_lines.csv saved!
#           Date Team              Player Pos  PTS_line  AST_line  REB_line  \
# 0   2025-12-29  MIL            AJ Green  SG       8.5       NaN       NaN
# 1   2025-12-29  IND       Aaron Nesmith  SF       8.5       NaN       2.5
# 2   2025-12-29  OKC       Ajay Mitchell  SG      11.5       2.5       3.5
# 3   2025-12-29  HOU       Amen Thompson  SF      19.5       5.5       7.5
# 4   2025-12-29  IND     Andrew Nembhard  PG      15.5       6.5       2.5
# ..         ...  ...                 ...  ..       ...       ...       ...
# 155 2025-12-29  GSW        Will Richard  SG       6.5       NaN       NaN
# 156 2025-12-29  WAS          Will Riley  SF       7.5       NaN       NaN
# 157 2025-12-29  NOP          Yves Missi   C       4.5       NaN       5.5
# 158 2025-12-29  ATL  Zaccharie Risacher  SF      12.5       2.5       3.5
# 159 2025-12-29  NOP     Zion Williamson  PF      21.5       3.5       5.5
#
#      STL_line  BLK_line  STL_BLK_line  TPM_line  PA_line  PR_line  RA_line  \
# 0         NaN       NaN           NaN       2.5      NaN      NaN      NaN
# 1         NaN       NaN           NaN       1.5      NaN     12.5      NaN
# 2         NaN       NaN           NaN       0.5     14.5     15.5      6.5
# 3         1.5       NaN           NaN       0.5     25.5     26.5     13.5
# 4         NaN       NaN           NaN       1.5     22.5     17.5      9.5
# ..        ...       ...           ...       ...      ...      ...      ...
# 155       NaN       NaN           NaN       NaN      NaN      NaN      NaN
# 156       NaN       NaN           NaN       NaN      NaN      NaN      NaN
# 157       NaN       NaN           NaN       NaN      NaN      9.5      NaN
# 158       NaN       NaN           NaN       1.5     15.5     16.5      6.5
# 159       0.5       0.5           1.5       NaN     25.5     27.5      9.5
#
#      PRA_line  Spread  Total
# 0         NaN    -3.5  227.5
# 1        12.5    13.5  222.5
# 2        18.5   -17.5  232.5
# 3        32.5   -13.5  222.5
# 4        25.5    13.5  222.5
# ..        ...     ...    ...
# 155       NaN    -6.5  227.5
# 156       NaN    10.5  233.5
# 157      10.5     8.5  247.5
# 158      19.5    17.5  232.5
# 159      31.5     8.5  247.5
#
# [160 rows x 17 columns]

# %%
def pick_finder(stat, collect=False):
    df_actuals = pd.read_csv(f"../tables/{year}/parlay_actuals.csv")
    
    df_mtch = df_gms[['AwayABV', 'HomeABV', 'AwayB2B', 'HomeB2B']]
    df_mtch = df_mtch.rename(columns={"AwayABV": "Team", "HomeABV": "Opp", "AwayB2B": "B2B"})[['Team', 'Opp', 'B2B']]
    df_mtch2 = df_mtch.copy().rename(columns={"Team": "Opp", "Opp": "Team", "HomeB2B": "B2B"})[['Team', 'Opp', 'B2B']]
    df_mtch = pd.concat([df_mtch, df_mtch2])
    
    df_rk = con.execute(f"""SELECT *, RANK() OVER (PARTITION BY Pos ORDER BY Off_{stat} DESC) as Off_Rk FROM
                            (SELECT Team, Player, Pos, AVG({stat}) as Off_{stat} FROM df 
                            WHERE Season = {year} AND {stat} > 0 AND Pos != 'None'
                            AND Team IN ({str(tms_today).replace("[", "").replace("]", "")})
                            GROUP BY Team, Player, Pos)""").fetchdf()
    df_rk_l5 = con.execute(f"""WITH last5 AS (
                                    SELECT Team, Player, Pos, {stat} AS stat_val,
                                    ROW_NUMBER() OVER (PARTITION BY Team, Player ORDER BY Date DESC) AS rn
                                    FROM df
                                    WHERE Season = {year} AND {stat} > 0 AND Pos != 'None'
                                    AND Team IN ({str(tms_today).replace('[','').replace(']','')})
                            )
                            SELECT Team, Player, Pos, AVG(stat_val) AS Off_L5_{stat},
                            FROM last5
                            WHERE rn <= 5
                            GROUP BY Team, Player, Pos
                            """).fetchdf()

    df_rk = con.execute(f"""SELECT df_rk.Team, df_rk.Player, df_rk.Pos, Off_{stat}, Off_L5_{stat}, Off_Rk FROM df_rk JOIN df_rk_l5 
                            ON df_rk.Team = df_rk_l5.Team AND df_rk.Player = df_rk_l5.Player""").fetchdf()
    df_save = pd.DataFrame()
    for pos in ['PG', 'SG', 'SF', 'PF', 'C']:
        print(pos)
        df_def = con.execute(f"""SELECT Team, '{pos}' AS Pos, Def_{stat}, Def_Rk FROM
                                 (SELECT *, RANK() OVER (ORDER BY Def_{stat}) as Def_Rk FROM
                                 (SELECT Opp as Team, AVG({stat}) as Def_{stat} FROM df 
                                 WHERE MP >= 27 AND Season = {year} AND Pos = '{pos}'
                                 GROUP BY Opp
                                 ORDER BY AVG(Fpts) DESC))
                                 WHERE Team IN ({str(tms_today).replace("[", "").replace("]", "")})""").fetchdf()

        df_def_l5 = con.execute(f"""WITH last5 AS (
                                    SELECT Opp AS Team, {stat} AS stat_val, 
                                    ROW_NUMBER() OVER (PARTITION BY Opp ORDER BY Date DESC) AS rn
                                    FROM df
                                    WHERE MP >= 27 AND Season = {year} AND Pos = '{pos}'
                                    )

                                    SELECT Team, '{pos}' AS Pos, AVG(stat_val) AS Def_L5_{stat} FROM last5
                                    WHERE rn <= 5
                                    GROUP BY Team
                                    HAVING Team IN ({str(tms_today).replace('[','').replace(']','')})
                                    """).fetchdf()
        df_def = con.execute(f"""SELECT df_def.Team, df_def.Pos, Def_{stat}, Def_L5_{stat}, Def_Rk FROM df_def 
                               JOIN df_def_l5 ON df_def.Team = df_def_l5.Team""").fetchdf()
        
        # Piece together the current matchups with offensive rankings vs defensive rankings
        df_picks = con.execute(f"""SELECT df_mtch.*, df_rk.* EXCLUDE(Team) FROM df_mtch 
                                  JOIN df_rk ON df_mtch.Team = df_rk.Team
                                  WHERE Pos = '{pos}'""").fetchdf()
        df_picks = con.execute(f"""SELECT df_picks.* EXCLUDE(Opp, Pos), Opp, df_def.Def_{stat}, df_def.Def_L5_{stat}, 
                                   df_def.Def_Rk FROM df_picks 
                                   JOIN df_def ON df_picks.Opp = df_def.Team""").fetchdf()
        df_picks['Rk_Diff'] = df_picks['Def_Rk'] - df_picks['Off_Rk']
        df_picks = con.execute(f"""SELECT * EXCLUDE(Status) FROM
                                    (SELECT t1.* EXCLUDE(Rk_Diff), 
                                    CASE WHEN Status IS NULL THEN 'Available' ELSE Status END as Status FROM df_picks t1
                                    LEFT JOIN df_inj t2 ON t1.Team = t2.Team AND t1.Player = t2.Player
                                    ORDER BY Rk_Diff DESC)
                                   WHERE Status != 'Out'""").fetchdf()
        
        # head to head
        df_h2h = pd.DataFrame()
        for index, row in df_picks.iterrows():
            query = f"""SELECT * EXCLUDE(Gms) FROM
                       (SELECT Player, COUNT(*) as Gms, AVG({stat}) AS AVG_{stat}_H2H FROM df 
                       WHERE Player = ? AND Opp = ? AND Date >= '2023-10-23'
                       GROUP BY Player)
                       WHERE Gms >= 4"""
            df_temp = con.execute(query, [row["Player"], row["Opp"]]).fetchdf()
            df_h2h = pd.concat([df_h2h, df_temp])
        try:
            df_picks = con.execute(f"""SELECT Team, B2B, t1.Player, Off_{stat}, Off_L5_{stat}, t2.AVG_{stat}_H2H, Off_Rk, 
                                   t1.* EXCLUDE(Team, B2B, Player, Off_{stat}, Off_L5_{stat}, Off_Rk)
                                   FROM df_picks t1 LEFT JOIN df_h2h t2 
                                   ON t1.Player = t2.Player""").fetchdf()
        except:
            pass
        
        # Add hit odds (df_actuals)
        df_hit_odds = con.execute(f"""WITH overs AS 
                                        (SELECT Team, Player, SUM({stat}_Diff) as O_Diff, count(*) as Hits FROM df_actuals 
                                        WHERE {stat}_Result = 'O' 
                                        GROUP BY Team, Player)

                                        SELECT overs.Team, overs.Player, Hits, Misses,
                                        O_Diff + U_Diff as {stat}_P_Diff,
                                        hits / (misses + hits) AS {stat}_Hit_Pct, misses / (misses + hits) AS Miss_Pct FROM

                                       (SELECT Team, Player, SUM({stat}_Diff) as U_Diff, count(*) as Misses FROM df_actuals 
                                       WHERE {stat}_Result = 'U' AND {stat}_line IS NOT NULL
                                       GROUP BY Team, Player) unders

                                       JOIN overs ON overs.Team = unders.Team AND overs.Player = unders.Player
                                       ORDER BY {stat}_Hit_Pct DESC""").fetchdf()
        df_picks = con.execute(f"""SELECT df_picks.*, df_hit_odds.{stat}_Hit_Pct, df_hit_odds.{stat}_P_Diff FROM df_picks LEFT JOIN df_hit_odds 
                                   ON df_picks.Team = df_hit_odds.Team AND df_picks.Player = df_hit_odds.Player""").fetchdf()     
        
        # Add Spread and Total
        df_picks = con.execute(f"""SELECT df_picks.* EXCLUDE({stat}_Hit_Pct, {stat}_P_Diff), df_lines.{stat}_line, {stat}_Hit_Pct, {stat}_P_Diff, 
                                   Spread, Total FROM df_picks LEFT JOIN df_lines 
                                   ON df_picks.Team = df_lines.Team AND df_picks.Player = df_lines.Player
                                   WHERE {stat}_line IS NOT NULL
                                   ORDER BY Def_Rk DESC""").fetchdf()
        df_save = pd.concat([df_save, df_picks], ignore_index=True)
        if collect == False:
            display(df_picks)
    if collect == True:
        df_save.insert(0, 'Date', pd.to_datetime(now))
        return df_save

# %%
for i in categories:
    print(f"==={i}===")
    pick_finder(i)
# Out:
# ===PTS===
# PG
#    Team  B2B                   Player    Off_PTS  Off_L5_PTS  AVG_PTS_H2H  \
# 0   TOR    0        Immanuel Quickley  16.468750        18.0    14.000000
# 1   TOR    0              Jamal Shead   6.774194         6.0     7.000000
# 2   CHI    0                Tre Jones  12.200000        11.4     7.400000
# 3   CHI    0              Josh Giddey  19.517241        16.0    11.000000
# 4   DAL    0             Cooper Flagg  19.531250        24.6          NaN
# 5   MIL    0             Ryan Rollins  17.187500        18.2     9.000000
# 6   MIL    0         Kevin Porter Jr.  19.076923        18.8          NaN
# 7   CLE    0           Darius Garland  17.000000        20.8          NaN
# 8   CLE    0               Lonzo Ball   5.909091         5.2          NaN
# 9   PHO    0         Collin Gillespie  13.516129        16.2          NaN
# 10  PHO    0           Jordan Goodwin   9.384615         9.2          NaN
# 11  DEN    0             Jamal Murray  25.400000        26.6    18.400000
# 12  MIA    0          Davion Mitchell   9.620690         8.8     8.166667
# 13  HOU    0            Reed Sheppard  13.448276        16.4          NaN
# 14  OKC    0  Shai Gilgeous-Alexander  31.967742        29.6    31.800000
# 15  CHO    0              LaMelo Ball  19.714286        20.8    32.250000
# 16  CHO    0                 Tre Mann   9.684211         7.8     9.666667
# 17  SAS    0             De'Aaron Fox  21.652174        15.2          NaN
# 18  SAS    0           Stephon Castle  18.478261        19.6          NaN
# 19  ORL    0            Anthony Black  15.093750        24.6     6.000000
# 20  ORL    0               Tyus Jones   6.058824         8.2     9.000000
# 21  IND    0           T.J. McConnell  10.526316        11.4     9.000000
# 22  IND    0          Andrew Nembhard  17.333333        14.8          NaN
# 23  NYK    0            Jalen Brunson  29.310345        32.4    17.250000
# 24  NYK    0              Tyler Kolek   6.333333         9.2          NaN
# 25  GSW    1        De'Anthony Melton   8.571429         6.6          NaN
# 26  GSW    1            Stephen Curry  28.869565        26.2    33.500000
# 27  NOP    0           Jeremiah Fears  14.757576        11.0          NaN
# 28  NOP    0             Jordan Poole  16.000000        13.0    15.000000
# 29  ATL    0               Vit Krejci  10.928571        12.2          NaN
#
#     Off_Rk  Opp    Def_PTS  Def_L5_PTS  Def_Rk  PTS_line  PTS_Hit_Pct  \
# 0       16  ORL  24.064516        23.4      29      16.5     0.500000
# 1       40  ORL  24.064516        23.4      29       6.5     0.400000
# 2       23  MIN  22.370370        24.4      27       9.5          NaN
# 3        8  MIN  22.370370        24.4      27      18.5     0.333333
# 4        7  POR  22.333333        17.6      26      22.5     0.750000
# 5       13  CHO  22.137931        21.4      24      14.5     0.666667
# 6       10  CHO  22.137931        21.4      24      17.5     0.666667
# 7       14  SAS  22.037037        23.8      22      17.5     0.666667
# 8       44  SAS  22.037037        23.8      22       4.5     0.333333
# 9       21  WAS  21.869565        19.6      21      16.5          NaN
# 10      31  WAS  21.869565        19.6      21      10.5     0.500000
# 11       4  MIA  21.760000        25.0      20      26.5          NaN
# 12      29  DEN  21.434783        28.2      17       8.5     0.500000
# 13      22  IND  21.428571        20.6      16      13.5     0.750000
# 14       1  ATL  20.956522        21.2      14      30.5     0.666667
# 15       6  MIL  20.708333        13.8      13      20.5     0.750000
# 16      28  MIL  20.708333        13.8      13       6.5     0.500000
# 17       5  CLE  20.000000        20.6      10      18.5     0.250000
# 18      11  CLE  20.000000        20.6      10      18.5     0.250000
# 19      19  TOR  19.500000        19.8       8      18.5          NaN
# 20      43  TOR  19.500000        19.8       8       4.5     0.500000
# 21      27  HOU  19.240000        23.0       7       7.5     0.666667
# 22      12  HOU  19.240000        23.0       7      15.5     0.750000
# 23       2  NOP  18.880000        13.2       6      28.5     0.250000
# 24      41  NOP  18.880000        13.2       6       6.5          NaN
# 25      34  BRK  18.086957        13.4       3       8.5          NaN
# 26       3  BRK  18.086957        13.4       3      26.5     0.333333
# 27      20  NYK  17.888889        16.0       2      14.5          NaN
# 28      17  NYK  17.888889        16.0       2      15.5     0.750000
# 29      26  OKC  16.518519        21.2       1      10.5     0.500000
#
#     PTS_P_Diff  Spread  Total
# 0        -12.0     1.5  220.5
# 1         -4.5     1.5  220.5
# 2          NaN     6.5  243.5
# 3         -3.5     6.5  243.5
# 4         27.0     2.5  232.5
# 5          0.5    -3.5  227.5
# 6         -2.5    -3.5  227.5
# 7         13.5     3.5  244.5
# 8         -5.5     3.5  244.5
# 9          NaN   -10.5  233.5
# 10        -5.0   -10.5  233.5
# 11         NaN    -1.5  244.5
# 12         2.0     1.5  244.5
# 13         8.0   -13.5  222.5
# 14         3.5   -17.5  232.5
# 15         7.0     3.5  227.5
# 16         1.0     3.5  227.5
# 17       -23.0    -3.5  244.5
# 18        -3.0    -3.5  244.5
# 19         NaN    -1.5  220.5
# 20         2.0    -1.5  220.5
# 21        11.5    13.5  222.5
# 22        12.0    13.5  222.5
# 23         3.0    -8.5  247.5
# 24         NaN    -8.5  247.5
# 25         NaN    -6.5  227.5
# 26       -15.5    -6.5  227.5
# 27         NaN     8.5  247.5
# 28         4.0     8.5  247.5
# 29        -5.0    17.5  232.5
# SG
#    Team  B2B                    Player    Off_PTS  Off_L5_PTS  AVG_PTS_H2H  \
# 0   SAS    0             Devin Vassell  15.156250        12.4    23.600000
# 1   SAS    0              Dylan Harper  12.318182         6.0          NaN
# 2   NYK    0             Miles McBride  12.210526        12.8     6.750000
# 3   NYK    0           Jordan Clarkson  10.645161        11.4          NaN
# 4   OKC    0             Cason Wallace   7.838710         5.6     7.400000
# 5   OKC    0             Ajay Mitchell  14.586207        13.6          NaN
# 6   OKC    0            Jalen Williams  17.307692        16.8    20.500000
# 7   DAL    0              Max Christie  11.733333        11.2     8.333333
# 8   CLE    0               Sam Merrill  13.562500        14.0    10.750000
# 9   CLE    0              Jaylon Tyson  13.925926        17.4          NaN
# 10  CLE    0          Donovan Mitchell  30.200000        27.8    25.400000
# 11  CHO    0                Sion James   7.275862         7.8          NaN
# 12  CHO    0             Collin Sexton  15.260870        12.4    16.833333
# 13  TOR    0            Ja'Kobe Walter   7.320000        10.6     8.000000
# 14  TOR    0               Gradey Dick   7.071429         3.8     8.000000
# 15  TOR    0              Ochai Agbaji   5.136364         7.2     8.500000
# 16  POR    0            Shaedon Sharpe  22.000000        22.4    19.777778
# 17  DEN    0          Julian Strawther   5.800000         5.8     4.000000
# 18  DEN    0          Tim Hardaway Jr.  13.161290        18.2    13.000000
# 19  DEN    0               Bruce Brown   7.724138         9.8    11.666667
# 20  MIL    0            Gary Trent Jr.   9.600000         9.4    11.333333
# 21  MIA    0                 Dru Smith   6.580645         7.4          NaN
# 22  MIA    0             Pelle Larsson  10.250000         9.6          NaN
# 23  MIA    0             Norman Powell  23.740741        21.0    18.625000
# 24  BRK    1              Terance Mann   8.346154         5.4     5.714286
# 25  GSW    1               Moses Moody  11.517241         8.6     7.750000
# 26  GSW    1        Brandin Podziemski  12.437500        14.2    10.250000
# 27  GSW    1              Will Richard   8.720000         9.6          NaN
# 28  WAS    0           Bilal Coulibaly   9.875000        10.8     7.750000
# 29  WAS    0               Tre Johnson  11.608696        13.8          NaN
# 30  WAS    0               CJ McCollum  18.633333        18.8    17.166667
# 31  MIN    0          Donte DiVincenzo  13.593750        12.2    16.000000
# 32  MIN    0           Anthony Edwards  29.320000        32.0    35.500000
# 33  ORL    0              Desmond Bane  19.156250        22.8          NaN
# 34  ORL    0           Jase Richardson   8.153846         8.2          NaN
# 35  CHI    0                Coby White  20.466667        17.4    23.500000
# 36  CHI    0               Isaac Okoro   9.428571         8.6          NaN
# 37  CHI    0               Ayo Dosunmu  14.000000         9.2    10.750000
# 38  PHO    0              Devin Booker  25.392857        26.8    24.000000
# 39  ATL    0              Luke Kennard   7.346154         4.6     5.909091
# 40  ATL    0  Nickeil Alexander-Walker  20.322581        18.6    11.714286
# 41  ATL    0             Dyson Daniels  11.468750        10.8     4.666667
# 42  IND    0             Johnny Furphy   6.300000         9.0          NaN
#
#     Off_Rk  Opp    Def_PTS  Def_L5_PTS  Def_Rk  PTS_line  PTS_Hit_Pct  \
# 0       16  CLE  19.071429        16.8      28      13.5     0.500000
# 1       24  CLE  19.071429        16.8      28      11.5     0.500000
# 2       25  NOP  18.756098        21.4      26       9.5          NaN
# 3       35  NOP  18.756098        21.4      26       9.5          NaN
# 4       46  ATL  18.633333        21.8      25       7.5          NaN
# 5       17  ATL  18.633333        21.8      25      11.5          NaN
# 6       12  ATL  18.633333        21.8      25      18.5     0.666667
# 7       27  POR  18.259259        13.8      23      10.5     0.500000
# 8       21  SAS  17.935484        15.4      22      11.5          NaN
# 9       19  SAS  17.935484        15.4      22      10.5     0.333333
# 10       1  SAS  17.935484        15.4      22      27.5     0.500000
# 11      51  MIL  17.653846        16.6      20       7.5     0.333333
# 12      15  MIL  17.653846        16.6      20      12.5          NaN
# 13      50  ORL  17.583333        17.4      19       5.5          NaN
# 14      53  ORL  17.583333        17.4      19       5.5          NaN
# 15      67  ORL  17.583333        17.4      19       6.5     0.750000
# 16       7  DAL  17.538462        19.0      18      23.5     0.250000
# 17      64  MIA  17.531250        14.8      17       5.5          NaN
# 18      22  MIA  17.531250        14.8      17      15.5     0.750000
# 19      48  MIA  17.531250        14.8      17       8.5     0.666667
# 20      38  CHO  17.464286        20.2      15       7.5          NaN
# 21      55  DEN  17.178571        18.6      14       5.5     0.333333
# 22      36  DEN  17.178571        18.6      14       8.5          NaN
# 23       5  DEN  17.178571        18.6      14      23.5          NaN
# 24      43  GSW  16.875000        22.8      11       6.5          NaN
# 25      30  BRK  16.678571        18.6      10      10.5     0.333333
# 26      23  BRK  16.678571        18.6      10      11.5          NaN
# 27      41  BRK  16.678571        18.6      10       6.5          NaN
# 28      37  PHO  16.034483        11.2       8      10.5     0.500000
# 29      29  PHO  16.034483        11.2       8      11.5     0.750000
# 30      11  PHO  16.034483        11.2       8      19.5     0.500000
# 31      20  CHI  15.652174        10.8       7      13.5     0.666667
# 32       2  CHI  15.652174        10.8       7      30.5     0.666667
# 33      10  TOR  15.441176        12.8       5      21.5     0.250000
# 34      44  TOR  15.441176        12.8       5       6.5          NaN
# 35       8  MIN  15.333333        14.0       4      19.5     0.333333
# 36      39  MIN  15.333333        14.0       4       5.5     0.666667
# 37      18  MIN  15.333333        14.0       4       9.5          NaN
# 38       3  WAS  14.843750        11.8       3      27.5          NaN
# 39      49  OKC  14.769231        11.6       2       6.5     0.500000
# 40       9  OKC  14.769231        11.6       2      19.5     0.666667
# 41      31  OKC  14.769231        11.6       2      12.5     0.333333
# 42      59  HOU  13.916667        13.0       1       5.5          NaN
#
#     PTS_P_Diff  Spread  Total
# 0          3.0    -3.5  244.5
# 1          0.0    -3.5  244.5
# 2          NaN    -8.5  247.5
# 3          NaN    -8.5  247.5
# 4          NaN   -17.5  232.5
# 5          NaN   -17.5  232.5
# 6          3.5   -17.5  232.5
# 7         -6.0     2.5  232.5
# 8          NaN     3.5  244.5
# 9        -12.5     3.5  244.5
# 10         0.0     3.5  244.5
# 11        -4.5     3.5  227.5
# 12         NaN     3.5  227.5
# 13         NaN     1.5  220.5
# 14         NaN     1.5  220.5
# 15         5.0     1.5  220.5
# 16        -9.0    -2.5  232.5
# 17         NaN    -1.5  244.5
# 18        14.0    -1.5  244.5
# 19         7.5    -1.5  244.5
# 20         NaN    -3.5  227.5
# 21        -1.5     1.5  244.5
# 22         NaN     1.5  244.5
# 23         NaN     1.5  244.5
# 24         NaN     6.5  227.5
# 25        -0.5    -6.5  227.5
# 26         NaN    -6.5  227.5
# 27         NaN    -6.5  227.5
# 28         5.0    10.5  233.5
# 29        10.0    10.5  233.5
# 30        -1.0    10.5  233.5
# 31        -1.5    -6.5  243.5
# 32        12.5    -6.5  243.5
# 33       -15.0    -1.5  220.5
# 34         NaN    -1.5  220.5
# 35       -14.5     6.5  243.5
# 36         1.5     6.5  243.5
# 37         NaN     6.5  243.5
# 38         NaN   -10.5  233.5
# 39        -2.0    17.5  232.5
# 40         9.5    17.5  232.5
# 41        -3.5    17.5  232.5
# 42         NaN    13.5  222.5
# SF
#    Team  B2B              Player    Off_PTS  Off_L5_PTS  AVG_PTS_H2H  Off_Rk  \
# 0   SAS    0   Julian Champagnie  10.266667         5.8    10.400000      32
# 1   SAS    0      Keldon Johnson  13.000000        17.2    14.600000      23
# 2   PHO    0       Dillon Brooks  21.360000        20.6     8.500000       7
# 3   PHO    0       Royce O'Neale  10.633333         8.8     8.400000      31
# 4   NYK    0       Mikal Bridges  16.531250        17.2    19.250000      15
# 5   DEN    0       Peyton Watson  11.518519        10.6     5.400000      28
# 6   OKC    0       Luguentz Dort   8.409091        10.0    14.800000      39
# 7   IND    0       Aaron Nesmith  14.916667        15.2          NaN      19
# 8   IND    0  Bennedict Mathurin  18.476190        14.2          NaN      12
# 9   CHO    0      Brandon Miller  17.933333        19.0    17.666667      13
# 10  HOU    0       Amen Thompson  17.724138        18.4     9.750000      14
# 11  HOU    0        Kevin Durant  25.370370        26.4    30.500000       3
# 12  TOR    0      Brandon Ingram  22.030303        22.0     6.250000       6
# 13  NOP    0          Saddiq Bey  14.718750        14.8          NaN      21
# 14  NOP    0     Trey Murphy III  20.645161        17.0          NaN       8
# 15  WAS    0          Will Riley   5.578947         4.8          NaN      46
# 16  WAS    0   Justin Champagnie   7.190476         7.4          NaN      41
# 17  DAL    0       Naji Marshall  13.303030        15.4     7.500000      22
# 18  DAL    0       Klay Thompson  11.482759        11.2    16.285714      29
# 19  GSW    1        Jimmy Butler  19.642857        22.0    16.000000       9
# 20  CLE    0     De'Andre Hunter  14.793103        12.6    17.333333      20
# 21  ATL    0  Zaccharie Risacher  10.700000         9.4          NaN      30
# 22  MIA    0      Andrew Wiggins  16.357143        15.4    15.500000      16
# 23  MIA    0    Jaime Jaquez Jr.  16.290323        20.4     8.200000      17
# 24  CHI    0       Kevin Huerter  12.360000        11.0     4.833333      25
# 25  POR    0         Kris Murray   6.481481         7.2     3.555556      44
# 26  POR    0         Deni Avdija  25.531250        24.0    19.857143       2
# 27  BRK    1  Michael Porter Jr.  25.760000        23.8    17.000000       1
#
#     Opp    Def_PTS  Def_L5_PTS  Def_Rk  PTS_line  PTS_Hit_Pct  PTS_P_Diff  \
# 0   CLE  20.551724        20.0      28       7.5     0.250000        -9.0
# 1   CLE  20.551724        20.0      28      10.5     0.750000         4.0
# 2   WAS  19.636364        19.6      27      21.5     0.666667         0.5
# 3   WAS  19.636364        19.6      27      10.5     0.333333       -11.5
# 4   NOP  19.608696        16.4      26      16.5     0.750000        13.0
# 5   MIA  19.580645        19.6      25      12.5     0.500000         5.0
# 6   ATL  18.933333        20.4      22       7.5     0.666667         1.5
# 7   HOU  18.655172        22.4      19       8.5          NaN         NaN
# 8   HOU  18.655172        22.4      19      16.5          NaN         NaN
# 9   MIL  18.444444        20.0      18      21.5     0.250000        -4.0
# 10  IND  18.406250        24.6      17      19.5          NaN         NaN
# 11  IND  18.406250        24.6      17      27.5     0.500000         8.0
# 12  ORL  18.333333        17.8      15      23.5     0.800000        11.5
# 13  NYK  18.083333        20.6      13      15.5     0.750000        26.0
# 14  NYK  18.083333        20.6      13      19.5     0.500000         0.0
# 15  PHO  18.040000        18.8      12       7.5          NaN         NaN
# 16  PHO  18.040000        18.8      12       8.5          NaN         NaN
# 17  POR  17.884615        22.2      10      12.5          NaN         NaN
# 18  POR  17.884615        22.2      10      11.5     0.750000         6.0
# 19  BRK  17.862069        16.6       9      19.5          NaN         NaN
# 20  SAS  17.736842        12.2       7      11.5     0.333333         4.5
# 21  OKC  17.647059        17.0       6      12.5     0.333333        -7.5
# 22  DEN  17.074074        18.2       4      15.5     0.333333       -13.5
# 23  DEN  17.074074        18.2       4      15.5     0.666667        12.5
# 24  MIN  17.000000        14.8       3       9.5     0.666667         5.5
# 25  DAL  16.555556        17.0       2       6.5     0.333333        -4.5
# 26  DAL  16.555556        17.0       2      27.5     0.500000         1.0
# 27  GSW  15.333333        15.2       1      23.5          NaN         NaN
#
#     Spread  Total
# 0     -3.5  244.5
# 1     -3.5  244.5
# 2    -10.5  233.5
# 3    -10.5  233.5
# 4     -8.5  247.5
# 5     -1.5  244.5
# 6    -17.5  232.5
# 7     13.5  222.5
# 8     13.5  222.5
# 9      3.5  227.5
# 10   -13.5  222.5
# 11   -13.5  222.5
# 12     1.5  220.5
# 13     8.5  247.5
# 14     8.5  247.5
# 15    10.5  233.5
# 16    10.5  233.5
# 17     2.5  232.5
# 18     2.5  232.5
# 19    -6.5  227.5
# 20     3.5  244.5
# 21    17.5  232.5
# 22     1.5  244.5
# 23     1.5  244.5
# 24     6.5  243.5
# 25    -2.5  232.5
# 26    -2.5  232.5
# 27     6.5  227.5
# PF
#    Team  B2B                 Player    Off_PTS  Off_L5_PTS  AVG_PTS_H2H  \
# 0   MIN    0        Jaden McDaniels  15.793103        16.8    13.000000
# 1   MIN    0          Julius Randle  22.562500        20.2          NaN
# 2   OKC    0          Chet Holmgren  18.296296        16.4    18.200000
# 3   PHO    0        Rasheer Fleming   4.454545         5.6          NaN
# 4   PHO    0           Oso Ighodaro   5.607143         6.2          NaN
# 5   MIL    0           Bobby Portis  12.718750        17.2    16.333333
# 6   MIL    0  Giannis Antetokounmpo  28.944444        23.2    19.750000
# 7   MIL    0             Kyle Kuzma  13.466667        13.4    23.571429
# 8   CHO    0         Tidjane Salaun   7.937500         9.0          NaN
# 9   CHO    0          Miles Bridges  20.419355        15.6    18.250000
# 10  IND    0          Pascal Siakam  23.419355        21.2          NaN
# 11  NOP    0        Zion Williamson  21.705882        24.2          NaN
# 12  HOU    0       Jabari Smith Jr.  15.642857        17.4    16.250000
# 13  HOU    0             Tari Eason  11.400000         9.6          NaN
# 14  ORL    0         Paolo Banchero  19.772727        16.2    26.833333
# 15  POR    0         Toumani Camara  12.812500        14.6     9.555556
# 16  BRK    1           Noah Clowney  13.750000        13.4          NaN
# 17  BRK    1             Danny Wolf   9.916667         9.6          NaN
# 18  DAL    0        P.J. Washington  15.666667        13.4    14.000000
# 19  CHI    0          Matas Buzelis  14.000000        17.0          NaN
# 20  SAS    0        Harrison Barnes  12.562500        11.8    13.200000
# 21  ATL    0         Mouhamed Gueye   6.222222         3.0     3.750000
# 22  ATL    0             Asa Newell   9.071429         7.8          NaN
# 23  GSW    1           Quinten Post   9.222222         7.6          NaN
# 24  GSW    1         Draymond Green   8.538462         9.6     5.250000
# 25  NYK    0             OG Anunoby  15.727273        11.8          NaN
# 26  CLE    0              Dean Wade   6.172414         7.8     3.750000
# 27  CLE    0            Evan Mobley  18.333333        15.2          NaN
# 28  TOR    0         Scottie Barnes  19.272727        16.4    15.600000
# 29  TOR    0   Collin Murray-Boyles   7.913043         7.2          NaN
#
#     Off_Rk  Opp    Def_PTS  Def_L5_PTS  Def_Rk  PTS_line  PTS_Hit_Pct  \
# 0       13  CHI  22.904762        21.0      30      14.5     0.333333
# 1        3  CHI  22.904762        21.0      30      21.5     0.666667
# 2       12  ATL  19.428571        21.8      28      17.5     0.500000
# 3       46  WAS  19.400000        17.2      27       6.5          NaN
# 4       42  WAS  19.400000        17.2      27       8.5          NaN
# 5       22  CHO  19.210526        14.0      25      11.5     0.666667
# 6        1  CHO  19.210526        14.0      25      25.5          NaN
# 7       20  CHO  19.210526        14.0      25      10.5          NaN
# 8       33  MIL  18.814815        16.6      22       7.5          NaN
# 9        6  MIL  18.814815        16.6      22      18.5     0.250000
# 10       2  HOU  18.809524        14.4      21      20.5     0.500000
# 11       4  NYK  18.636364        17.8      20      21.5     0.500000
# 12      16  IND  18.260870        18.2      18      15.5     0.750000
# 13      25  IND  18.260870        18.2      18      12.5          NaN
# 14       8  TOR  18.034483        16.6      16      22.5     0.250000
# 15      21  DAL  17.913043        16.4      15      14.5     0.750000
# 16      19  GSW  17.703704        14.0      13      12.5     0.500000
# 17      27  GSW  17.703704        14.0      13       6.5          NaN
# 18      15  POR  17.678571        11.4      12      16.5     0.500000
# 19      17  MIN  17.275862        11.4      11      11.5     0.333333
# 20      23  CLE  16.818182        16.8       8      10.5     0.500000
# 21      38  OKC  16.518519        15.8       7       8.5          NaN
# 22      30  OKC  16.518519        15.8       7       9.5          NaN
# 23      29  BRK  16.388889        13.4       6       9.5     0.333333
# 24      32  BRK  16.388889        13.4       6       7.5     0.333333
# 25      14  NOP  15.920000        17.0       4      17.5     0.500000
# 26      39  SAS  15.800000        18.2       3       5.5     0.333333
# 27      11  SAS  15.800000        18.2       3      13.5          NaN
# 28       9  ORL  14.842105        17.4       1      17.5     0.250000
# 29      34  ORL  14.842105        17.4       1       6.5     0.500000
#
#     PTS_P_Diff  Spread  Total
# 0         -6.5    -6.5  243.5
# 1          2.5    -6.5  243.5
# 2          3.0   -17.5  232.5
# 3          NaN   -10.5  233.5
# 4          NaN   -10.5  233.5
# 5         10.5    -3.5  227.5
# 6          NaN    -3.5  227.5
# 7          NaN    -3.5  227.5
# 8          NaN     3.5  227.5
# 9         -8.0     3.5  227.5
# 10        -7.0    13.5  222.5
# 11         4.0     8.5  247.5
# 12         3.0   -13.5  222.5
# 13         NaN   -13.5  222.5
# 14       -17.0    -1.5  220.5
# 15         7.0    -2.5  232.5
# 16        -2.0     6.5  227.5
# 17         NaN     6.5  227.5
# 18         0.0     2.5  232.5
# 19         7.5     6.5  243.5
# 20        -9.0    -3.5  244.5
# 21         NaN    17.5  232.5
# 22         NaN    17.5  232.5
# 23        -3.5    -6.5  227.5
# 24        -5.5    -6.5  227.5
# 25        -4.0    -8.5  247.5
# 26        -1.5     3.5  244.5
# 27         NaN     3.5  244.5
# 28       -23.0     1.5  220.5
# 29        -5.0     1.5  220.5
# C
#    Team  B2B                 Player    Off_PTS  Off_L5_PTS  AVG_PTS_H2H  \
# 0   POR    0        Donovan Clingan  10.678571        13.4     7.000000
# 1   PHO    0          Nick Richards   3.952381         2.6     9.428571
# 2   NYK    0     Karl-Anthony Towns  22.133333        22.2    19.333333
# 3   CHI    0         Nikola Vucevic  15.833333        16.2    19.500000
# 4   CHI    0            Jalen Smith   9.000000         6.0          NaN
# 5   DAL    0         Daniel Gafford   8.142857         5.2    15.833333
# 6   BRK    1         Day'Ron Sharpe   7.178571         8.2          NaN
# 7   HOU    0           Steven Adams   5.875000         4.4          NaN
# 8   MIN    0               Naz Reid  13.687500        12.2    12.500000
# 9   MIN    0            Rudy Gobert  11.250000         9.2    15.500000
# 10  IND    0               Jay Huff   8.600000         8.2     4.000000
# 11  CLE    0          Jarrett Allen  13.227273        10.6    22.000000
# 12  MIL    0           Myles Turner  12.312500        13.0    16.222222
# 13  MIA    0            Bam Adebayo  17.958333        13.4    15.400000
# 14  MIA    0            Kel'el Ware  13.266667        17.6          NaN
# 15  CHO    0         Moussa Diabate   8.000000         6.6     7.333333
# 16  SAS    0            Luke Kornet   8.608696         9.8     3.166667
# 17  SAS    0      Victor Wembanyama  23.600000        20.6          NaN
# 18  TOR    0  Sandro Mamukelashvili  10.967742        13.6     0.750000
# 19  DEN    0      Jonas Valanciunas   8.290323         7.2     7.500000
# 20  DEN    0           Nikola Jokic  29.903226        31.6    23.400000
# 21  ORL    0     Wendell Carter Jr.  12.612903        14.2     9.333333
# 22  ORL    0           Goga Bitadze   6.346154         4.4     3.166667
# 23  NOP    0            Derik Queen  13.454545        17.0          NaN
# 24  NOP    0             Yves Missi   6.090909         5.2          NaN
# 25  ATL    0         Onyeka Okongwu  16.062500        16.6    13.200000
#
#     Off_Rk  Opp    Def_PTS  Def_L5_PTS  Def_Rk  PTS_line  PTS_Hit_Pct  \
# 0       21  DAL  19.925926        19.6      30      12.5     0.750000
# 1       51  WAS  19.733333        19.6      29       6.5          NaN
# 2        4  NOP  19.400000        16.8      27      24.5     0.333333
# 3        9  MIN  19.360000        24.8      26      15.5     0.666667
# 4       24  MIN  19.360000        24.8      26       8.5          NaN
# 5       30  POR  18.952381        20.4      25       9.5     0.500000
# 6       33  GSW  18.812500        17.8      24       6.5          NaN
# 7       39  IND  18.117647        21.0      22       7.5     0.500000
# 8       10  CHI  17.884615        18.2      21      13.5     0.333333
# 9       18  CHI  17.884615        18.2      21      11.5     0.333333
# 10      27  HOU  17.833333        13.6      20       8.5          NaN
# 11      14  SAS  17.812500        16.0      19      10.5          NaN
# 12      17  CHO  17.210526        20.8      16      11.5     0.666667
# 13       7  DEN  16.761905        13.0      15      18.5     0.333333
# 14      13  DEN  16.761905        13.0      15      12.5          NaN
# 15      31  MIL  16.687500        16.2      14       9.5     0.333333
# 16      26  CLE  16.333333        13.8      13       5.5          NaN
# 17       2  CLE  16.333333        13.8      13      22.5     0.250000
# 18      20  ORL  15.920000        20.8      10      12.5     0.600000
# 19      28  MIA  15.913043        10.4       9       7.5     0.750000
# 20       1  MIA  15.913043        10.4       9      30.5     0.500000
# 21      16  TOR  14.600000        15.2       5      12.5     0.750000
# 22      35  TOR  14.600000        15.2       5       4.5     0.500000
# 23      12  NYK  14.409091        19.6       4      12.5     0.750000
# 24      38  NYK  14.409091        19.6       4       4.5          NaN
# 25       8  OKC  13.384615        11.4       2      15.5          NaN
#
#     PTS_P_Diff  Spread  Total
# 0         20.0    -2.5  232.5
# 1          NaN   -10.5  233.5
# 2        -22.5    -8.5  247.5
# 3          7.5     6.5  243.5
# 4          NaN     6.5  243.5
# 5         -2.0     2.5  232.5
# 6          NaN     6.5  227.5
# 7         -4.0   -13.5  222.5
# 8         -0.5    -6.5  243.5
# 9         -2.5    -6.5  243.5
# 10         NaN    13.5  222.5
# 11         NaN     3.5  244.5
# 12         4.5    -3.5  227.5
# 13       -13.5     1.5  244.5
# 14         NaN     1.5  244.5
# 15        -2.5     3.5  227.5
# 16         NaN    -3.5  244.5
# 17        -5.0    -3.5  244.5
# 18        13.5     1.5  220.5
# 19        -1.0    -1.5  244.5
# 20        12.0    -1.5  244.5
# 21        16.0    -1.5  220.5
# 22        -2.0    -1.5  220.5
# 23         5.0     8.5  247.5
# 24         NaN     8.5  247.5
# 25         NaN    17.5  232.5
# ===AST===
# PG
#    Team  B2B                   Player   Off_AST  Off_L5_AST  AVG_AST_H2H  \
# 0   OKC    0  Shai Gilgeous-Alexander  6.419355         6.4     6.600000
# 1   NYK    0            Jalen Brunson  6.482759         6.6     5.000000
# 2   NYK    0              Tyler Kolek  3.521739         4.8          NaN
# 3   DEN    0             Jamal Murray  6.833333         7.8     5.000000
# 4   PHO    0           Jordan Goodwin  2.360000         2.6          NaN
# 5   PHO    0         Collin Gillespie  5.096774         6.6          NaN
# 6   TOR    0        Immanuel Quickley  6.406250         7.2     5.833333
# 7   TOR    0              Jamal Shead  5.393939         4.4     4.000000
# 8   NOP    0             Jordan Poole  3.500000         3.6     3.600000
# 9   NOP    0           Jeremiah Fears  3.156250         2.6          NaN
# 10  CHO    0              LaMelo Ball  8.476190         8.4     7.750000
# 11  SAS    0             De'Aaron Fox  6.217391         5.8          NaN
# 12  SAS    0           Stephon Castle  7.173913         7.0          NaN
# 13  GSW    1            Stephen Curry  4.454545         5.4     3.750000
# 14  CHI    0              Josh Giddey  9.206897        10.8     5.166667
# 15  CHI    0                Tre Jones  5.000000         4.2     5.600000
# 16  IND    0          Andrew Nembhard  6.875000         8.4          NaN
# 17  IND    0           T.J. McConnell  4.550000         5.2     2.750000
# 18  MIA    0          Davion Mitchell  7.366667         5.8     4.500000
# 19  MIL    0             Ryan Rollins  5.781250         4.8     2.333333
# 20  MIL    0         Kevin Porter Jr.  7.384615         8.2          NaN
# 21  DAL    0             Cooper Flagg  4.275862         5.6          NaN
# 22  HOU    0            Reed Sheppard  3.482759         4.4          NaN
# 23  ORL    0               Tyus Jones  2.925926         4.4     5.000000
# 24  ORL    0            Anthony Black  3.580645         4.6     1.000000
# 25  CLE    0           Darius Garland  6.705882         7.4          NaN
# 26  CLE    0               Lonzo Ball  4.750000         4.6          NaN
#
#     Off_Rk  Opp   Def_AST  Def_L5_AST  Def_Rk  AST_line  AST_Hit_Pct  \
# 0       12  ATL  8.260870        10.4      30       6.5     0.666667
# 1       11  NOP  7.280000         7.0      28       6.5          NaN
# 2       29  NOP  7.280000         7.0      28       3.5          NaN
# 3        9  MIA  7.200000         8.2      26       6.5     0.333333
# 4       40  WAS  7.173913         7.0      25       2.5          NaN
# 5       17  WAS  7.173913         7.0      25       6.5     0.666667
# 6       13  ORL  7.000000         6.4      22       5.5     0.750000
# 7       16  ORL  7.000000         6.4      22       4.5     0.500000
# 8       30  NYK  6.814815         7.8      21       3.5     0.500000
# 9       35  NYK  6.814815         7.8      21       3.5     0.500000
# 10       3  MIL  6.791667         7.8      20       7.5     0.500000
# 11      14  CLE  6.750000         7.0      19       5.5     0.750000
# 12       7  CLE  6.750000         7.0      19       6.5          NaN
# 13      22  BRK  6.652174         6.8      18       4.5          NaN
# 14       1  MIN  6.629630         8.8      17       8.5     0.666667
# 15      18  MIN  6.629630         8.8      17       4.5          NaN
# 16       8  HOU  6.520000         6.8      13       6.5     0.500000
# 17      21  HOU  6.520000         6.8      13       4.5     0.666667
# 18       6  DEN  6.478261         6.0      12       6.5     0.333333
# 19      15  CHO  6.413793         7.4      11       4.5     0.666667
# 20       5  CHO  6.413793         7.4      11       6.5     0.666667
# 21      24  POR  6.222222         5.6       9       4.5     0.750000
# 22      31  IND  5.904762         5.0       7       4.5     0.666667
# 23      37  TOR  5.500000         4.2       5       3.5     0.333333
# 24      28  TOR  5.500000         4.2       5       4.5     0.250000
# 25      10  SAS  5.074074         5.0       1       6.5     0.333333
# 26      20  SAS  5.074074         5.0       1       2.5     0.666667
#
#     AST_P_Diff  Spread  Total
# 0          1.5   -17.5  232.5
# 1          NaN    -8.5  247.5
# 2          NaN    -8.5  247.5
# 3         -1.5    -1.5  244.5
# 4          NaN   -10.5  233.5
# 5          2.5   -10.5  233.5
# 6          7.0     1.5  220.5
# 7          5.0     1.5  220.5
# 8          3.0     8.5  247.5
# 9          0.0     8.5  247.5
# 10         4.0     3.5  227.5
# 11         4.0    -3.5  244.5
# 12         NaN    -3.5  244.5
# 13         NaN    -6.5  227.5
# 14         3.5     6.5  243.5
# 15         NaN     6.5  243.5
# 16        -2.0    13.5  222.5
# 17         2.5    13.5  222.5
# 18        -1.5     1.5  244.5
# 19         0.5    -3.5  227.5
# 20         3.5    -3.5  227.5
# 21         5.0     2.5  232.5
# 22         2.5   -13.5  222.5
# 23        -1.5    -1.5  220.5
# 24        -2.0    -1.5  220.5
# 25         0.5     3.5  244.5
# 26         2.5     3.5  244.5
# SG
#    Team  B2B                    Player   Off_AST  Off_L5_AST  AVG_AST_H2H  \
# 0   CLE    0               Sam Merrill  3.071429         3.4     2.500000
# 1   CLE    0          Donovan Mitchell  5.433333         5.2     9.000000
# 2   CLE    0              Jaylon Tyson  2.000000         2.0          NaN
# 3   DAL    0              Max Christie  2.583333         3.0     1.666667
# 4   ORL    0              Desmond Bane  4.593750         3.8          NaN
# 5   WAS    0               CJ McCollum  3.600000         4.6     4.333333
# 6   WAS    0           Bilal Coulibaly  2.625000         1.6     1.750000
# 7   PHO    0              Devin Booker  6.464286         5.4     6.500000
# 8   GSW    1        Brandin Podziemski  3.620690         3.8     3.500000
# 9   MIN    0          Donte DiVincenzo  4.031250         5.4     4.000000
# 10  MIN    0           Anthony Edwards  3.833333         3.2     4.750000
# 11  CHO    0             Collin Sexton  4.043478         2.6     4.833333
# 12  CHI    0                Coby White  4.866667         5.0     5.500000
# 13  SAS    0             Devin Vassell  2.758621         2.0     3.200000
# 14  SAS    0              Dylan Harper  4.684211         6.2          NaN
# 15  POR    0            Shaedon Sharpe  2.444444         2.0     3.111111
# 16  MIA    0             Norman Powell  2.920000         3.8     1.875000
# 17  MIA    0             Pelle Larsson  3.826087         3.4          NaN
# 18  OKC    0             Cason Wallace  2.500000         2.2     2.800000
# 19  OKC    0             Ajay Mitchell  3.566667         3.2          NaN
# 20  OKC    0            Jalen Williams  5.384615         4.8     5.250000
# 21  BRK    1              Terance Mann  4.040000         4.0     2.142857
# 22  DEN    0               Bruce Brown  2.869565         2.4     1.833333
# 23  DEN    0          Tim Hardaway Jr.  1.954545         1.8     1.000000
# 24  ATL    0  Nickeil Alexander-Walker  3.300000         2.4     2.285714
# 25  ATL    0             Dyson Daniels  5.718750         6.0     0.777778
#
#     Off_Rk  Opp   Def_AST  Def_L5_AST  Def_Rk  AST_line  AST_Hit_Pct  \
# 0       23  SAS  4.193548         4.4      26       2.5          NaN
# 1        3  SAS  4.193548         4.4      26       5.5          NaN
# 2       50  SAS  4.193548         4.4      26       1.5          NaN
# 3       33  POR  3.814815         4.0      21       1.5          NaN
# 4        7  TOR  3.794118         2.8      20       4.5     0.250000
# 5       15  PHO  3.724138         4.6      18       3.5     0.750000
# 6       32  PHO  3.724138         4.6      18       2.5          NaN
# 7        1  WAS  3.718750         3.8      17       6.5          NaN
# 8       14  BRK  3.678571         2.8      16       3.5     0.666667
# 9       11  CHI  3.652174         3.4      15       4.5     0.666667
# 10      12  CHI  3.652174         3.4      15       4.5     0.333333
# 11       9  MIL  3.615385         3.4      14       3.5          NaN
# 12       5  MIN  3.592593         1.6      13       3.5     0.666667
# 13      30  CLE  3.571429         3.6      12       2.5     0.750000
# 14       6  CLE  3.571429         3.6      12       4.5     0.250000
# 15      38  DAL  3.538462         2.2      10       2.5     0.250000
# 16      27  DEN  3.535714         4.0       9       2.5     0.750000
# 17      13  DEN  3.535714         4.0       9       2.5          NaN
# 18      37  ATL  3.433333         4.4       8       2.5     0.500000
# 19      16  ATL  3.433333         4.4       8       2.5     0.333333
# 20       4  ATL  3.433333         4.4       8       5.5          NaN
# 21      10  GSW  3.281250         3.2       6       3.5     0.500000
# 22      28  MIA  3.281250         3.0       6       2.5          NaN
# 23      53  MIA  3.281250         3.0       6       1.5          NaN
# 24      18  OKC  2.884615         3.2       3       3.5     0.500000
# 25       2  OKC  2.884615         3.2       3       6.5     0.333333
#
#     AST_P_Diff  Spread  Total
# 0          NaN     3.5  244.5
# 1          NaN     3.5  244.5
# 2          NaN     3.5  244.5
# 3          NaN     2.5  232.5
# 4         -3.0    -1.5  220.5
# 5          3.0    10.5  233.5
# 6          NaN    10.5  233.5
# 7          NaN   -10.5  233.5
# 8          3.5    -6.5  227.5
# 9          2.5    -6.5  243.5
# 10        -1.5    -6.5  243.5
# 11         NaN     3.5  227.5
# 12         5.5     6.5  243.5
# 13         1.0    -3.5  244.5
# 14        -3.0    -3.5  244.5
# 15        -3.0    -2.5  232.5
# 16         5.0     1.5  244.5
# 17         NaN     1.5  244.5
# 18         1.0   -17.5  232.5
# 19         0.5   -17.5  232.5
# 20         NaN   -17.5  232.5
# 21         2.0     6.5  227.5
# 22         NaN    -1.5  244.5
# 23         NaN    -1.5  244.5
# 24         0.0    17.5  232.5
# 25        -2.5    17.5  232.5
# SF
#    Team  B2B              Player   Off_AST  Off_L5_AST  AVG_AST_H2H  Off_Rk  \
# 0   SAS    0   Julian Champagnie  1.800000         1.6     0.800000      38
# 1   SAS    0      Keldon Johnson  1.840000         1.4     1.000000      37
# 2   DEN    0       Peyton Watson  1.869565         1.4     1.600000      35
# 3   CLE    0     De'Andre Hunter  2.307692         1.4     2.166667      25
# 4   PHO    0       Royce O'Neale  2.806452         2.6     2.800000      20
# 5   MIA    0    Jaime Jaquez Jr.  4.580645         3.4     2.000000       7
# 6   MIA    0      Andrew Wiggins  2.857143         2.8     2.500000      19
# 7   NOP    0     Trey Murphy III  3.821429         3.4          NaN      12
# 8   NOP    0          Saddiq Bey  2.464286         1.8          NaN      23
# 9   NYK    0       Mikal Bridges  4.387097         5.2     1.500000       8
# 10  CHO    0      Brandon Miller  3.846154         5.0     2.500000      11
# 11  GSW    1        Jimmy Butler  4.892857         4.6     2.285714       6
# 12  DAL    0       Naji Marshall  2.964286         3.0     2.000000      18
# 13  ATL    0  Zaccharie Risacher  2.300000         2.0          NaN      26
# 14  POR    0         Deni Avdija  6.750000         9.4     4.000000       2
# 15  HOU    0        Kevin Durant  4.259259         5.8     5.250000       9
# 16  HOU    0       Amen Thompson  5.275862         5.6     2.500000       3
# 17  TOR    0      Brandon Ingram  3.968750         4.0     2.000000      10
# 18  BRK    1  Michael Porter Jr.  3.521739         3.6     1.857143      15
#
#     Opp   Def_AST  Def_L5_AST  Def_Rk  AST_line  AST_Hit_Pct  AST_P_Diff  \
# 0   CLE  4.379310         4.6      29       1.5          NaN         NaN
# 1   CLE  4.379310         4.6      29       1.5          NaN         NaN
# 2   MIA  4.129032         4.2      26       1.5          NaN         NaN
# 3   SAS  3.868421         4.4      22       1.5          NaN         NaN
# 4   WAS  3.727273         2.0      20       2.5     0.666667         0.5
# 5   DEN  3.703704         3.2      19       3.5     0.666667         0.5
# 6   DEN  3.703704         3.2      19       2.5     0.666667         1.5
# 7   NYK  3.625000         5.4      17       3.5     0.500000         0.0
# 8   NYK  3.625000         5.4      17       1.5          NaN         NaN
# 9   NOP  3.565217         2.2      15       4.5          NaN         NaN
# 10  MIL  3.555556         4.2      14       3.5     0.250000        -3.0
# 11  BRK  3.517241         2.4      13       4.5          NaN         NaN
# 12  POR  3.423077         4.0      12       2.5     0.666667         3.5
# 13  OKC  3.411765         4.6      10       2.5          NaN         NaN
# 14  DAL  3.250000         4.6       8       8.5     0.750000         4.0
# 15  IND  3.218750         2.6       7       5.5     0.750000         7.0
# 16  IND  3.218750         2.6       7       5.5     0.500000         2.0
# 17  ORL  3.138889         2.6       6       3.5     0.400000         1.5
# 18  GSW  3.074074         2.8       4       2.5     0.500000         1.0
#
#     Spread  Total
# 0     -3.5  244.5
# 1     -3.5  244.5
# 2     -1.5  244.5
# 3      3.5  244.5
# 4    -10.5  233.5
# 5      1.5  244.5
# 6      1.5  244.5
# 7      8.5  247.5
# 8      8.5  247.5
# 9     -8.5  247.5
# 10     3.5  227.5
# 11    -6.5  227.5
# 12     2.5  232.5
# 13    17.5  232.5
# 14    -2.5  232.5
# 15   -13.5  222.5
# 16   -13.5  222.5
# 17     1.5  220.5
# 18     6.5  227.5
# PF
#    Team  B2B                 Player   Off_AST  Off_L5_AST  AVG_AST_H2H  \
# 0   MIL    0             Kyle Kuzma  2.833333         3.0     5.000000
# 1   MIL    0  Giannis Antetokounmpo  5.833333         3.2     6.750000
# 2   GSW    1         Draymond Green  5.280000         3.2     6.000000
# 3   SAS    0        Harrison Barnes  2.538462         1.8     1.800000
# 4   CHO    0          Miles Bridges  4.321429         4.4     3.375000
# 5   MIN    0          Julius Randle  5.687500         5.4          NaN
# 6   MIN    0        Jaden McDaniels  2.827586         3.4     2.000000
# 7   CLE    0              Dean Wade  2.080000         2.0     1.750000
# 8   CLE    0            Evan Mobley  4.153846         3.4          NaN
# 9   BRK    1             Danny Wolf  2.000000         1.8          NaN
# 10  BRK    1           Noah Clowney  2.200000         2.2          NaN
# 11  NOP    0        Zion Williamson  3.687500         3.2          NaN
# 12  ORL    0         Paolo Banchero  4.409091         5.4     5.166667
# 13  POR    0         Toumani Camara  3.034483         3.4     1.111111
# 14  TOR    0         Scottie Barnes  5.242424         5.6     4.800000
# 15  IND    0          Pascal Siakam  3.838710         2.8          NaN
#
#     Off_Rk  Opp   Def_AST  Def_L5_AST  Def_Rk  AST_line  AST_Hit_Pct  \
# 0       15  CHO  4.842105         2.8      30       2.5     0.500000
# 1        1  CHO  4.842105         2.8      30       5.5          NaN
# 2        3  BRK  4.388889         4.2      29       5.5          NaN
# 3       20  CLE  3.590909         3.4      27       1.5     0.500000
# 4        6  MIL  3.481481         1.8      25       3.5     0.500000
# 5        2  CHI  3.380952         3.2      22       5.5     0.666667
# 6       16  CHI  3.380952         3.2      22       2.5     0.333333
# 7       30  SAS  3.000000         1.4      14       1.5          NaN
# 8        7  SAS  3.000000         1.4      14       2.5          NaN
# 9       31  GSW  3.000000         4.2      14       1.5          NaN
# 10      25  GSW  3.000000         4.2      14       1.5          NaN
# 11       9  NYK  2.954545         3.4      13       3.5     0.500000
# 12       5  TOR  2.931034         2.2      11       4.5     0.750000
# 13      12  DAL  2.739130         4.2       7       2.5     0.250000
# 14       4  ORL  2.526316         2.8       5       4.5     0.500000
# 15       8  HOU  2.380952         3.4       3       2.5     0.250000
#
#     AST_P_Diff  Spread  Total
# 0          1.0    -3.5  227.5
# 1          NaN    -3.5  227.5
# 2          NaN    -6.5  227.5
# 3         -1.0    -3.5  244.5
# 4          0.0     3.5  227.5
# 5         -1.5    -6.5  243.5
# 6         -0.5    -6.5  243.5
# 7          NaN     3.5  244.5
# 8          NaN     3.5  244.5
# 9          NaN     6.5  227.5
# 10         NaN     6.5  227.5
# 11         2.0     8.5  247.5
# 12         7.0    -1.5  220.5
# 13        -3.0    -2.5  232.5
# 14        -5.0     1.5  220.5
# 15        -2.0    13.5  222.5
# C
#    Team  B2B                 Player    Off_AST  Off_L5_AST  AVG_AST_H2H  \
# 0   NYK    0     Karl-Anthony Towns   2.800000         1.2     3.000000
# 1   CLE    0          Jarrett Allen   2.142857         2.8     1.250000
# 2   MIN    0               Naz Reid   2.533333         1.8     3.250000
# 3   CHI    0         Nikola Vucevic   3.571429         2.8     3.500000
# 4   MIA    0            Bam Adebayo   2.636364         2.4     2.800000
# 5   TOR    0  Sandro Mamukelashvili   2.115385         2.6     0.000000
# 6   DEN    0           Nikola Jokic  11.064516        11.8    10.600000
# 7   SAS    0      Victor Wembanyama   3.400000         2.6          NaN
# 8   SAS    0            Luke Kornet   2.142857         1.6     0.500000
# 9   ATL    0         Onyeka Okongwu   3.333333         3.8     1.400000
# 10  CHO    0         Moussa Diabate   1.714286         1.8     1.333333
# 11  ORL    0     Wendell Carter Jr.   2.137931         2.4     3.000000
# 12  NOP    0            Derik Queen   4.888889         4.0          NaN
#
#     Off_Rk  Opp   Def_AST  Def_L5_AST  Def_Rk  AST_line  AST_Hit_Pct  \
# 0       11  NOP  4.150000         5.4      30       2.5          NaN
# 1       23  SAS  3.812500         3.8      27       1.5          NaN
# 2       15  CHI  3.730769         3.2      25       2.5     0.333333
# 3        5  MIN  3.560000         4.6      21       3.5     0.333333
# 4       12  DEN  3.190476         3.4      17       2.5          NaN
# 5       26  ORL  3.160000         6.2      16       1.5          NaN
# 6        1  MIA  3.043478         4.6      15      10.5          NaN
# 7        7  CLE  2.761905         1.8      10       3.5     0.500000
# 8       23  CLE  2.761905         1.8      10       1.5          NaN
# 9        8  OKC  2.692308         1.6       8       3.5     0.666667
# 10      36  MIL  2.562500         1.8       7       1.5          NaN
# 11      25  TOR  2.350000         2.0       4       2.5     0.333333
# 12       3  NYK  1.863636         0.8       1       3.5     0.500000
#
#     AST_P_Diff  Spread  Total
# 0          NaN    -8.5  247.5
# 1          NaN     3.5  244.5
# 2         -0.5    -6.5  243.5
# 3         -1.5     6.5  243.5
# ...
# 4  PHO    0      Devin Booker  1.400000         1.6     1.000000      43  WAS
# 5  MIA    0     Norman Powell  1.636364         1.8     0.875000      28  DEN
# 6  CLE    0  Donovan Mitchell  1.791667         2.2     1.600000      19  SAS
# 7  ATL    0     Dyson Daniels  2.172414         1.6     0.777778       5  OKC
#
#     Def_STL  Def_L5_STL  Def_Rk  STL_line  STL_Hit_Pct  STL_P_Diff  Spread  \
# 0  1.423077         0.8      26       1.5     0.333333         2.5    -2.5
# 1  1.347826         1.6      25       1.5     0.666667         1.5    -6.5
# 2  1.058824         1.8      16       0.5          NaN         NaN    -1.5
# 3  1.033333         1.4      13       1.5     0.666667        -0.5   -17.5
# 4  1.031250         0.4      12       0.5          NaN         NaN   -10.5
# 5  1.000000         1.2       8       1.5     0.666667         4.5     1.5
# 6  0.967742         1.4       7       1.5          NaN         NaN     3.5
# 7  0.961538         0.8       5       1.5          NaN         NaN    17.5
#
#    Total
# 0  232.5
# 1  243.5
# 2  220.5
# 3  232.5
# 4  233.5
# 5  244.5
# 6  244.5
# 7  232.5
# SF
#   Team  B2B              Player   Off_STL  Off_L5_STL  AVG_STL_H2H  Off_Rk  \
# 0  MIA    0      Andrew Wiggins  1.631579         1.8     0.833333      18
# 1  HOU    0       Amen Thompson  1.857143         1.8     1.000000       6
# 2  NYK    0       Mikal Bridges  2.217391         1.4     1.000000       1
# 3  POR    0         Deni Avdija  1.333333         1.4     0.571429      39
# 4  BRK    1  Michael Porter Jr.  1.500000         1.8     0.571429      25
# 5  CHO    0      Brandon Miller  1.400000         1.6     0.833333      36
# 6  PHO    0       Dillon Brooks  1.736842         1.4     0.500000      11
# 7  TOR    0      Brandon Ingram  1.733333         1.6     0.250000      12
# 8  GSW    1        Jimmy Butler  1.950000         1.6     1.000000       5
# 9  NOP    0     Trey Murphy III  2.120000         2.2          NaN       2
#
#    Opp   Def_STL  Def_L5_STL  Def_Rk  STL_line  STL_Hit_Pct  STL_P_Diff  \
# 0  DEN  1.444444         1.0      27       0.5     0.750000         3.0
# 1  IND  1.375000         2.0      24       1.5     0.500000         1.0
# 2  NOP  1.304348         1.2      22       1.5          NaN         NaN
# 3  DAL  1.250000         1.6      21       0.5     0.333333        -0.5
# 4  GSW  1.222222         1.0      19       0.5          NaN         NaN
# 5  MIL  1.185185         0.8      17       0.5     0.500000         2.0
# 6  WAS  1.181818         0.0      16       1.5     0.333333        -0.5
# 7  ORL  1.055556         0.8       8       0.5     0.333333         0.5
# 8  BRK  1.034483         0.6       6       1.5          NaN         NaN
# 9  NYK  0.625000         0.8       1       1.5     0.666667         3.5
#
#    Spread  Total
# 0     1.5  244.5
# 1   -13.5  222.5
# 2    -8.5  247.5
# 3    -2.5  232.5
# 4     6.5  227.5
# 5     3.5  227.5
# 6   -10.5  233.5
# 7     1.5  220.5
# 8    -6.5  227.5
# 9     8.5  247.5
# PF
#   Team  B2B                 Player   Off_STL  Off_L5_STL  AVG_STL_H2H  Off_Rk  \
# 0  ORL    0         Paolo Banchero  1.181818         1.2     1.166667      46
# 1  GSW    1         Draymond Green  1.533333         1.6     0.000000      21
# 2  CHO    0          Miles Bridges  1.125000         1.0     0.750000      48
# 3  POR    0         Toumani Camara  1.800000         2.0     0.888889       7
# 4  MIL    0  Giannis Antetokounmpo  1.416667         1.2     0.500000      30
# 5  TOR    0         Scottie Barnes  1.571429         2.0     2.000000      16
# 6  NOP    0        Zion Williamson  2.000000         1.8          NaN       3
# 7  MIN    0          Julius Randle  1.761905         2.2          NaN      10
# 8  MIN    0        Jaden McDaniels  1.684211         1.4     0.500000      12
# 9  NYK    0             OG Anunoby  2.176471         2.2          NaN       2
#
#    Opp   Def_STL  Def_L5_STL  Def_Rk  STL_line  STL_Hit_Pct  STL_P_Diff  \
# 0  TOR  1.379310         1.0      28       0.5          NaN         NaN
# 1  BRK  1.222222         1.6      25       0.5     0.500000        -1.0
# 2  MIL  1.185185         1.6      24       0.5     0.500000         0.0
# 3  DAL  1.173913         2.0      23       1.5          NaN         NaN
# 4  CHO  1.157895         1.0      22       0.5          NaN         NaN
# 5  ORL  1.105263         2.0      21       1.5     0.400000        -2.5
# 6  NYK  1.045455         1.2      17       0.5          NaN         NaN
# 7  CHI  0.857143         0.4       7       0.5     0.666667         3.5
# 8  CHI  0.857143         0.4       7       0.5          NaN         NaN
# 9  NOP  0.640000         0.8       2       1.5          NaN         NaN
#
#    Spread  Total
# 0    -1.5  220.5
# 1    -6.5  227.5
# 2     3.5  227.5
# 3    -2.5  232.5
# 4    -3.5  227.5
# 5     1.5  220.5
# 6     8.5  247.5
# 7    -6.5  243.5
# 8    -6.5  243.5
# 9    -8.5  247.5
# C
#   Team  B2B              Player   Off_STL  Off_L5_STL  AVG_STL_H2H  Off_Rk  \
# 0  SAS    0   Victor Wembanyama  1.133333         1.0          NaN      43
# 1  NYK    0  Karl-Anthony Towns  1.500000         1.6     0.166667      15
# 2  ATL    0      Onyeka Okongwu  1.454545         1.6     0.600000      21
#
#    Opp   Def_STL  Def_L5_STL  Def_Rk  STL_line  STL_Hit_Pct  STL_P_Diff  \
# 0  CLE  1.523810         2.8      30       0.5          NaN         NaN
# 1  NOP  1.000000         1.0      19       0.5     0.666667         2.5
# 2  OKC  0.923077         1.0      17       0.5          NaN         NaN
#
#    Spread  Total
# 0    -3.5  244.5
# 1    -8.5  247.5
# 2    17.5  232.5
# ===BLK===
# PG
#   Team  B2B        Player   Off_BLK  Off_L5_BLK  AVG_BLK_H2H  Off_Rk  Opp  \
# 0  DAL    0  Cooper Flagg  1.368421         1.4          NaN       8  POR
#
#     Def_BLK  Def_L5_BLK  Def_Rk  BLK_line  BLK_Hit_Pct  BLK_P_Diff  Spread  \
# 0  0.333333         0.0      10       0.5          NaN         NaN     2.5
#
#    Total
# 0  232.5
# SG
# Empty DataFrame
# Columns: [Team, B2B, Player, Off_BLK, Off_L5_BLK, AVG_BLK_H2H, Off_Rk, Opp, Def_BLK, Def_L5_BLK, Def_Rk, BLK_line, BLK_Hit_Pct, BLK_P_Diff, Spread, Total]
# Index: []
# SF
#   Team  B2B           Player   Off_BLK  Off_L5_BLK  AVG_BLK_H2H  Off_Rk  Opp  \
# 0  CHO    0   Brandon Miller  1.500000         1.4     0.333333       6  MIL
# 1  NYK    0    Mikal Bridges  1.611111         1.0     0.250000       4  NOP
# 2  DEN    0    Peyton Watson  1.611111         2.0     0.800000       4  MIA
# 3  POR    0      Deni Avdija  1.250000         1.2     0.571429      25  DAL
# 4  NOP    0  Trey Murphy III  1.000000         1.0          NaN      36  NYK
#
#     Def_BLK  Def_L5_BLK  Def_Rk  BLK_line  BLK_Hit_Pct  BLK_P_Diff  Spread  \
# 0  0.666667         0.0      27       0.5          NaN         NaN     3.5
# 1  0.652174         0.2      25       0.5          NaN         NaN    -8.5
# 2  0.645161         0.2      24       1.5          NaN         NaN    -1.5
# 3  0.611111         0.2      22       0.5     0.666667         0.5    -2.5
# 4  0.416667         0.4       8       0.5          NaN         NaN     8.5
#
#    Total
# 0  227.5
# 1  247.5
# 2  244.5
# 3  232.5
# 4  247.5
# PF
#    Team  B2B                 Player   Off_BLK  Off_L5_BLK  AVG_BLK_H2H  \
# 0   DAL    0        P.J. Washington  1.695652         2.4     0.200000
# 1   GSW    1         Draymond Green  1.400000         1.2     0.500000
# 2   TOR    0         Scottie Barnes  1.961538         2.0     0.600000
# 3   OKC    0          Chet Holmgren  1.863636         1.8     2.000000
# 4   ORL    0         Paolo Banchero  1.500000         1.2     0.666667
# 5   CLE    0            Evan Mobley  1.909091         2.2          NaN
# 6   POR    0         Toumani Camara  1.166667         1.2     0.111111
# 7   NYK    0             OG Anunoby  1.214286         1.2          NaN
# 8   CHO    0          Miles Bridges  1.266667         1.4     0.125000
# 9   MIL    0  Giannis Antetokounmpo  1.416667         1.4     0.750000
# 10  NOP    0        Zion Williamson  1.142857         1.2          NaN
#
#     Off_Rk  Opp   Def_BLK  Def_L5_BLK  Def_Rk  BLK_line  BLK_Hit_Pct  \
# 0        7  POR  0.964286         0.2      27       1.5          NaN
# 1       15  BRK  0.888889         0.8      23       0.5          NaN
# 2        1  ORL  0.842105         1.0      21       1.5         0.75
# 3        4  ATL  0.809524         1.2      19       1.5         0.50
# 4       10  TOR  0.793103         1.0      17       0.5          NaN
# 5        3  SAS  0.750000         1.0      16       1.5          NaN
# 6       31  DAL  0.739130         0.8      15       0.5          NaN
# 7       29  NOP  0.680000         0.6      11       0.5          NaN
# 8       25  MIL  0.666667         0.6      10       0.5         0.75
# 9       14  CHO  0.578947         0.6       7       0.5          NaN
# 10      34  NYK  0.500000         0.4       3       0.5          NaN
#
#     BLK_P_Diff  Spread  Total
# 0          NaN     2.5  232.5
# 1          NaN    -6.5  227.5
# 2          1.0     1.5  220.5
# 3         -1.0   -17.5  232.5
# 4          NaN    -1.5  220.5
# 5          NaN     3.5  244.5
# 6          NaN    -2.5  232.5
# 7          NaN    -8.5  247.5
# 8          3.0     3.5  227.5
# 9          NaN    -3.5  227.5
# 10         NaN     8.5  247.5
# C
#   Team  B2B              Player   Off_BLK  Off_L5_BLK  AVG_BLK_H2H  Off_Rk  \
# 0  NYK    0  Karl-Anthony Towns  1.461538         1.4     0.833333      34
# 1  DAL    0      Daniel Gafford  2.066667         2.0     3.000000       6
# 2  MIN    0         Rudy Gobert  2.000000         3.0     1.500000       7
# 3  ORL    0  Wendell Carter Jr.  1.466667         1.2     0.333333      33
# 4  DEN    0        Nikola Jokic  1.562500         1.8     0.400000      29
# 5  POR    0     Donovan Clingan  2.000000         2.4     1.000000       7
# 6  SAS    0   Victor Wembanyama  3.210526         2.8          NaN       1
# 7  MIA    0         Kel'el Ware  1.615385         1.8          NaN      24
# 8  CHO    0      Moussa Diabate  1.588235         1.2     0.833333      27
# 9  MIL    0        Myles Turner  1.916667         1.8     1.222222      12
#
#    Opp   Def_BLK  Def_L5_BLK  Def_Rk  BLK_line  BLK_Hit_Pct  BLK_P_Diff  \
# 0  NOP  2.000000         1.4      29       0.5          NaN         NaN
# 1  POR  1.571429         1.2      26       1.5          NaN         NaN
# 2  CHI  1.538462         0.6      24       1.5     0.333333         2.5
# 3  TOR  1.250000         0.4      19       0.5          NaN         NaN
# 4  MIA  1.217391         0.8      18       0.5          NaN         NaN
# 5  DAL  1.148148         1.0      15       1.5     0.750000         1.0
# 6  CLE  1.000000         0.8       9       2.5     0.250000         0.0
# 7  DEN  0.904762         1.4       5       1.5     0.250000        -2.0
# 8  MIL  0.812500         1.4       3       1.5          NaN         NaN
# 9  CHO  0.789474         0.6       2       1.5          NaN         NaN
#
#    Spread  Total
# 0    -8.5  247.5
# 1     2.5  232.5
# 2    -6.5  243.5
# 3    -1.5  220.5
# 4    -1.5  244.5
# 5    -2.5  232.5
# 6    -3.5  244.5
# 7     1.5  244.5
# 8     3.5  227.5
# 9    -3.5  227.5
# ===STL_BLK===
# PG
#   Team  B2B        Player  Off_STL_BLK  Off_L5_STL_BLK  AVG_STL_BLK_H2H  \
# 0  DAL    0  Cooper Flagg         2.25             2.0              NaN
#
#    Off_Rk  Opp  Def_STL_BLK  Def_L5_STL_BLK  Def_Rk  STL_BLK_line  \
# 0       7  POR     1.666667             1.4      14           1.5
#
#    STL_BLK_Hit_Pct  STL_BLK_P_Diff  Spread  Total
# 0              0.5             1.0     2.5  232.5
# SG
# Empty DataFrame
# Columns: [Team, B2B, Player, Off_STL_BLK, Off_L5_STL_BLK, AVG_STL_BLK_H2H, Off_Rk, Opp, Def_STL_BLK, Def_L5_STL_BLK, Def_Rk, STL_BLK_line, STL_BLK_Hit_Pct, STL_BLK_P_Diff, Spread, Total]
# Index: []
# SF
#   Team  B2B              Player  Off_STL_BLK  Off_L5_STL_BLK  AVG_STL_BLK_H2H  \
# 0  NYK    0       Mikal Bridges     3.200000             2.0         1.250000
# 1  POR    0         Deni Avdija     1.692308             1.6         1.142857
# 2  BRK    1  Michael Porter Jr.     1.625000             2.2         1.571429
# 3  GSW    1        Jimmy Butler     2.090909             1.4         1.428571
# 4  NOP    0     Trey Murphy III     2.360000             2.4              NaN
#
#    Off_Rk  Opp  Def_STL_BLK  Def_L5_STL_BLK  Def_Rk  STL_BLK_line  \
# 0       1  NOP     1.956522             1.4      26           1.5
# 1      29  DAL     1.861111             1.8      18           1.5
# 2      31  GSW     1.444444             1.0       7           1.5
# 3      15  BRK     1.413793             1.0       5           1.5
# 4       4  NYK     1.041667             1.2       2           1.5
#
#    STL_BLK_Hit_Pct  STL_BLK_P_Diff  Spread  Total
# 0              NaN             NaN    -8.5  247.5
# 1              NaN             NaN    -2.5  232.5
# 2              NaN             NaN     6.5  227.5
# 3              NaN             NaN    -6.5  227.5
# 4              NaN             NaN     8.5  247.5
# PF
#   Team  B2B                 Player  Off_STL_BLK  Off_L5_STL_BLK  \
# 0  DAL    0        P.J. Washington     2.481481             3.2
# 1  ORL    0         Paolo Banchero     1.866667             1.6
# 2  GSW    1         Draymond Green     2.000000             2.4
# 3  TOR    0         Scottie Barnes     3.064516             3.6
# 4  POR    0         Toumani Camara     2.000000             2.0
# 5  CHO    0          Miles Bridges     1.541667             1.8
# 6  MIL    0  Giannis Antetokounmpo     2.125000             1.6
# 7  NOP    0        Zion Williamson     2.153846             1.4
# 8  CLE    0            Evan Mobley     2.913043             3.0
# 9  NYK    0             OG Anunoby     2.700000             2.2
#
#    AVG_STL_BLK_H2H  Off_Rk  Opp  Def_STL_BLK  Def_L5_STL_BLK  Def_Rk  \
# 0         1.400000       5  POR     2.500000             1.4      30
# 1         1.833333      27  TOR     2.172414             2.0      27
# 2         0.500000      15  BRK     2.111111             2.4      26
# 3         2.600000       1  ORL     1.947368             3.0      22
# 4         1.000000      15  DAL     1.913043             2.8      20
# 5         0.875000      38  MIL     1.851852             2.2      18
# 6         1.250000      13  CHO     1.736842             1.6      14
# 7              NaN      12  NYK     1.545455             1.6       9
# 8              NaN       2  SAS     1.500000             1.6       5
# 9              NaN       4  NOP     1.320000             1.4       2
#
#    STL_BLK_line  STL_BLK_Hit_Pct  STL_BLK_P_Diff  Spread  Total
# 0           2.5              NaN             NaN     2.5  232.5
# 1           1.5              NaN             NaN    -1.5  220.5
# 2           1.5              NaN             NaN    -6.5  227.5
# 3           2.5         0.500000             0.0     1.5  220.5
# 4           1.5              NaN             NaN    -2.5  232.5
# 5           1.5         0.333333            -1.5     3.5  227.5
# 6           1.5              NaN             NaN    -3.5  227.5
# 7           1.5              NaN             NaN     8.5  247.5
# 8           1.5              NaN             NaN     3.5  244.5
# 9           2.5         0.333333            -2.5    -8.5  247.5
# C
#   Team  B2B              Player  Off_STL_BLK  Off_L5_STL_BLK  AVG_STL_BLK_H2H  \
# 0  NYK    0  Karl-Anthony Towns     1.916667             1.8              1.0
# 1  SAS    0   Victor Wembanyama     4.105263             3.2              NaN
#
#    Off_Rk  Opp  Def_STL_BLK  Def_L5_STL_BLK  Def_Rk  STL_BLK_line  \
# 0      35  NOP      3.00000             2.4      29           1.5
# 1       1  CLE      2.52381             3.6      24           3.5
#
#    STL_BLK_Hit_Pct  STL_BLK_P_Diff  Spread  Total
# 0         0.666667            -0.5    -8.5  247.5
# 1         0.333333            -0.5    -3.5  244.5

# %%
df_stats = pd.DataFrame()
for i in categories:
    print(f"==={i}===")
    df_temp = pick_finder(i, collect=True)
    df_stats = pd.concat([df_stats, df_temp], ignore_index=True)
    
df_stats = con.execute("SELECT Date, Team, B2B, Spread, Total, Player, Opp, * EXCLUDE(Date, Team, B2B, Player, Opp, Off_Rk, Def_Rk, Spread, Total) FROM df_stats").fetchdf()
df_save = pd.DataFrame()
for player in df_stats.Player.unique():
    df_temp = df_stats[(df_stats.Player == player)]
    for col in df_temp.columns.difference(['Date', 'Team', 'Player']):
        df_temp[col] = df_temp[col].ffill()
        df_temp[col] = df_temp[col].backfill()
    df_temp = df_temp.drop_duplicates()
    df_save = pd.concat([df_save, df_temp])
print('Saving for Date:', now)
partition_save_df(df_save, f"../tables/{year}/parlay_stats.csv")
display(df_save)

# %% [markdown]
# # REPOPULATE DATA

# %%
def pick_finder2(stat, season, now, df_inj, collect=False):    

    df_gms = pd.read_csv(f"../tables/{season}/nba_schedule.csv")
    df_gms['Date'] = pd.to_datetime(df_gms.Date)
    df_gms = df_gms[(df_gms.Date == now)]
    tms_today = df_gms.AwayABV.tolist() + df_gms.HomeABV.tolist()
    df_teams = pd.read_csv("../src/team_info_xref.csv")
    
    df_mtch = df_gms[['AwayABV', 'HomeABV', 'AwayB2B', 'HomeB2B']]
    df_mtch = df_mtch.rename(columns={"AwayABV": "Team", "HomeABV": "Opp", "AwayB2B": "B2B"})[['Team', 'Opp', 'B2B']]
    df_mtch2 = df_mtch.copy().rename(columns={"Team": "Opp", "Opp": "Team", "HomeB2B": "B2B"})[['Team', 'Opp', 'B2B']]
    df_mtch = pd.concat([df_mtch, df_mtch2])

    df_rk = con.execute(f"""SELECT *, RANK() OVER (PARTITION BY Pos ORDER BY Off_{stat} DESC) as Off_Rk FROM
                            (SELECT Team, Player, Pos, AVG({stat}) as Off_{stat} FROM df 
                            WHERE Season = {season} AND Pos != 'None' AND Date < '{now}'
                            AND Team IN ({str(tms_today).replace("[", "").replace("]", "")})
                            GROUP BY Team, Player, Pos)""").fetchdf()
    df_rk_l5 = con.execute(f"""WITH last5 AS (
                                    SELECT Team, Player, Pos, {stat} AS stat_val,
                                    ROW_NUMBER() OVER (PARTITION BY Team, Player ORDER BY Date DESC) AS rn
                                    FROM df
                                    WHERE Season = {season} AND Pos != 'None' AND Date < '{now}'
                                    AND Team IN ({str(tms_today).replace('[','').replace(']','')})
                            )
                            SELECT Team, Player, Pos, AVG(stat_val) AS Off_L5_{stat}
                            FROM last5
                            WHERE rn <= 5
                            GROUP BY Team, Player, Pos
                            """).fetchdf()
    df_rk = con.execute(f"""SELECT df_rk.Team, df_rk.Player, df_rk.Pos, Off_{stat}, Off_L5_{stat}, Off_Rk FROM df_rk JOIN df_rk_l5 
                            ON df_rk.Team = df_rk_l5.Team AND df_rk.Player = df_rk_l5.Player""").fetchdf()
    df_save = pd.DataFrame()
    for pos in ['PG', 'SG', 'SF', 'PF', 'C']:
        print(pos)
        df_def = con.execute(f"""SELECT Team, '{pos}' AS Pos, Def_{stat}, Def_Rk FROM
                                 (SELECT *, RANK() OVER (ORDER BY Def_{stat}) as Def_Rk FROM
                                 (SELECT Opp as Team, AVG({stat}) as Def_{stat} FROM df 
                                 WHERE MP >= 18 AND Season = {season} AND Pos = '{pos}' AND Date < '{now}'
                                 GROUP BY Opp
                                 ORDER BY AVG(Fpts) DESC))
                                 WHERE Team IN ({str(tms_today).replace("[", "").replace("]", "")})
                                 """).fetchdf()

        df_def_l5 = con.execute(f"""WITH last5 AS (
                                    SELECT Opp AS Team, {stat} AS stat_val, 
                                    ROW_NUMBER() OVER (PARTITION BY Opp ORDER BY Date DESC) AS rn
                                    FROM df
                                    WHERE MP >= 18 AND Season = {season} AND Pos = '{pos}' AND Date < '{now}'
                                    )

                                    SELECT Team, '{pos}' AS Pos, AVG(stat_val) AS Def_L5_{stat} FROM last5
                                    WHERE rn <= 5
                                    GROUP BY Team
                                    HAVING Team IN ({str(tms_today).replace('[','').replace(']','')})
                                    """).fetchdf()
        df_def = con.execute(f"""SELECT df_def.Team, df_def.Pos, Def_{stat}, Def_L5_{stat}, Def_Rk FROM df_def 
                               JOIN df_def_l5 ON df_def.Team = df_def_l5.Team""").fetchdf()
        # Piece together the current matchups with offensive rankings vs defensive rankings
        df_picks = con.execute(f"""SELECT df_mtch.*, df_rk.* EXCLUDE(Team) FROM df_mtch 
                                  JOIN df_rk ON df_mtch.Team = df_rk.Team
                                  WHERE Pos = '{pos}'""").fetchdf()
        df_picks = con.execute(f"""SELECT df_picks.* EXCLUDE(Opp, Pos), Opp, df_def.Def_{stat}, df_def.Def_L5_{stat}, 
                                   df_def.Def_Rk FROM df_picks 
                                   JOIN df_def ON df_picks.Opp = df_def.Team""").fetchdf()
        df_picks['Rk_Diff'] = df_picks['Def_Rk'] - df_picks['Off_Rk']
        df_picks = con.execute(f"""SELECT * EXCLUDE(Status) FROM
                                    (SELECT t1.* EXCLUDE(Rk_Diff), 
                                    CASE WHEN Status IS NULL THEN 'Available' ELSE Status END as Status FROM df_picks t1
                                    LEFT JOIN df_inj t2 ON t1.Team = t2.Team AND t1.Player = t2.Player
                                    ORDER BY Rk_Diff DESC)
                                   WHERE Status != 'Out'""").fetchdf()
        # head to head
        df_h2h = pd.DataFrame()
        for index, row in df_picks.iterrows():
            query = f"""SELECT * EXCLUDE(Gms) FROM
                       (SELECT Player, COUNT(*) as Gms, AVG({stat}) AS AVG_{stat}_H2H FROM df 
                       WHERE Player = ? AND Opp = ? AND Date < '{now}'
                       GROUP BY Player)
                       WHERE Gms >= 4"""
            df_temp = con.execute(query, [row["Player"], row["Opp"]]).fetchdf()
            df_h2h = pd.concat([df_h2h, df_temp])
        try:
            df_picks = con.execute(f"""SELECT Team, B2B, t1.Player, Off_{stat}, Off_L5_{stat}, t2.AVG_{stat}_H2H, Off_Rk, 
                                   t1.* EXCLUDE(Team, B2B, Player, Off_{stat}, Off_L5_{stat}, Off_Rk)
                                   FROM df_picks t1 LEFT JOIN df_h2h t2 
                                   ON t1.Player = t2.Player""").fetchdf()
        except:
            pass
    
        df_save = pd.concat([df_save, df_picks], ignore_index=True)
        if collect == False:
            display(df_picks)
    if collect == True:
        df_save.insert(0, 'Date', pd.to_datetime(now))
        return df_save

# %%
def repopulate_old_szns(season):
    schd = pd.read_csv(f"../tables/{season}/nba_schedule.csv")
    schd['Date'] = pd.to_datetime(schd.Date)
#     schd = schd[(schd.Date >= '2025-11-03')]
    df_lines = pd.read_csv(f"../tables/{season}/parlay_lines.csv")
    df_teams = pd.read_csv("../src/team_info_xref.csv")
    for date in schd.Date.unique().tolist():
        dt_str = date.strftime("%Y-%m-%d")
        print(dt_str)
        now = dt_str

        if now not in ['2023-05-02']:        
            df_inj = injury.get_reportdata(datetime.strptime(now, "%Y-%m-%d"), return_df=True)
            df_inj = df_inj.rename(columns={"Game Date": "Date", "Player Name": "Player", "Current Status": "Status"})
            df_inj['Player'] = df_inj.Player.str.split(",").str[1] + " " + df_inj.Player.str.split(",").str[0]
            df_inj['Player'] = df_inj['Player'].str.strip()
            df_inj['Date'] = pd.to_datetime(df_inj['Date'])
            df_inj = con.execute(f"""SELECT Date, ABV as Team, Player, Status, Reason FROM df_inj 
                                 JOIN df_teams ON df_inj.Team = df_teams.Team
                                 WHERE Date = '{now}' AND Status = 'Out'""").fetchdf()
        else:
            df_inj = pd.DataFrame(columns=['Date', 'Team', 'Player', 'Status', 'Reason'])
        
        df_stats = pd.DataFrame()
        for stat in categories:
            print(f"==={stat}===")
            df_temp = pick_finder2(stat, season, now, df_inj, collect=True)
            df_stats = pd.concat([df_stats, df_temp], ignore_index=True)

        df_stats = con.execute("SELECT Date, Team, B2B, Player, Opp, * EXCLUDE(Date, Team, B2B, Player, Opp, Off_Rk, Def_Rk) FROM df_stats").fetchdf()
        df_save = pd.DataFrame()
        for player in df_stats.Player.unique():
            df_temp = df_stats[(df_stats.Player == player)]
            for col in df_temp.columns.difference(['Date', 'Team', 'Player']):
                df_temp[col] = df_temp[col].ffill()
                df_temp[col] = df_temp[col].backfill()
            df_temp = df_temp.drop_duplicates()
            df_save = pd.concat([df_save, df_temp])
        print('Saving for Date:', now)
        print('row count - ', df_save.shape[0])
#         display(df_save)
        partition_save_df(df_save, f"../tables/{season}/parlay_stats.csv")
